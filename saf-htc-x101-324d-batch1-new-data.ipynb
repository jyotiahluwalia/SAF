# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# PyTorch version: 2.3.1
# CUDA available: True
# CUDA version: 12.1

# %%
# Check mmengine installation
import mmengine
print(f"MMengine: {mmengine.__version__}")

# Check Openmim installation
from importlib.metadata import version
print(f"Openmim: {version('openmim')}")

# Check mmcv installation
import mmcv
print("mmcv:",mmcv.__version__)

# Check MMDetection installation
import mmdet
print("mmdetection:",mmdet.__version__)
# Out:
# MMengine: 0.10.4
# Openmim: 0.3.9
# mmcv: 2.0.0rc4
# mmdetection: 3.3.0

# %%
import mmcv
import mmengine
from mmdet.apis import init_detector, inference_detector
from mmdet.utils import register_all_modules
# Choose to use a config and initialize the detector
config_file = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco.py'
# Setup a checkpoint file to load
checkpoint_file = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'

# register all modules in mmdet into the registries
register_all_modules()

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')  # or device='cuda:0'
# Out:
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias

# %%
from pycocotools.coco import COCO

# Path to load the COCO annotation file
annotation_file = 'mmdetection/data/saf24/train/annotation_coco.json'

# Initialise the COCO object
coco = COCO(annotation_file)

# Get all category tags and corresponding category IDs
categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}

# Print all category IDs and corresponding category names
for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Category ID: 1, Category Name: Blurry
# Category ID: 2, Category Name: ClassicalEvaporation
# Category ID: 3, Category Name: DiffusiveMixing
# Category ID: 4, Category Name: TransitionalMixing

# %% [markdown]
# ### Wandb integration

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# True

# %%
# Weights and Biases version
print(wandb.__version__)
# Out:
# 0.17.5

# %% [markdown]
# ## Hypertuning the Parameters

# %%
from mmengine.runner import set_random_seed
from mmengine import Config
import random
import numpy as np
import matplotlib.pyplot as plt
from mmdet.visualization import DetLocalVisualizer
import os
import cv2

# %%
# Load the configuration
cfg = Config.fromfile('mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco.py')


# Modify dataset classes and color
cfg.metainfo = {
    'classes': ('ClassicalEvaporation', 'TransitionalMixing', 'DiffusiveMixing', 'Blurry'),
    'palette': [
        (13,24,103), (167,13,13), (91,117,249), (203,173,55),
    ]
}

# Modify dataset type and path
cfg.data_root = 'mmdetection/data/saf24/'

cfg.train_dataloader.dataset.ann_file = 'train/annotation_coco.json'
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = {'img': 'train/'}
cfg.train_dataloader.dataset.metainfo = cfg.metainfo

cfg.val_dataloader.dataset.ann_file = 'val/annotation_coco.json'
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = {'img': 'val/'}
cfg.val_dataloader.dataset.metainfo = cfg.metainfo

cfg.test_dataloader = cfg.val_dataloader

# Modify metric config
cfg.val_evaluator.ann_file = f'{cfg.data_root}val/annotation_coco.json'
cfg.test_evaluator = cfg.val_evaluator

################################################################################################

# Modify num classes of the model in box head and mask head
if isinstance(cfg.model.roi_head.bbox_head, list):
    for head in cfg.model.roi_head.bbox_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.bbox_head.num_classes = 4

if isinstance(cfg.model.roi_head.mask_head, list):
    for head in cfg.model.roi_head.mask_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.mask_head.num_classes = 4

################################################################################################

# Configure checkpoint saving
cfg.default_hooks.checkpoint = dict(
    type='CheckpointHook',
    interval=1,
    save_optimizer=True,
    save_best = ['coco/bbox_mAP','coco/segm_mAP'],
    save_last=True,
    rule='greater',
    max_keep_ckpts=1
)

cfg.default_hooks.early_stopping = dict(
    type="EarlyStoppingHook",
    monitor="coco/segm_mAP",
    patience=10,
    min_delta=0.005
)

cfg.test_evaluator.update(dict(classwise=True))

# Use the pre-trained HTC model
cfg.load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'

# Set up working dir to save files and logs
cfg.work_dir = './tutorial_exps/60-new-data-batch1'

# Set the number of epochs
cfg.train_cfg.max_epochs = 60

# Set the evaluation interval
cfg.train_cfg.val_interval = 3

# Set the checkpoint saving interval to reduce the storage cost
cfg.default_hooks.checkpoint.interval = 3

# Adjust learning rate for single GPU
cfg.optim_wrapper.optimizer.lr = 0.02 / 8

# Set logging interval
cfg.default_hooks.logger.interval = 10

# Set seed for reproducibility
set_random_seed(0, deterministic=False)

# Use Tensorboard to log the training process
cfg.visualizer.vis_backends.append({"type": 'TensorboardVisBackend'})

# Configure WandB logger
cfg.visualizer.vis_backends.append(dict(type='WandbVisBackend', init_kwargs=dict(
    project='SAF_Project',
    entity='ahluwaliajyoti50-university-of-sussex',
    config={
        'learning_rate': cfg.optim_wrapper.optimizer.lr,
        'architecture': 'HTC_resnext101_32x4d',
        'dataset': 'SAF22',
        'epochs': cfg.train_cfg.max_epochs,
        'batch_size': cfg.train_dataloader.batch_size,
        'optimizer': cfg.optim_wrapper.optimizer.type,
        'classes': cfg.metainfo['classes'],
        'seed': 0,
    }
)))

# Save the modified config
config = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco-new-data-batch1.py'
with open(config, 'w') as f:
    f.write(cfg.pretty_text)

# Train using train.py
# %run mmdetection/tools/train.py {config}

# [Optional] Finish the wandb run
wandb.finish()
# Out:
# 08/15 10:51:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 209652396
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#     MSVC: n/a, reason: fileno
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 209652396
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/15 10:51:33 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf24/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.005,
#         monitor='coco/segm_mAP',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TransitionalMixing',
#         'DiffusiveMixing',
#         'Blurry',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf24/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf24/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=60, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf24/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf24/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf24/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TransitionalMixing',
#                         'DiffusiveMixing',
#                         'Blurry',
#                     ),
#                     dataset='SAF22',
#                     epochs=60,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/150-new-data-batch1'
# wandb version 0.17.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>C:\Users\ja683\Downloads\saf\tutorial_exps\150-new-data-batch1\20240815_105128\vis_data\wandb\run-20240815_105134-rrysdpw1</code>
# Syncing run <strong><a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/rrysdpw1' target="_blank">pleasant-snowflake-100</a></strong> to <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a>
#  View run at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/rrysdpw1' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/rrysdpw1</a>
# 08/15 10:51:51 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/15 10:51:51 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 08/15 10:51:52 - mmengine - INFO - load model from: open-mmlab://resnext101_32x4d
# 08/15 10:51:52 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_32x4d
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias
#
# 08/15 10:51:52 - mmengine - INFO - Load checkpoint from mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# 08/15 10:51:52 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/15 10:51:52 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/15 10:51:52 - mmengine - INFO - Checkpoints will be saved to C:\Users\ja683\Downloads\saf\tutorial_exps\150-new-data-batch1.
# 08/15 10:52:17 - mmengine - INFO - Epoch(train)  [1][ 10/286]  lr: 4.7545e-05  eta: 11:47:50  time: 2.4764  data_time: 1.8290  memory: 5133  loss: 5.1856  loss_rpn_cls: 0.7798  loss_rpn_bbox: 0.0386  s0.loss_cls: 1.4408  s0.acc: 80.6641  s0.loss_bbox: 0.1296  s0.loss_mask: 0.7084  s1.loss_cls: 0.8434  s1.acc: 12.1094  s1.loss_bbox: 0.1318  s1.loss_mask: 0.4008  s2.loss_cls: 0.4040  s2.acc: 17.3828  s2.loss_bbox: 0.0582  s2.loss_mask: 0.2502
# 08/15 10:52:21 - mmengine - INFO - Epoch(train)  [1][ 20/286]  lr: 9.7595e-05  eta: 6:43:32  time: 1.4126  data_time: 0.9186  memory: 5064  loss: 4.7556  loss_rpn_cls: 0.5559  loss_rpn_bbox: 0.0411  s0.loss_cls: 1.3193  s0.acc: 96.8750  s0.loss_bbox: 0.1494  s0.loss_mask: 0.7050  s1.loss_cls: 0.7903  s1.acc: 94.9219  s1.loss_bbox: 0.1433  s1.loss_mask: 0.3859  s2.loss_cls: 0.3816  s2.acc: 95.8984  s2.loss_bbox: 0.0499  s2.loss_mask: 0.2338
# 08/15 10:52:24 - mmengine - INFO - Epoch(train)  [1][ 30/286]  lr: 1.4765e-04  eta: 5:02:13  time: 1.0586  data_time: 0.6155  memory: 5214  loss: 4.2366  loss_rpn_cls: 0.3788  loss_rpn_bbox: 0.0418  s0.loss_cls: 1.1325  s0.acc: 99.2188  s0.loss_bbox: 0.1499  s0.loss_mask: 0.6975  s1.loss_cls: 0.6893  s1.acc: 99.2188  s1.loss_bbox: 0.1493  s1.loss_mask: 0.3802  s2.loss_cls: 0.3409  s2.acc: 99.4141  s2.loss_bbox: 0.0542  s2.loss_mask: 0.2222
# 08/15 10:52:27 - mmengine - INFO - Epoch(train)  [1][ 40/286]  lr: 1.9770e-04  eta: 4:09:53  time: 0.8758  data_time: 0.4635  memory: 4939  loss: 3.7251  loss_rpn_cls: 0.2938  loss_rpn_bbox: 0.0381  s0.loss_cls: 0.9388  s0.acc: 96.6797  s0.loss_bbox: 0.1339  s0.loss_mask: 0.6857  s1.loss_cls: 0.5735  s1.acc: 95.5078  s1.loss_bbox: 0.1393  s1.loss_mask: 0.3718  s2.loss_cls: 0.2869  s2.acc: 94.9219  s2.loss_bbox: 0.0496  s2.loss_mask: 0.2137
# 08/15 10:52:31 - mmengine - INFO - Epoch(train)  [1][ 50/286]  lr: 2.4775e-04  eta: 3:40:00  time: 0.7715  data_time: 0.3725  memory: 5426  loss: 3.4513  loss_rpn_cls: 0.2389  loss_rpn_bbox: 0.0363  s0.loss_cls: 0.8438  s0.acc: 93.9453  s0.loss_bbox: 0.1331  s0.loss_mask: 0.6754  s1.loss_cls: 0.5079  s1.acc: 92.5781  s1.loss_bbox: 0.1410  s1.loss_mask: 0.3635  s2.loss_cls: 0.2513  s2.acc: 93.3594  s2.loss_bbox: 0.0543  s2.loss_mask: 0.2058
# 08/15 10:52:34 - mmengine - INFO - Epoch(train)  [1][ 60/286]  lr: 2.9780e-04  eta: 3:19:25  time: 0.3444  data_time: 0.0080  memory: 4899  loss: 2.8408  loss_rpn_cls: 0.0855  loss_rpn_bbox: 0.0365  s0.loss_cls: 0.6239  s0.acc: 96.6797  s0.loss_bbox: 0.1398  s0.loss_mask: 0.6530  s1.loss_cls: 0.3753  s1.acc: 95.1172  s1.loss_bbox: 0.1469  s1.loss_mask: 0.3484  s2.loss_cls: 0.1856  s2.acc: 94.1406  s2.loss_bbox: 0.0540  s2.loss_mask: 0.1918
# 08/15 10:52:38 - mmengine - INFO - Epoch(train)  [1][ 70/286]  lr: 3.4785e-04  eta: 3:04:20  time: 0.3410  data_time: 0.0080  memory: 4907  loss: 2.3456  loss_rpn_cls: 0.0223  loss_rpn_bbox: 0.0338  s0.loss_cls: 0.4415  s0.acc: 94.3359  s0.loss_bbox: 0.1347  s0.loss_mask: 0.6218  s1.loss_cls: 0.2565  s1.acc: 95.1172  s1.loss_bbox: 0.1397  s1.loss_mask: 0.3342  s2.loss_cls: 0.1265  s2.acc: 98.4375  s2.loss_bbox: 0.0533  s2.loss_mask: 0.1813
# 08/15 10:52:42 - mmengine - INFO - Epoch(train)  [1][ 80/286]  lr: 3.9790e-04  eta: 2:55:27  time: 0.3510  data_time: 0.0090  memory: 5445  loss: 2.2263  loss_rpn_cls: 0.0239  loss_rpn_bbox: 0.0373  s0.loss_cls: 0.3897  s0.acc: 77.9297  s0.loss_bbox: 0.1531  s0.loss_mask: 0.6002  s1.loss_cls: 0.2123  s1.acc: 81.8359  s1.loss_bbox: 0.1537  s1.loss_mask: 0.3232  s2.loss_cls: 0.0983  s2.acc: 88.2812  s2.loss_bbox: 0.0590  s2.loss_mask: 0.1755
# 08/15 10:52:46 - mmengine - INFO - Epoch(train)  [1][ 90/286]  lr: 4.4795e-04  eta: 2:48:23  time: 0.3648  data_time: 0.0102  memory: 5408  loss: 2.2250  loss_rpn_cls: 0.0203  loss_rpn_bbox: 0.0409  s0.loss_cls: 0.3955  s0.acc: 83.9844  s0.loss_bbox: 0.1708  s0.loss_mask: 0.5660  s1.loss_cls: 0.2137  s1.acc: 75.0000  s1.loss_bbox: 0.1725  s1.loss_mask: 0.3073  s2.loss_cls: 0.0977  s2.acc: 80.2734  s2.loss_bbox: 0.0738  s2.loss_mask: 0.1664
# 08/15 10:52:49 - mmengine - INFO - Epoch(train)  [1][100/286]  lr: 4.9800e-04  eta: 2:41:10  time: 0.3622  data_time: 0.0102  memory: 5380  loss: 2.0715  loss_rpn_cls: 0.0182  loss_rpn_bbox: 0.0412  s0.loss_cls: 0.3510  s0.acc: 84.1797  s0.loss_bbox: 0.1680  s0.loss_mask: 0.5256  s1.loss_cls: 0.1933  s1.acc: 80.4688  s1.loss_bbox: 0.1716  s1.loss_mask: 0.2868  s2.loss_cls: 0.0898  s2.acc: 86.9141  s2.loss_bbox: 0.0728  s2.loss_mask: 0.1534
# 08/15 10:52:53 - mmengine - INFO - Epoch(train)  [1][110/286]  lr: 5.4805e-04  eta: 2:35:52  time: 0.3670  data_time: 0.0110  memory: 5522  loss: 2.0203  loss_rpn_cls: 0.0240  loss_rpn_bbox: 0.0405  s0.loss_cls: 0.3482  s0.acc: 98.8281  s0.loss_bbox: 0.1657  s0.loss_mask: 0.4980  s1.loss_cls: 0.1943  s1.acc: 96.8750  s1.loss_bbox: 0.1756  s1.loss_mask: 0.2668  s2.loss_cls: 0.0920  s2.acc: 99.2188  s2.loss_bbox: 0.0759  s2.loss_mask: 0.1394
# 08/15 10:52:56 - mmengine - INFO - Epoch(train)  [1][120/286]  lr: 5.9810e-04  eta: 2:31:29  time: 0.3742  data_time: 0.0111  memory: 5496  loss: 2.0128  loss_rpn_cls: 0.0236  loss_rpn_bbox: 0.0411  s0.loss_cls: 0.3556  s0.acc: 93.5547  s0.loss_bbox: 0.1660  s0.loss_mask: 0.4689  s1.loss_cls: 0.2019  s1.acc: 92.1875  s1.loss_bbox: 0.1954  s1.loss_mask: 0.2488  s2.loss_cls: 0.0968  s2.acc: 85.1562  s2.loss_bbox: 0.0875  s2.loss_mask: 0.1273
# 08/15 10:53:00 - mmengine - INFO - Epoch(train)  [1][130/286]  lr: 6.4815e-04  eta: 2:27:58  time: 0.3693  data_time: 0.0100  memory: 5461  loss: 1.8088  loss_rpn_cls: 0.0190  loss_rpn_bbox: 0.0348  s0.loss_cls: 0.3107  s0.acc: 99.8047  s0.loss_bbox: 0.1383  s0.loss_mask: 0.4325  s1.loss_cls: 0.1818  s1.acc: 99.4141  s1.loss_bbox: 0.1815  s1.loss_mask: 0.2243  s2.loss_cls: 0.0895  s2.acc: 94.7266  s2.loss_bbox: 0.0847  s2.loss_mask: 0.1117
# 08/15 10:53:04 - mmengine - INFO - Epoch(train)  [1][140/286]  lr: 6.9820e-04  eta: 2:24:37  time: 0.3622  data_time: 0.0090  memory: 5433  loss: 1.6770  loss_rpn_cls: 0.0184  loss_rpn_bbox: 0.0326  s0.loss_cls: 0.2856  s0.acc: 99.8047  s0.loss_bbox: 0.1294  s0.loss_mask: 0.4072  s1.loss_cls: 0.1646  s1.acc: 99.6094  s1.loss_bbox: 0.1752  s1.loss_mask: 0.2050  s2.loss_cls: 0.0801  s2.acc: 95.3125  s2.loss_bbox: 0.0795  s2.loss_mask: 0.0995
# 08/15 10:53:08 - mmengine - INFO - Epoch(train)  [1][150/286]  lr: 7.4825e-04  eta: 2:22:22  time: 0.3730  data_time: 0.0096  memory: 5496  loss: 1.7053  loss_rpn_cls: 0.0199  loss_rpn_bbox: 0.0350  s0.loss_cls: 0.3012  s0.acc: 92.3828  s0.loss_bbox: 0.1350  s0.loss_mask: 0.3955  s1.loss_cls: 0.1717  s1.acc: 88.0859  s1.loss_bbox: 0.1855  s1.loss_mask: 0.1953  s2.loss_cls: 0.0843  s2.acc: 91.2109  s2.loss_bbox: 0.0872  s2.loss_mask: 0.0949
# 08/15 10:53:12 - mmengine - INFO - Epoch(train)  [1][160/286]  lr: 7.9830e-04  eta: 2:20:20  time: 0.3783  data_time: 0.0103  memory: 5543  loss: 1.6715  loss_rpn_cls: 0.0132  loss_rpn_bbox: 0.0339  s0.loss_cls: 0.2932  s0.acc: 92.5781  s0.loss_bbox: 0.1324  s0.loss_mask: 0.3872  s1.loss_cls: 0.1662  s1.acc: 89.8438  s1.loss_bbox: 0.1856  s1.loss_mask: 0.1928  s2.loss_cls: 0.0832  s2.acc: 90.6250  s2.loss_bbox: 0.0902  s2.loss_mask: 0.0935
# 08/15 10:53:15 - mmengine - INFO - Epoch(train)  [1][170/286]  lr: 8.4835e-04  eta: 2:18:22  time: 0.3813  data_time: 0.0109  memory: 5478  loss: 1.6273  loss_rpn_cls: 0.0324  loss_rpn_bbox: 0.0397  s0.loss_cls: 0.2765  s0.acc: 99.8047  s0.loss_bbox: 0.1328  s0.loss_mask: 0.3739  s1.loss_cls: 0.1571  s1.acc: 99.8047  s1.loss_bbox: 0.1768  s1.loss_mask: 0.1823  s2.loss_cls: 0.0797  s2.acc: 99.6094  s2.loss_bbox: 0.0885  s2.loss_mask: 0.0877
# 08/15 10:53:19 - mmengine - INFO - Epoch(train)  [1][180/286]  lr: 8.9840e-04  eta: 2:16:51  time: 0.3854  data_time: 0.0114  memory: 5532  loss: 1.6691  loss_rpn_cls: 0.0347  loss_rpn_bbox: 0.0427  s0.loss_cls: 0.2873  s0.acc: 76.7578  s0.loss_bbox: 0.1467  s0.loss_mask: 0.3675  s1.loss_cls: 0.1621  s1.acc: 73.9044  s1.loss_bbox: 0.1881  s1.loss_mask: 0.1787  s2.loss_cls: 0.0813  s2.acc: 90.4382  s2.loss_bbox: 0.0943  s2.loss_mask: 0.0857
# 08/15 10:53:23 - mmengine - INFO - Epoch(train)  [1][190/286]  lr: 9.4845e-04  eta: 2:15:21  time: 0.3910  data_time: 0.0118  memory: 5581  loss: 1.6975  loss_rpn_cls: 0.0341  loss_rpn_bbox: 0.0460  s0.loss_cls: 0.2918  s0.acc: 90.4297  s0.loss_bbox: 0.1516  s0.loss_mask: 0.3685  s1.loss_cls: 0.1642  s1.acc: 88.2812  s1.loss_bbox: 0.1939  s1.loss_mask: 0.1802  s2.loss_cls: 0.0827  s2.acc: 88.2812  s2.loss_bbox: 0.0985  s2.loss_mask: 0.0862
# 08/15 10:53:27 - mmengine - INFO - Epoch(train)  [1][200/286]  lr: 9.9850e-04  eta: 2:14:21  time: 0.3945  data_time: 0.0128  memory: 5577  loss: 1.7312  loss_rpn_cls: 0.0352  loss_rpn_bbox: 0.0549  s0.loss_cls: 0.3012  s0.acc: 87.1094  s0.loss_bbox: 0.1581  s0.loss_mask: 0.3714  s1.loss_cls: 0.1705  s1.acc: 87.2727  s1.loss_bbox: 0.1910  s1.loss_mask: 0.1804  s2.loss_cls: 0.0857  s2.acc: 83.2323  s2.loss_bbox: 0.0969  s2.loss_mask: 0.0859
# 08/15 10:53:31 - mmengine - INFO - Epoch(train)  [1][210/286]  lr: 1.0485e-03  eta: 2:13:12  time: 0.3954  data_time: 0.0126  memory: 5535  loss: 1.7227  loss_rpn_cls: 0.0369  loss_rpn_bbox: 0.0553  s0.loss_cls: 0.3015  s0.acc: 94.3359  s0.loss_bbox: 0.1589  s0.loss_mask: 0.3611  s1.loss_cls: 0.1727  s1.acc: 92.1875  s1.loss_bbox: 0.1924  s1.loss_mask: 0.1737  s2.loss_cls: 0.0870  s2.acc: 91.4062  s2.loss_bbox: 0.1007  s2.loss_mask: 0.0826
# 08/15 10:53:35 - mmengine - INFO - Epoch(train)  [1][220/286]  lr: 1.0986e-03  eta: 2:12:17  time: 0.4001  data_time: 0.0127  memory: 5567  loss: 1.7815  loss_rpn_cls: 0.0286  loss_rpn_bbox: 0.0525  s0.loss_cls: 0.3250  s0.acc: 88.6719  s0.loss_bbox: 0.1649  s0.loss_mask: 0.3647  s1.loss_cls: 0.1836  s1.acc: 88.5375  s1.loss_bbox: 0.2073  s1.loss_mask: 0.1748  s2.loss_cls: 0.0910  s2.acc: 87.9921  s2.loss_bbox: 0.1065  s2.loss_mask: 0.0826
# 08/15 10:53:39 - mmengine - INFO - Epoch(train)  [1][230/286]  lr: 1.1486e-03  eta: 2:11:17  time: 0.3995  data_time: 0.0124  memory: 5363  loss: 1.7612  loss_rpn_cls: 0.0287  loss_rpn_bbox: 0.0527  s0.loss_cls: 0.3175  s0.acc: 91.6016  s0.loss_bbox: 0.1661  s0.loss_mask: 0.3604  s1.loss_cls: 0.1779  s1.acc: 87.8906  s1.loss_bbox: 0.2080  s1.loss_mask: 0.1724  s2.loss_cls: 0.0900  s2.acc: 83.5938  s2.loss_bbox: 0.1061  s2.loss_mask: 0.0813
# 08/15 10:53:43 - mmengine - INFO - Epoch(train)  [1][240/286]  lr: 1.1987e-03  eta: 2:10:25  time: 0.4014  data_time: 0.0132  memory: 5461  loss: 1.7860  loss_rpn_cls: 0.0303  loss_rpn_bbox: 0.0503  s0.loss_cls: 0.3325  s0.acc: 87.8906  s0.loss_bbox: 0.1718  s0.loss_mask: 0.3594  s1.loss_cls: 0.1853  s1.acc: 87.6953  s1.loss_bbox: 0.2087  s1.loss_mask: 0.1709  s2.loss_cls: 0.0921  s2.acc: 86.5234  s2.loss_bbox: 0.1041  s2.loss_mask: 0.0805
# 08/15 10:53:47 - mmengine - INFO - Epoch(train)  [1][250/286]  lr: 1.2487e-03  eta: 2:09:23  time: 0.3943  data_time: 0.0117  memory: 5487  loss: 1.7705  loss_rpn_cls: 0.0331  loss_rpn_bbox: 0.0394  s0.loss_cls: 0.3264  s0.acc: 85.9375  s0.loss_bbox: 0.1746  s0.loss_mask: 0.3548  s1.loss_cls: 0.1781  s1.acc: 83.0078  s1.loss_bbox: 0.2174  s1.loss_mask: 0.1705  s2.loss_cls: 0.0889  s2.acc: 85.1562  s2.loss_bbox: 0.1064  s2.loss_mask: 0.0809
# 08/15 10:53:51 - mmengine - INFO - Epoch(train)  [1][260/286]  lr: 1.2988e-03  eta: 2:08:12  time: 0.3864  data_time: 0.0108  memory: 5551  loss: 1.7603  loss_rpn_cls: 0.0318  loss_rpn_bbox: 0.0387  s0.loss_cls: 0.3171  s0.acc: 91.7969  s0.loss_bbox: 0.1805  s0.loss_mask: 0.3618  s1.loss_cls: 0.1736  s1.acc: 86.1328  s1.loss_bbox: 0.2175  s1.loss_mask: 0.1726  s2.loss_cls: 0.0854  s2.acc: 93.9453  s2.loss_bbox: 0.1008  s2.loss_mask: 0.0806
# 08/15 10:53:54 - mmengine - INFO - Epoch(train)  [1][270/286]  lr: 1.3488e-03  eta: 2:07:12  time: 0.3787  data_time: 0.0105  memory: 5452  loss: 1.6659  loss_rpn_cls: 0.0215  loss_rpn_bbox: 0.0406  s0.loss_cls: 0.2898  s0.acc: 95.3125  s0.loss_bbox: 0.1693  s0.loss_mask: 0.3612  s1.loss_cls: 0.1597  s1.acc: 94.5312  s1.loss_bbox: 0.1976  s1.loss_mask: 0.1732  s2.loss_cls: 0.0796  s2.acc: 88.2812  s2.loss_bbox: 0.0927  s2.loss_mask: 0.0807
# 08/15 10:53:58 - mmengine - INFO - Epoch(train)  [1][280/286]  lr: 1.3989e-03  eta: 2:06:09  time: 0.3709  data_time: 0.0100  memory: 5523  loss: 1.6101  loss_rpn_cls: 0.0212  loss_rpn_bbox: 0.0397  s0.loss_cls: 0.2782  s0.acc: 96.8750  s0.loss_bbox: 0.1551  s0.loss_mask: 0.3608  s1.loss_cls: 0.1528  s1.acc: 95.1172  s1.loss_bbox: 0.1816  s1.loss_mask: 0.1738  s2.loss_cls: 0.0758  s2.acc: 95.5078  s2.loss_bbox: 0.0898  s2.loss_mask: 0.0814
# 08/15 10:54:00 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco-new-data-batch1_20240815_105128
# 08/15 10:54:04 - mmengine - INFO - Epoch(train)  [2][ 10/286]  lr: 1.4790e-03  eta: 2:04:55  time: 0.3668  data_time: 0.0096  memory: 5568  loss: 1.6199  loss_rpn_cls: 0.0223  loss_rpn_bbox: 0.0451  s0.loss_cls: 0.2671  s0.acc: 88.8672  s0.loss_bbox: 0.1538  s0.loss_mask: 0.3710  s1.loss_cls: 0.1469  s1.acc: 84.5703  s1.loss_bbox: 0.1864  s1.loss_mask: 0.1779  s2.loss_cls: 0.0740  s2.acc: 90.4297  s2.loss_bbox: 0.0928  s2.loss_mask: 0.0826
# 08/15 10:54:08 - mmengine - INFO - Epoch(train)  [2][ 20/286]  lr: 1.5290e-03  eta: 2:04:04  time: 0.3641  data_time: 0.0097  memory: 5523  loss: 1.5276  loss_rpn_cls: 0.0172  loss_rpn_bbox: 0.0462  s0.loss_cls: 0.2499  s0.acc: 88.6719  s0.loss_bbox: 0.1340  s0.loss_mask: 0.3573  s1.loss_cls: 0.1368  s1.acc: 82.2266  s1.loss_bbox: 0.1750  s1.loss_mask: 0.1711  s2.loss_cls: 0.0706  s2.acc: 79.2969  s2.loss_bbox: 0.0903  s2.loss_mask: 0.0792
# 08/15 10:54:11 - mmengine - INFO - Epoch(train)  [2][ 30/286]  lr: 1.5791e-03  eta: 2:03:04  time: 0.3597  data_time: 0.0091  memory: 5381  loss: 1.4428  loss_rpn_cls: 0.0165  loss_rpn_bbox: 0.0424  s0.loss_cls: 0.2346  s0.acc: 96.2891  s0.loss_bbox: 0.1272  s0.loss_mask: 0.3358  s1.loss_cls: 0.1270  s1.acc: 94.5312  s1.loss_bbox: 0.1655  s1.loss_mask: 0.1621  s2.loss_cls: 0.0666  s2.acc: 93.7500  s2.loss_bbox: 0.0890  s2.loss_mask: 0.0760
# 08/15 10:54:15 - mmengine - INFO - Epoch(train)  [2][ 40/286]  lr: 1.6291e-03  eta: 2:02:28  time: 0.3614  data_time: 0.0092  memory: 5505  loss: 1.4568  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0404  s0.loss_cls: 0.2357  s0.acc: 86.3281  s0.loss_bbox: 0.1315  s0.loss_mask: 0.3354  s1.loss_cls: 0.1261  s1.acc: 85.7988  s1.loss_bbox: 0.1767  s1.loss_mask: 0.1622  s2.loss_cls: 0.0659  s2.acc: 83.2347  s2.loss_bbox: 0.0910  s2.loss_mask: 0.0763
# 08/15 10:54:18 - mmengine - INFO - Epoch(train)  [2][ 50/286]  lr: 1.6792e-03  eta: 2:01:55  time: 0.3657  data_time: 0.0104  memory: 5381  loss: 1.4321  loss_rpn_cls: 0.0160  loss_rpn_bbox: 0.0434  s0.loss_cls: 0.2304  s0.acc: 96.6797  s0.loss_bbox: 0.1302  s0.loss_mask: 0.3319  s1.loss_cls: 0.1222  s1.acc: 98.4375  s1.loss_bbox: 0.1696  s1.loss_mask: 0.1618  s2.loss_cls: 0.0635  s2.acc: 96.8750  s2.loss_bbox: 0.0869  s2.loss_mask: 0.0763
# 08/15 10:54:22 - mmengine - INFO - Epoch(train)  [2][ 60/286]  lr: 1.7292e-03  eta: 2:01:14  time: 0.3626  data_time: 0.0096  memory: 5496  loss: 1.3709  loss_rpn_cls: 0.0113  loss_rpn_bbox: 0.0372  s0.loss_cls: 0.2109  s0.acc: 98.6328  s0.loss_bbox: 0.1235  s0.loss_mask: 0.3302  s1.loss_cls: 0.1129  s1.acc: 97.4609  s1.loss_bbox: 0.1639  s1.loss_mask: 0.1619  s2.loss_cls: 0.0595  s2.acc: 97.6562  s2.loss_bbox: 0.0823  s2.loss_mask: 0.0773
# 08/15 10:54:26 - mmengine - INFO - Epoch(train)  [2][ 70/286]  lr: 1.7793e-03  eta: 2:00:54  time: 0.3704  data_time: 0.0102  memory: 5541  loss: 1.4228  loss_rpn_cls: 0.0113  loss_rpn_bbox: 0.0380  s0.loss_cls: 0.2192  s0.acc: 96.6797  s0.loss_bbox: 0.1294  s0.loss_mask: 0.3412  s1.loss_cls: 0.1182  s1.acc: 98.2422  s1.loss_bbox: 0.1709  s1.loss_mask: 0.1675  s2.loss_cls: 0.0619  s2.acc: 85.9375  s2.loss_bbox: 0.0858  s2.loss_mask: 0.0795
# 08/15 10:54:30 - mmengine - INFO - Epoch(train)  [2][ 80/286]  lr: 1.8293e-03  eta: 2:00:30  time: 0.3805  data_time: 0.0108  memory: 5478  loss: 1.5153  loss_rpn_cls: 0.0127  loss_rpn_bbox: 0.0392  s0.loss_cls: 0.2409  s0.acc: 94.9219  s0.loss_bbox: 0.1386  s0.loss_mask: 0.3467  s1.loss_cls: 0.1298  s1.acc: 98.4375  s1.loss_bbox: 0.1916  s1.loss_mask: 0.1698  s2.loss_cls: 0.0682  s2.acc: 87.5000  s2.loss_bbox: 0.0968  s2.loss_mask: 0.0809
# 08/15 10:54:34 - mmengine - INFO - Epoch(train)  [2][ 90/286]  lr: 1.8794e-03  eta: 2:00:00  time: 0.3799  data_time: 0.0100  memory: 5514  loss: 1.5090  loss_rpn_cls: 0.0113  loss_rpn_bbox: 0.0353  s0.loss_cls: 0.2399  s0.acc: 83.2031  s0.loss_bbox: 0.1366  s0.loss_mask: 0.3482  s1.loss_cls: 0.1312  s1.acc: 81.1395  s1.loss_bbox: 0.1888  s1.loss_mask: 0.1701  s2.loss_cls: 0.0684  s2.acc: 82.7112  s2.loss_bbox: 0.0981  s2.loss_mask: 0.0811
# 08/15 10:54:38 - mmengine - INFO - Epoch(train)  [2][100/286]  lr: 1.9294e-03  eta: 1:59:43  time: 0.3839  data_time: 0.0098  memory: 5532  loss: 1.5701  loss_rpn_cls: 0.0115  loss_rpn_bbox: 0.0333  s0.loss_cls: 0.2635  s0.acc: 76.1719  s0.loss_bbox: 0.1471  s0.loss_mask: 0.3421  s1.loss_cls: 0.1434  s1.acc: 75.2475  s1.loss_bbox: 0.2041  s1.loss_mask: 0.1662  s2.loss_cls: 0.0740  s2.acc: 77.7120  s2.loss_bbox: 0.1063  s2.loss_mask: 0.0786
# 08/15 10:54:42 - mmengine - INFO - Epoch(train)  [2][110/286]  lr: 1.9795e-03  eta: 1:59:23  time: 0.3906  data_time: 0.0109  memory: 5522  loss: 1.6129  loss_rpn_cls: 0.0115  loss_rpn_bbox: 0.0377  s0.loss_cls: 0.2789  s0.acc: 77.5391  s0.loss_bbox: 0.1528  s0.loss_mask: 0.3407  s1.loss_cls: 0.1503  s1.acc: 77.5758  s1.loss_bbox: 0.2092  s1.loss_mask: 0.1645  s2.loss_cls: 0.0774  s2.acc: 81.4229  s2.loss_bbox: 0.1125  s2.loss_mask: 0.0772
# 08/15 10:54:45 - mmengine - INFO - Epoch(train)  [2][120/286]  lr: 2.0295e-03  eta: 1:59:03  time: 0.3882  data_time: 0.0107  memory: 5397  loss: 1.6259  loss_rpn_cls: 0.0119  loss_rpn_bbox: 0.0413  s0.loss_cls: 0.2853  s0.acc: 84.9609  s0.loss_bbox: 0.1578  s0.loss_mask: 0.3362  s1.loss_cls: 0.1520  s1.acc: 84.5382  s1.loss_bbox: 0.2131  s1.loss_mask: 0.1622  s2.loss_cls: 0.0765  s2.acc: 85.9719  s2.loss_bbox: 0.1132  s2.loss_mask: 0.0762
# ...
# 08/15 12:35:10 - mmengine - INFO - Epoch(train) [48][140/286]  lr: 2.5000e-05  eta: 0:25:18  time: 0.7937  data_time: 0.0127  memory: 5577  loss: 0.6105  loss_rpn_cls: 0.0029  loss_rpn_bbox: 0.0105  s0.loss_cls: 0.0527  s0.acc: 99.0234  s0.loss_bbox: 0.0404  s0.loss_mask: 0.1978  s1.loss_cls: 0.0196  s1.acc: 99.2188  s1.loss_bbox: 0.0684  s1.loss_mask: 0.0987  s2.loss_cls: 0.0137  s2.acc: 99.8031  s2.loss_bbox: 0.0572  s2.loss_mask: 0.0486
# 08/15 12:35:18 - mmengine - INFO - Epoch(train) [48][150/286]  lr: 2.5000e-05  eta: 0:25:14  time: 0.7973  data_time: 0.0131  memory: 5578  loss: 0.6143  loss_rpn_cls: 0.0030  loss_rpn_bbox: 0.0114  s0.loss_cls: 0.0533  s0.acc: 99.6094  s0.loss_bbox: 0.0429  s0.loss_mask: 0.1952  s1.loss_cls: 0.0203  s1.acc: 100.0000  s1.loss_bbox: 0.0708  s1.loss_mask: 0.0974  s2.loss_cls: 0.0145  s2.acc: 100.0000  s2.loss_bbox: 0.0578  s2.loss_mask: 0.0478
# 08/15 12:35:26 - mmengine - INFO - Epoch(train) [48][160/286]  lr: 2.5000e-05  eta: 0:25:11  time: 0.8010  data_time: 0.0141  memory: 5579  loss: 0.6256  loss_rpn_cls: 0.0033  loss_rpn_bbox: 0.0125  s0.loss_cls: 0.0533  s0.acc: 99.2188  s0.loss_bbox: 0.0443  s0.loss_mask: 0.1991  s1.loss_cls: 0.0210  s1.acc: 99.8047  s1.loss_bbox: 0.0721  s1.loss_mask: 0.0991  s2.loss_cls: 0.0149  s2.acc: 99.8047  s2.loss_bbox: 0.0576  s2.loss_mask: 0.0483
# 08/15 12:35:36 - mmengine - INFO - Epoch(train) [48][170/286]  lr: 2.5000e-05  eta: 0:25:08  time: 0.8275  data_time: 0.0129  memory: 5578  loss: 0.6120  loss_rpn_cls: 0.0043  loss_rpn_bbox: 0.0121  s0.loss_cls: 0.0499  s0.acc: 96.4844  s0.loss_bbox: 0.0427  s0.loss_mask: 0.1967  s1.loss_cls: 0.0184  s1.acc: 99.1150  s1.loss_bbox: 0.0711  s1.loss_mask: 0.0983  s2.loss_cls: 0.0136  s2.acc: 95.9276  s2.loss_bbox: 0.0573  s2.loss_mask: 0.0476
# 08/15 12:35:43 - mmengine - INFO - Epoch(train) [48][180/286]  lr: 2.5000e-05  eta: 0:25:05  time: 0.8270  data_time: 0.0121  memory: 5576  loss: 0.5819  loss_rpn_cls: 0.0037  loss_rpn_bbox: 0.0104  s0.loss_cls: 0.0450  s0.acc: 99.0234  s0.loss_bbox: 0.0370  s0.loss_mask: 0.1951  s1.loss_cls: 0.0153  s1.acc: 98.4127  s1.loss_bbox: 0.0635  s1.loss_mask: 0.0977  s2.loss_cls: 0.0112  s2.acc: 98.7578  s2.loss_bbox: 0.0555  s2.loss_mask: 0.0475
# 08/15 12:35:51 - mmengine - INFO - Epoch(train) [48][190/286]  lr: 2.5000e-05  eta: 0:25:02  time: 0.8254  data_time: 0.0131  memory: 5576  loss: 0.6051  loss_rpn_cls: 0.0037  loss_rpn_bbox: 0.0111  s0.loss_cls: 0.0482  s0.acc: 99.0234  s0.loss_bbox: 0.0397  s0.loss_mask: 0.2000  s1.loss_cls: 0.0168  s1.acc: 99.0234  s1.loss_bbox: 0.0671  s1.loss_mask: 0.0998  s2.loss_cls: 0.0122  s2.acc: 99.8024  s2.loss_bbox: 0.0581  s2.loss_mask: 0.0483
# 08/15 12:36:01 - mmengine - INFO - Epoch(train) [48][200/286]  lr: 2.5000e-05  eta: 0:24:59  time: 0.8505  data_time: 0.0124  memory: 5574  loss: 0.5970  loss_rpn_cls: 0.0034  loss_rpn_bbox: 0.0106  s0.loss_cls: 0.0472  s0.acc: 98.2422  s0.loss_bbox: 0.0384  s0.loss_mask: 0.1983  s1.loss_cls: 0.0154  s1.acc: 99.1507  s1.loss_bbox: 0.0665  s1.loss_mask: 0.0988  s2.loss_cls: 0.0116  s2.acc: 98.2340  s2.loss_bbox: 0.0585  s2.loss_mask: 0.0482
# 08/15 12:36:09 - mmengine - INFO - Epoch(train) [48][210/286]  lr: 2.5000e-05  eta: 0:24:55  time: 0.8491  data_time: 0.0114  memory: 5577  loss: 0.5828  loss_rpn_cls: 0.0033  loss_rpn_bbox: 0.0092  s0.loss_cls: 0.0463  s0.acc: 96.8750  s0.loss_bbox: 0.0361  s0.loss_mask: 0.1944  s1.loss_cls: 0.0144  s1.acc: 98.8636  s1.loss_bbox: 0.0640  s1.loss_mask: 0.0976  s2.loss_cls: 0.0108  s2.acc: 98.5915  s2.loss_bbox: 0.0587  s2.loss_mask: 0.0479
# 08/15 12:36:17 - mmengine - INFO - Epoch(train) [48][220/286]  lr: 2.5000e-05  eta: 0:24:52  time: 0.8265  data_time: 0.0114  memory: 5576  loss: 0.5848  loss_rpn_cls: 0.0020  loss_rpn_bbox: 0.0099  s0.loss_cls: 0.0474  s0.acc: 95.7031  s0.loss_bbox: 0.0385  s0.loss_mask: 0.1917  s1.loss_cls: 0.0170  s1.acc: 98.9316  s1.loss_bbox: 0.0653  s1.loss_mask: 0.0955  s2.loss_cls: 0.0121  s2.acc: 95.8606  s2.loss_bbox: 0.0583  s2.loss_mask: 0.0471
# 08/15 12:36:24 - mmengine - INFO - Epoch(train) [48][230/286]  lr: 2.5000e-05  eta: 0:24:49  time: 0.8197  data_time: 0.0108  memory: 5575  loss: 0.5722  loss_rpn_cls: 0.0018  loss_rpn_bbox: 0.0093  s0.loss_cls: 0.0447  s0.acc: 95.7031  s0.loss_bbox: 0.0383  s0.loss_mask: 0.1860  s1.loss_cls: 0.0174  s1.acc: 96.2500  s1.loss_bbox: 0.0653  s1.loss_mask: 0.0932  s2.loss_cls: 0.0120  s2.acc: 97.2163  s2.loss_bbox: 0.0582  s2.loss_mask: 0.0459
# 08/15 12:36:33 - mmengine - INFO - Epoch(train) [48][240/286]  lr: 2.5000e-05  eta: 0:24:45  time: 0.8382  data_time: 0.0106  memory: 5578  loss: 0.5523  loss_rpn_cls: 0.0024  loss_rpn_bbox: 0.0096  s0.loss_cls: 0.0416  s0.acc: 99.4141  s0.loss_bbox: 0.0359  s0.loss_mask: 0.1830  s1.loss_cls: 0.0165  s1.acc: 99.1379  s1.loss_bbox: 0.0610  s1.loss_mask: 0.0915  s2.loss_cls: 0.0111  s2.acc: 99.7783  s2.loss_bbox: 0.0546  s2.loss_mask: 0.0451
# 08/15 12:36:41 - mmengine - INFO - Epoch(train) [48][250/286]  lr: 2.5000e-05  eta: 0:24:42  time: 0.8118  data_time: 0.0103  memory: 5579  loss: 0.5406  loss_rpn_cls: 0.0023  loss_rpn_bbox: 0.0087  s0.loss_cls: 0.0405  s0.acc: 99.4141  s0.loss_bbox: 0.0343  s0.loss_mask: 0.1819  s1.loss_cls: 0.0166  s1.acc: 100.0000  s1.loss_bbox: 0.0576  s1.loss_mask: 0.0910  s2.loss_cls: 0.0109  s2.acc: 100.0000  s2.loss_bbox: 0.0520  s2.loss_mask: 0.0449
# 08/15 12:36:49 - mmengine - INFO - Epoch(train) [48][260/286]  lr: 2.5000e-05  eta: 0:24:39  time: 0.8107  data_time: 0.0102  memory: 5575  loss: 0.5497  loss_rpn_cls: 0.0024  loss_rpn_bbox: 0.0093  s0.loss_cls: 0.0418  s0.acc: 94.9219  s0.loss_bbox: 0.0374  s0.loss_mask: 0.1802  s1.loss_cls: 0.0189  s1.acc: 95.2381  s1.loss_bbox: 0.0619  s1.loss_mask: 0.0896  s2.loss_cls: 0.0127  s2.acc: 91.6016  s2.loss_bbox: 0.0517  s2.loss_mask: 0.0437
# 08/15 12:36:57 - mmengine - INFO - Epoch(train) [48][270/286]  lr: 2.5000e-05  eta: 0:24:35  time: 0.8065  data_time: 0.0106  memory: 5578  loss: 0.5571  loss_rpn_cls: 0.0028  loss_rpn_bbox: 0.0085  s0.loss_cls: 0.0412  s0.acc: 97.6562  s0.loss_bbox: 0.0357  s0.loss_mask: 0.1859  s1.loss_cls: 0.0181  s1.acc: 99.3562  s1.loss_bbox: 0.0618  s1.loss_mask: 0.0933  s2.loss_cls: 0.0121  s2.acc: 99.5585  s2.loss_bbox: 0.0523  s2.loss_mask: 0.0454
# 08/15 12:37:05 - mmengine - INFO - Epoch(train) [48][280/286]  lr: 2.5000e-05  eta: 0:24:32  time: 0.8135  data_time: 0.0121  memory: 5576  loss: 0.5818  loss_rpn_cls: 0.0037  loss_rpn_bbox: 0.0092  s0.loss_cls: 0.0454  s0.acc: 99.6094  s0.loss_bbox: 0.0386  s0.loss_mask: 0.1921  s1.loss_cls: 0.0200  s1.acc: 100.0000  s1.loss_bbox: 0.0647  s1.loss_mask: 0.0955  s2.loss_cls: 0.0137  s2.acc: 100.0000  s2.loss_bbox: 0.0525  s2.loss_mask: 0.0462
# 08/15 12:37:10 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco-new-data-batch1_20240815_105128
# 08/15 12:37:10 - mmengine - INFO - Saving checkpoint at 48 epochs
# 08/15 12:37:18 - mmengine - INFO - Epoch(val) [48][10/68]    eta: 0:00:30  time: 0.6039  data_time: 0.0356  memory: 5561
# 08/15 12:37:22 - mmengine - INFO - Epoch(val) [48][20/68]    eta: 0:00:22  time: 0.6366  data_time: 0.0341  memory: 3026
# 08/15 12:37:26 - mmengine - INFO - Epoch(val) [48][30/68]    eta: 0:00:17  time: 0.6757  data_time: 0.0382  memory: 3896
# 08/15 12:37:32 - mmengine - INFO - Epoch(val) [48][40/68]    eta: 0:00:13  time: 0.4412  data_time: 0.0359  memory: 3152
# 08/15 12:37:36 - mmengine - INFO - Epoch(val) [48][50/68]    eta: 0:00:08  time: 0.4750  data_time: 0.0361  memory: 4231
# 08/15 12:37:41 - mmengine - INFO - Epoch(val) [48][60/68]    eta: 0:00:03  time: 0.4725  data_time: 0.0251  memory: 4365
# 08/15 12:37:45 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.25s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.570
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.253
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.201
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.408
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.208
# 08/15 12:37:45 - mmengine - INFO - bbox_mAP_copypaste: 0.275 0.570 0.253 0.112 0.357 0.201
# 08/15 12:37:45 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.25s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.559
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.152
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.337
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.184
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.447
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.183
# 08/15 12:37:45 - mmengine - INFO - segm_mAP_copypaste: 0.242 0.559 0.152 0.087 0.337 0.184
# 08/15 12:37:45 - mmengine - INFO - Epoch(val) [48][68/68]    coco/bbox_mAP: 0.2750  coco/bbox_mAP_50: 0.5700  coco/bbox_mAP_75: 0.2530  coco/bbox_mAP_s: 0.1120  coco/bbox_mAP_m: 0.3570  coco/bbox_mAP_l: 0.2010  coco/segm_mAP: 0.2420  coco/segm_mAP_50: 0.5590  coco/segm_mAP_75: 0.1520  coco/segm_mAP_s: 0.0870  coco/segm_mAP_m: 0.3370  coco/segm_mAP_l: 0.1840  data_time: 0.0330  time: 0.4689
# 08/15 12:37:45 - mmengine - INFO - the monitored metric did not improve in the last 10 records. best score: 0.249.
# W&B sync reduced upload amount by 92.7%
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>▁▃▆▅▅███████████</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁▂▆▅▅███████████</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁▃▅▆▅███████████</td></tr><tr><td>coco/bbox_mAP_l</td><td>▁▅▃▅▄▆▆███████▇▇</td></tr><tr><td>coco/bbox_mAP_m</td><td>▁▄▆▆▆███████████</td></tr><tr><td>coco/bbox_mAP_s</td><td>▁▃▃▄▄▇▇████▇█▇▇█</td></tr><tr><td>coco/segm_mAP</td><td>▁▄▆▅▆██████████▇</td></tr><tr><td>coco/segm_mAP_50</td><td>▁▃▆▅▅██████▇████</td></tr><tr><td>coco/segm_mAP_75</td><td>▁▆▅▄▆█▇▇▇▇▇█▇▇▇▆</td></tr><tr><td>coco/segm_mAP_l</td><td>▄▆▁▇▄▅▆██████▇▇▇</td></tr><tr><td>coco/segm_mAP_m</td><td>▁▄▆▅▇█▇▇▇███▇▇▇▇</td></tr><tr><td>coco/segm_mAP_s</td><td>▁▃▃▄▅▇▇▇████████</td></tr><tr><td>data_time</td><td>▂▁▂▂▃▁▂▃▂▂▂▂▁▁▁▂▂▁▂▁▂▃▃▂▃▂▃▂▃▂▂▂▂▃▂▂▃▃▃█</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>iter</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▇▇▆▅▅▅▅▅▄▄▃▃▂▂▂▂▁▂▂▁▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▂▂▁</td></tr><tr><td>loss_rpn_bbox</td><td>▆▇█▇▅▅▅▃▄▄▃▄▃▃▂▂▂▂▁▃▂▁▂▂▁▃▂▂▂▂▂▂▁▂▂▂▂▂▃▁</td></tr><tr><td>loss_rpn_cls</td><td>▇▇█▅▅▅▄▄▅▃▃▃▃▃▂▂▂▂▁▃▂▁▂▃▂▂▂▂▂▁▁▂▁▁▂▁▂▂▂▂</td></tr><tr><td>lr</td><td>▃█████████████▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>memory</td><td>▃▇█▁▇██▇█▇██████▇████▇█████████████▇████</td></tr><tr><td>s0.acc</td><td>▄▃▁▇▄▁▃▄▇▃▅▄▇▇▅▇█▆▆▇██▇▇▇▆▆▇▇█▅▇██▇▇▇█▆█</td></tr><tr><td>s0.loss_bbox</td><td>▇██▇▇▆▆▅▅▅▅▄▃▄▂▂▂▂▁▃▂▁▂▂▂▃▂▂▂▂▂▂▁▂▂▁▁▂▂▁</td></tr><tr><td>s0.loss_cls</td><td>█▇▇▆▆▅▄▃▃▃▃▃▂▂▂▂▁▁▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁</td></tr><tr><td>s0.loss_mask</td><td>█▇▆▅▅▅▄▄▄▄▄▄▃▃▂▃▂▂▂▂▂▂▂▂▂▃▂▂▂▂▂▂▁▂▂▂▂▂▂▂</td></tr><tr><td>s1.acc</td><td>▃▁▁▆▃▂▂▃▇▃▆▄█▇▆▇█▆▆▇████▇▆▅███▇█▇█▇█▇▇▇█</td></tr><tr><td>s1.loss_bbox</td><td>▇▇█▇▇▆▆▅▆▆▅▄▄▄▃▃▂▂▁▃▂▁▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▂▃▁</td></tr><tr><td>s1.loss_cls</td><td>█▇▇▆▅▄▄▃▃▃▃▃▂▂▂▂▁▁▁▂▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁</td></tr><tr><td>s1.loss_mask</td><td>█▇▆▅▅▅▄▄▄▄▄▄▃▃▃▂▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁</td></tr><tr><td>s2.acc</td><td>▅▂▄▆▃▄▁▄▇▅▅▃█▇▆██▆▇▇█████▆▆▇██▇█▇█▆▇▇█▅█</td></tr><tr><td>s2.loss_bbox</td><td>▅▆████▇▇██▆▆▅▇▄▄▂▃▂▄▃▂▄▂▂▄▄▃▃▃▂▂▁▂▃▃▂▃▃▁</td></tr><tr><td>s2.loss_cls</td><td>█▇▇▆▆▅▅▄▄▄▄▃▃▃▂▂▁▂▁▂▁▁▂▁▁▂▂▂▂▁▁▂▁▁▂▁▁▂▂▁</td></tr><tr><td>s2.loss_mask</td><td>█▆▆▅▅▅▄▄▄▄▄▄▃▃▂▂▂▂▂▂▂▁▂▂▁▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁</td></tr><tr><td>time</td><td>▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▁▂▂▁▂▂▂▁▂▃▃█▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>0.275</td></tr><tr><td>coco/bbox_mAP_50</td><td>0.57</td></tr><tr><td>coco/bbox_mAP_75</td><td>0.253</td></tr><tr><td>coco/bbox_mAP_l</td><td>0.201</td></tr><tr><td>coco/bbox_mAP_m</td><td>0.357</td></tr><tr><td>coco/bbox_mAP_s</td><td>0.112</td></tr><tr><td>coco/segm_mAP</td><td>0.242</td></tr><tr><td>coco/segm_mAP_50</td><td>0.559</td></tr><tr><td>coco/segm_mAP_75</td><td>0.152</td></tr><tr><td>coco/segm_mAP_l</td><td>0.184</td></tr><tr><td>coco/segm_mAP_m</td><td>0.337</td></tr><tr><td>coco/segm_mAP_s</td><td>0.087</td></tr><tr><td>data_time</td><td>0.03303</td></tr><tr><td>epoch</td><td>48</td></tr><tr><td>iter</td><td>13722</td></tr><tr><td>loss</td><td>0.58183</td></tr><tr><td>loss_rpn_bbox</td><td>0.00918</td></tr><tr><td>loss_rpn_cls</td><td>0.00374</td></tr><tr><td>lr</td><td>2e-05</td></tr><tr><td>memory</td><td>5576</td></tr><tr><td>s0.acc</td><td>99.60938</td></tr><tr><td>s0.loss_bbox</td><td>0.03865</td></tr><tr><td>s0.loss_cls</td><td>0.04544</td></tr><tr><td>s0.loss_mask</td><td>0.19211</td></tr><tr><td>s1.acc</td><td>100.0</td></tr><tr><td>s1.loss_bbox</td><td>0.06475</td></tr><tr><td>s1.loss_cls</td><td>0.02004</td></tr><tr><td>s1.loss_mask</td><td>0.09552</td></tr><tr><td>s2.acc</td><td>100.0</td></tr><tr><td>s2.loss_bbox</td><td>0.05252</td></tr><tr><td>s2.loss_cls</td><td>0.01367</td></tr><tr><td>s2.loss_mask</td><td>0.04621</td></tr><tr><td>time</td><td>0.46886</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pleasant-snowflake-100</strong> at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/rrysdpw1' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/rrysdpw1</a><br/> View project at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a><br/>Synced 6 W&B file(s), 0 media file(s), 2230 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\tutorial_exps\150-new-data-batch1\20240815_105128\vis_data\wandb\run-20240815_105134-rrysdpw1\logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
config = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco-new-data-batch1.py'

# %%
from glob import glob
ckpt = 'tutorial_exps/60-new-data-batch1/best_coco_segm_mAP_epoch_18.pth'

# %%
ckpt_b  = 'tutorial_exps/60-new-data-batch1/best_coco_bbox_mAP_epoch_45.pth'

# %% [markdown]
# ## Inference on trained Model

# %%
import os
from mmdet.apis import init_detector, inference_detector
import mmcv
import cv2
from mmdet.registry import VISUALIZERS

model = init_detector(config, ckpt, device='cuda:0')

image_folder = 'mmdetection/data/saf24/test/'
output_folder = 'tutorial_exps/60-new-data-batch1/inference-results/segm'
image_paths = [os.path.join(image_folder, img_name) for img_name in os.listdir(image_folder) if img_name.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'tiff'))]

visualizer = VISUALIZERS.build(model.cfg.visualizer)
visualizer.dataset_meta = model.dataset_meta
# Out:
# Loads checkpoint by local backend from path: tutorial_exps/150-new-data-batch1/best_coco_segm_mAP_epoch_18.pth
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\utils\manager.py:113: UserWarning: <class 'mmdet.visualization.local_visualizer.DetLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(

# %%
for img_path in image_paths:
    img = mmcv.imread(img_path)
    if img is None:
        print(f"Failed to read image at {img_path}")
        continue
    
    new_result_segm = inference_detector(model, img)
    os.makedirs(output_folder, exist_ok=True)
    output_file = os.path.join(output_folder, os.path.basename(img_path))
    
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    visualizer.add_datasample(
        'new_result_segm',
        img_rgb,
        data_sample=new_result_segm,        
        draw_gt=None,
        wait_time=0,
        out_file=output_file
    )
# Out:
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(

# %% [markdown]
# ## Save results.pkl

# %%
# !python mmdetection/tools/test.py {config} {ckpt}  --out ./results/150-new-data-batch1/results.pkl
# Out:
# 08/15 12:51:56 - mmengine -
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# INFO
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
#  -
# wandb:  $ pip install wandb --upgrade
# ------------------------------------------------------------
# System environment:
# wandb: Tracking run with wandb version 0.17.5
#     sys.platform: win32
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\150-new-data-batch1\20240815_125149\vis_data\wandb\run-20240815_125200-s121bl5h
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb: Run `wandb offline` to turn off syncing.
#     CUDA available: True
# wandb: Syncing run lilac-violet-101
#     MUSA available: False
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     numpy_random_seed: 502276769
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/s121bl5h
#     GPU 0: NVIDIA RTX A4000
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#   mask_preds = bboxes.new_tensor(mask_preds)
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
# wandb: - 10.629 MB of 10.629 MB uploaded (10.339 MB deduped)
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# wandb: \ 10.629 MB of 10.629 MB uploaded (10.339 MB deduped)
#     GCC: n/a
#     PyTorch: 2.3.1
# wandb: | 10.713 MB of 10.750 MB uploaded (10.344 MB deduped)
#     PyTorch compiling details: PyTorch built with:
# wandb: / 10.737 MB of 10.750 MB uploaded (10.344 MB deduped)
#   - C++ Version: 201703
# wandb: - 10.737 MB of 10.750 MB uploaded (10.344 MB deduped)
#   - MSVC 192930154
# wandb: \ 10.750 MB of 10.750 MB uploaded (10.344 MB deduped)
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# wandb:
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
# wandb: W&B sync reduced upload amount by 96.2%
#   - OpenMP 2019
# wandb:  View run lilac-violet-101 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/s121bl5h
#   - LAPACK is enabled (usually provided by MKL)
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
# wandb: Synced 6 W&B file(s), 0 media file(s), 2235 artifact file(s) and 0 other file(s)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
# wandb: Find logs at: .\tutorial_exps\150-new-data-batch1\20240815_125149\vis_data\wandb\run-20240815_125200-s121bl5h\logs
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 502276769
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/15 12:51:57 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf24/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.005,
#         monitor='coco/segm_mAP',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'tutorial_exps/150-new-data-batch1/best_coco_segm_mAP_epoch_18.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TransitionalMixing',
#         'DiffusiveMixing',
#         'Blurry',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf24/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf24/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=60, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf24/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf24/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf24/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TransitionalMixing',
#                         'DiffusiveMixing',
#                         'Blurry',
#                     ),
#                     dataset='SAF22',
#                     epochs=60,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/150-new-data-batch1'
#
# 08/15 12:52:23 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/15 12:52:23 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 08/15 12:52:24 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: tutorial_exps/150-new-data-batch1/best_coco_segm_mAP_epoch_18.pth
# 08/15 12:52:26 - mmengine - INFO - Load checkpoint from tutorial_exps/150-new-data-batch1/best_coco_segm_mAP_epoch_18.pth
# 08/15 12:52:57 - mmengine - INFO - Epoch(test) [10/68]    eta: 0:03:03  time: 3.1702  data_time: 1.1602  memory: 2546
# 08/15 12:53:09 - mmengine - INFO - Epoch(test) [20/68]    eta: 0:01:44  time: 2.1744  data_time: 0.5892  memory: 2513
# 08/15 12:53:36 - mmengine - INFO - Epoch(test) [30/68]    eta: 0:01:29  time: 2.3550  data_time: 0.4056  memory: 3685
# 08/15 12:53:50 - mmengine - INFO - Epoch(test) [40/68]    eta: 0:00:59  time: 2.1118  data_time: 0.3103  memory: 2405
# 08/15 12:54:08 - mmengine - INFO - Epoch(test) [50/68]    eta: 0:00:36  time: 2.0426  data_time: 0.2544  memory: 2405
# 08/15 12:54:57 - mmengine - INFO - Epoch(test) [60/68]    eta: 0:00:20  time: 2.3962  data_time: 0.0272  memory: 3182
# 08/15 12:55:08 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.29s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.257
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.192
# 08/15 12:55:09 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | Blurry               | 0.178 | 0.449  | 0.091  | 0.088 | 0.226 | 0.3   |
# | ClassicalEvaporation | 0.322 | 0.661  | 0.291  | 0.211 | 0.477 | 0.0   |
# | DiffusiveMixing      | 0.382 | 0.723  | 0.434  | 0.0   | 0.419 | 0.265 |
# | TransitionalMixing   | 0.217 | 0.449  | 0.211  | 0.147 | 0.307 | nan   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/15 12:55:09 - mmengine - INFO - bbox_mAP_copypaste: 0.275 0.571 0.257 0.111 0.357 0.188
# 08/15 12:55:09 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.26s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.249
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.564
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.167
# 08/15 12:55:09 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | Blurry               | 0.172 | 0.442  | 0.087  | 0.054 | 0.232 | 0.3   |
# | ClassicalEvaporation | 0.309 | 0.647  | 0.274  | 0.187 | 0.468 | 0.0   |
# | DiffusiveMixing      | 0.316 | 0.726  | 0.152  | 0.0   | 0.355 | 0.203 |
# | TransitionalMixing   | 0.198 | 0.441  | 0.17   | 0.087 | 0.345 | nan   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/15 12:55:09 - mmengine - INFO - segm_mAP_copypaste: 0.249 0.564 0.171 0.082 0.350 0.168
# 08/15 12:55:09 - mmengine - INFO - Results has been saved to ./results/150-new-data-batch1/results.pkl.
# 08/15 12:55:09 - mmengine - INFO - Epoch(test) [68/68]    coco/Blurry_precision: 0.1720  coco/ClassicalEvaporation_precision: 0.3090  coco/DiffusiveMixing_precision: 0.3160  coco/TransitionalMixing_precision: 0.1980  coco/bbox_mAP: 0.2750  coco/bbox_mAP_50: 0.5710  coco/bbox_mAP_75: 0.2570  coco/bbox_mAP_s: 0.1110  coco/bbox_mAP_m: 0.3570  coco/bbox_mAP_l: 0.1880  coco/segm_mAP: 0.2490  coco/segm_mAP_50: 0.5640  coco/segm_mAP_75: 0.1710  coco/segm_mAP_s: 0.0820  coco/segm_mAP_m: 0.3500  coco/segm_mAP_l: 0.1680  data_time: 0.1945  time: 2.3927

# %% [markdown]
# The masks are represented as a tensor of boolean values, these boolean tensors represent the masks directly, rather than as coordinates.

# %% [markdown]
# ## Log Analysis

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.1
# Summary: Python plotting package
# Home-page:
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
#         =========================================================
#
#         1. This LICENSE AGREEMENT is between the Matplotlib Development Team
#         ("MDT"), and the Individual or Organization ("Licensee") accessing and
#         otherwise using matplotlib software in source or binary form and its
#         associated documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, MDT
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that MDT's
#         License Agreement and MDT's notice of copyright, i.e., "Copyright (c)
#         2012- Matplotlib Development Team; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib .
#
#         4. MDT is making matplotlib available to Licensee on an "AS
#         IS" basis.  MDT MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, MDT MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. MDT SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between MDT and
#         Licensee.  This License Agreement does not grant permission to use MDT
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib ,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
#
#         License agreement for matplotlib versions prior to 1.3.0
#         ========================================================
#
#         1. This LICENSE AGREEMENT is between John D. Hunter ("JDH"), and the
#         Individual or Organization ("Licensee") accessing and otherwise using
#         matplotlib software in source or binary form and its associated
#         documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, JDH
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that JDH's
#         License Agreement and JDH's notice of copyright, i.e., "Copyright (c)
#         2002-2011 John D. Hunter; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib  or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib.
#
#         4. JDH is making matplotlib  available to Licensee on an "AS
#         IS" basis.  JDH MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, JDH MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. JDH SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between JDH and
#         Licensee.  This License Agreement does not grant permission to use JDH
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
# Location: c:\users\ja683\appdata\roaming\python\python310\site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: mmdet, mmengine, pycocotools, seaborn

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib
print(matplotlib.rcParams['backend'])
# Out:
# module://matplotlib_inline.backend_inline

# %%
json_log = 'tutorial_exps/60-new-data-batch1/20240815_105128/vis_data/20240815_105128.json'

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py plot_curve \
  --keys loss \
  --title "Training Metrics" \
  --legend "Loss" \
  --backend TkAgg \
  --style darkgrid \
  --out tutorial_exps/60-new-data-batch1/20240815_105128/training_curves.png \
  {json_log}
# Out:
# plot curve of tutorial_exps/150-new-data-batch1/20240815_105128/vis_data/20240815_105128.json, metric is loss
# save curve to: tutorial_exps/150-new-data-batch1/20240815_105128/training_curves.png

# %% [markdown]
# ### Compute the average training speed.

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py cal_train_time {json_log} --include-outliers
# Out:
# -----Analyze train time of tutorial_exps/150-new-data-batch1/20240815_105128/vis_data/20240815_105128.json-----
# slowest epoch 48, average time is 0.8229 s/iter
# fastest epoch 2, average time is 0.3794 s/iter
# time std over epochs is 0.0824
# average iter time: 0.4301 s/iter

# %% [markdown]
# ## Result Analysis

# %%
# !python mmdetection/tools/analysis_tools/analyze_results.py \
       {config} \
       ./results/60-new-data-batch1/results.pkl \
       ./results/60-new-data-batch1/vis_data \
       --show
# [Optional] Finish the wandb run
wandb.finish()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# loading annotations into memory...
# Done (t=0.00s)
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# creating index...
# wandb: Tracking run with wandb version 0.17.5
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\results\150-new-data-batch1\vis_data\20240815_131016\vis_data\wandb\run-20240815_131025-ti7nu1zf
# index created!
# wandb: Run `wandb offline` to turn off syncing.
# 08/15 13:10:22 - mmengine -
# wandb: Syncing run glowing-haze-102
# INFO
#  -
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
# ------------------------------------------------------------
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ti7nu1zf
# System environment:
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#     sys.platform: win32
#   warnings.warn(
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#     CUDA available: True
#   warnings.warn(
#     MUSA available: False
#     numpy_random_seed: 2066316551
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
#     GCC: n/a
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 2066316551
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/15 13:10:22 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf24/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     early_stopping=dict(
#         min_delta=0.005,
#         monitor='coco/segm_mAP',
#         patience=10,
#         type='EarlyStoppingHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TransitionalMixing',
#         'DiffusiveMixing',
#         'Blurry',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf24/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf24/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=60, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf24/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf24/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TransitionalMixing',
#                 'DiffusiveMixing',
#                 'Blurry',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf24/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TransitionalMixing',
#                         'DiffusiveMixing',
#                         'Blurry',
#                     ),
#                     dataset='SAF22',
#                     epochs=60,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './results/150-new-data-batch1/vis_data'
#
# 08/15 13:10:43 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/15 13:10:43 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
# (LOWEST      ) EarlyStoppingHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# [                                                  ] 0/68, elapsed: 0s, ETA:
# [                                 ] 1/68, 0.1 task/s, elapsed: 16s, ETA:  1072s
# [                                 ] 2/68, 0.1 task/s, elapsed: 34s, ETA:  1138s
# [>                                ] 3/68, 0.1 task/s, elapsed: 59s, ETA:  1269s
# [>                                ] 4/68, 0.1 task/s, elapsed: 68s, ETA:  1094s
# [>>                               ] 5/68, 0.1 task/s, elapsed: 76s, ETA:   960s
# [>>                               ] 6/68, 0.1 task/s, elapsed: 83s, ETA:   859s
# [>>>                              ] 7/68, 0.1 task/s, elapsed: 91s, ETA:   789s
# [>>>                             ] 8/68, 0.1 task/s, elapsed: 101s, ETA:   755s
# [>>>>                            ] 9/68, 0.1 task/s, elapsed: 108s, ETA:   707s
# [>>>>                           ] 10/68, 0.1 task/s, elapsed: 115s, ETA:   668s
# [>>>>>                          ] 11/68, 0.1 task/s, elapsed: 122s, ETA:   633s
# [>>>>>                          ] 12/68, 0.1 task/s, elapsed: 129s, ETA:   604s
# [>>>>>                          ] 13/68, 0.1 task/s, elapsed: 136s, ETA:   576s
# [>>>>>>                         ] 14/68, 0.1 task/s, elapsed: 143s, ETA:   552s
# [>>>>>>                         ] 15/68, 0.1 task/s, elapsed: 151s, ETA:   534s
# [>>>>>>>                        ] 16/68, 0.1 task/s, elapsed: 159s, ETA:   517s
# [>>>>>>>                        ] 17/68, 0.1 task/s, elapsed: 168s, ETA:   503s
# [>>>>>>>>                       ] 18/68, 0.1 task/s, elapsed: 175s, ETA:   487s
# [>>>>>>>>                       ] 19/68, 0.1 task/s, elapsed: 182s, ETA:   471s
# [>>>>>>>>>                      ] 20/68, 0.1 task/s, elapsed: 189s, ETA:   455s
# [>>>>>>>>>                      ] 21/68, 0.1 task/s, elapsed: 197s, ETA:   440s
# [>>>>>>>>>>                     ] 22/68, 0.1 task/s, elapsed: 204s, ETA:   427s
# [>>>>>>>>>>                     ] 23/68, 0.1 task/s, elapsed: 214s, ETA:   419s
# [>>>>>>>>>>                     ] 24/68, 0.1 task/s, elapsed: 221s, ETA:   405s
# [>>>>>>>>>>>                    ] 25/68, 0.1 task/s, elapsed: 229s, ETA:   394s
# [>>>>>>>>>>>                    ] 26/68, 0.1 task/s, elapsed: 241s, ETA:   389s
# [>>>>>>>>>>>>                   ] 27/68, 0.1 task/s, elapsed: 248s, ETA:   377s
# [>>>>>>>>>>>>                   ] 28/68, 0.1 task/s, elapsed: 257s, ETA:   367s
# [>>>>>>>>>>>>>                  ] 29/68, 0.1 task/s, elapsed: 264s, ETA:   356s
# [>>>>>>>>>>>>>                  ] 30/68, 0.1 task/s, elapsed: 271s, ETA:   344s
# [>>>>>>>>>>>>>>                 ] 31/68, 0.1 task/s, elapsed: 279s, ETA:   333s
# [>>>>>>>>>>>>>>                 ] 32/68, 0.1 task/s, elapsed: 286s, ETA:   322s
# [>>>>>>>>>>>>>>>                ] 33/68, 0.1 task/s, elapsed: 295s, ETA:   312s
# [>>>>>>>>>>>>>>>                ] 34/68, 0.1 task/s, elapsed: 303s, ETA:   303s
# [>>>>>>>>>>>>>>>                ] 35/68, 0.1 task/s, elapsed: 310s, ETA:   292s
# [>>>>>>>>>>>>>>>>               ] 36/68, 0.1 task/s, elapsed: 320s, ETA:   284s
# [>>>>>>>>>>>>>>>>               ] 37/68, 0.1 task/s, elapsed: 327s, ETA:   274s
# [>>>>>>>>>>>>>>>>>              ] 38/68, 0.1 task/s, elapsed: 335s, ETA:   264s
# [>>>>>>>>>>>>>>>>>              ] 39/68, 0.1 task/s, elapsed: 341s, ETA:   254s
# [>>>>>>>>>>>>>>>>>>             ] 40/68, 0.1 task/s, elapsed: 348s, ETA:   244s
# [>>>>>>>>>>>>>>>>>>             ] 41/68, 0.1 task/s, elapsed: 355s, ETA:   234s
# [>>>>>>>>>>>>>>>>>>>            ] 42/68, 0.1 task/s, elapsed: 362s, ETA:   224s
# [>>>>>>>>>>>>>>>>>>>            ] 43/68, 0.1 task/s, elapsed: 370s, ETA:   215s
# [>>>>>>>>>>>>>>>>>>>>           ] 44/68, 0.1 task/s, elapsed: 376s, ETA:   205s
# [>>>>>>>>>>>>>>>>>>>>           ] 45/68, 0.1 task/s, elapsed: 385s, ETA:   197s
# [>>>>>>>>>>>>>>>>>>>>           ] 46/68, 0.1 task/s, elapsed: 392s, ETA:   188s
# [>>>>>>>>>>>>>>>>>>>>>          ] 47/68, 0.1 task/s, elapsed: 399s, ETA:   178s
# [>>>>>>>>>>>>>>>>>>>>>          ] 48/68, 0.1 task/s, elapsed: 407s, ETA:   170s
# [>>>>>>>>>>>>>>>>>>>>>>         ] 49/68, 0.1 task/s, elapsed: 417s, ETA:   162s
# [>>>>>>>>>>>>>>>>>>>>>>         ] 50/68, 0.1 task/s, elapsed: 427s, ETA:   154s
# [>>>>>>>>>>>>>>>>>>>>>>>        ] 51/68, 0.1 task/s, elapsed: 433s, ETA:   144s
# [>>>>>>>>>>>>>>>>>>>>>>>        ] 52/68, 0.1 task/s, elapsed: 441s, ETA:   136s
# [>>>>>>>>>>>>>>>>>>>>>>>>       ] 53/68, 0.1 task/s, elapsed: 449s, ETA:   127s
# [>>>>>>>>>>>>>>>>>>>>>>>>       ] 54/68, 0.1 task/s, elapsed: 458s, ETA:   119s
# [>>>>>>>>>>>>>>>>>>>>>>>>>      ] 55/68, 0.1 task/s, elapsed: 464s, ETA:   110s
# [>>>>>>>>>>>>>>>>>>>>>>>>>      ] 56/68, 0.1 task/s, elapsed: 472s, ETA:   101s
# [>>>>>>>>>>>>>>>>>>>>>>>>>      ] 57/68, 0.1 task/s, elapsed: 480s, ETA:    93s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>     ] 58/68, 0.1 task/s, elapsed: 487s, ETA:    84s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>     ] 59/68, 0.1 task/s, elapsed: 496s, ETA:    76s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 60/68, 0.1 task/s, elapsed: 503s, ETA:    67s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 61/68, 0.1 task/s, elapsed: 510s, ETA:    58s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 62/68, 0.1 task/s, elapsed: 519s, ETA:    50s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 63/68, 0.1 task/s, elapsed: 526s, ETA:    42s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 64/68, 0.1 task/s, elapsed: 533s, ETA:    33s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 65/68, 0.1 task/s, elapsed: 540s, ETA:    25s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> ] 66/68, 0.1 task/s, elapsed: 551s, ETA:    17s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>> ] 67/68, 0.1 task/s, elapsed: 558s, ETA:     8s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 68/68, 0.1 task/s, elapsed: 566s, ETA:     0sImage shape: (1300, 2072)
# Resized masks shape: (16, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (8, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (9, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (13, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (7, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (37, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (1, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (1, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (9, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (4, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (8, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (16, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (14, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (10, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (8, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (1, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (4, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (7, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (3, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (2, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (41, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (10, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (5, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (7, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (100, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (61, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (17, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (51, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (15, 1300, 2072)
# Image shape: (1300, 2072)
# Resized masks shape: (32, 1300, 2072)

# %% [markdown]
# ## Confusion Matrix

# %%
# !python mmdetection/tools/analysis_tools/confusion_matrix.py \
        {config} \
        results/60-new-data-batch1/results.pkl \
        results/60-new-data-batch1 --show
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [                                                  ] 0/68, elapsed: 0s, ETA:
# [                                ] 1/68, 999.1 task/s, elapsed: 0s, ETA:     0s
# [                               ] 2/68, 1998.2 task/s, elapsed: 0s, ETA:     0s
# [>                              ] 3/68, 1000.9 task/s, elapsed: 0s, ETA:     0s
# [>                               ] 4/68, 996.3 task/s, elapsed: 0s, ETA:     0s
# [>>                             ] 5/68, 1245.4 task/s, elapsed: 0s, ETA:     0s
# [>>                             ] 6/68, 1199.9 task/s, elapsed: 0s, ETA:     0s
# [>>>                            ] 7/68, 1399.8 task/s, elapsed: 0s, ETA:     0s
# [>>>                            ] 8/68, 1142.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>                           ] 9/68, 1285.1 task/s, elapsed: 0s, ETA:     0s
# [>>>>                          ] 10/68, 1250.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>                          ] 11/68, 1375.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>                         ] 12/68, 1500.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>                         ] 13/68, 1444.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>                        ] 14/68, 1555.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>                        ] 15/68, 1667.1 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>                       ] 16/68, 1567.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>                       ] 17/68, 1665.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>                       ] 18/68, 1607.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>                      ] 19/68, 1697.1 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>                      ] 20/68, 1786.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>                     ] 21/68, 1875.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>                     ] 22/68, 1804.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>                    ] 23/68, 1743.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>                    ] 24/68, 1819.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>                   ] 25/68, 1761.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>                   ] 26/68, 1710.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>                   ] 27/68, 1776.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>                  ] 28/68, 1729.2 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>                  ] 29/68, 1687.1 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>                 ] 30/68, 1745.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>                 ] 31/68, 1803.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>                ] 32/68, 1861.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>                ] 33/68, 1814.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>               ] 34/68, 1869.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>               ] 35/68, 1823.2 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>               ] 36/68, 1782.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>              ] 37/68, 1832.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>              ] 38/68, 1792.1 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>             ] 39/68, 1839.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>             ] 40/68, 1886.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>            ] 41/68, 1933.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>            ] 42/68, 1980.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>            ] 43/68, 1937.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>           ] 44/68, 1982.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>           ] 45/68, 1939.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>          ] 46/68, 1939.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>          ] 47/68, 1981.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>         ] 48/68, 1942.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>         ] 49/68, 1904.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>        ] 50/68, 1871.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>        ] 51/68, 1840.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>        ] 52/68, 1876.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>       ] 53/68, 1912.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>       ] 54/68, 1879.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>      ] 55/68, 1851.2 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>      ] 56/68, 1884.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>     ] 57/68, 1823.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>     ] 58/68, 1855.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 59/68, 1856.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 60/68, 1887.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 61/68, 1861.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 62/68, 1834.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>   ] 63/68, 1864.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 64/68, 1893.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>  ] 65/68, 1869.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>> ] 66/68, 1844.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>> ] 67/68, 1872.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 68/68, 1849.0 task/s, elapsed: 0s, ETA:     0sFigure(1500x956.25)

# %%
# !pip install scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: seaborn in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from scikit-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Eval Metric from results.pkl file

# %%
# !python mmdetection/tools/analysis_tools/eval_metric.py \
        {config} \
        results/60-new-data-batch1/results.pkl
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 08/15 13:26:19 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.30s).
# Accumulating evaluation results...
# DONE (t=0.06s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.275
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.571
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.257
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.111
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.357
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.188
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.410
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.204
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.192
# 08/15 13:26:19 - mmengine - INFO - bbox_mAP_copypaste: 0.275 0.571 0.257 0.111 0.357 0.188
# 08/15 13:26:19 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.30s).
# Accumulating evaluation results...
# DONE (t=0.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.249
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.564
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.082
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.350
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.462
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.167
# 08/15 13:26:19 - mmengine - INFO - segm_mAP_copypaste: 0.249 0.564 0.171 0.082 0.350 0.168
# {'coco/bbox_mAP': 0.275, 'coco/bbox_mAP_50': 0.571, 'coco/bbox_mAP_75': 0.257, 'coco/bbox_mAP_s': 0.111, 'coco/bbox_mAP_m': 0.357, 'coco/bbox_mAP_l': 0.188, 'coco/segm_mAP': 0.249, 'coco/segm_mAP_50': 0.564, 'coco/segm_mAP_75': 0.171, 'coco/segm_mAP_s': 0.082, 'coco/segm_mAP_m': 0.35, 'coco/segm_mAP_l': 0.168}
# wandb: Encountered an error while tearing down the service manager: [WinError 10054] An existing connection was forcibly closed by the remote host
