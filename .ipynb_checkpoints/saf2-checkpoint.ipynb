# %%
from mmdet.apis import init_detector, inference_detector
import mmcv
import matplotlib.pyplot as plt

config_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco.py'
checkpoint_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco_20200317-7332cf16.pth'
model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
inference_detector(model, 'mmdetection/demo/demo.jpg')
# Out:
# c:\users\ahluw\onedrive - university of sussex\sem 2\saf2\mmdetection\mmdet\models\losses\cross_entropy_loss.py:240: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_r50_fpn_1x_coco_20200317-7332cf16.pth
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 checkpoint_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco_20200317-7332cf16.pth'
#       7 model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
# ----> 8 inference_detector(model, 'demo/demo.jpg')
#
# File c:\users\ahluw\onedrive - university of sussex\sem 2\saf2\mmdetection\mmdet\apis\inference.py:182, in inference_detector(model, imgs, test_pipeline, text_prompt, custom_entities)
#     179     data_['custom_entities'] = custom_entities
#     181 # build the data pipeline
# --> 182 data_ = test_pipeline(data_)
#     184 data_['inputs'] = [data_['inputs']]
#     185 data_['data_samples'] = [data_['data_samples']]
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmcv\transforms\base.py:12, in BaseTransform.__call__(self, results)
#       9 def __call__(self,
#      10              results: Dict) -> Optional[Union[Dict, Tuple[List, List]]]:
# ---> 12     return self.transform(results)
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmcv\transforms\wrappers.py:88, in Compose.transform(self, results)
#      79 """Call function to apply transforms sequentially.
#      80
#      81 Args:
#    (...)
#      85     dict or None: Transformed results.
#      86 """
#      87 for t in self.transforms:
# ---> 88     results = t(results)  # type: ignore
#      89     if results is None:
#      90         return None
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmcv\transforms\base.py:12, in BaseTransform.__call__(self, results)
#       9 def __call__(self,
#      10              results: Dict) -> Optional[Union[Dict, Tuple[List, List]]]:
# ---> 12     return self.transform(results)
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmcv\transforms\loading.py:107, in LoadImageFromFile.transform(self, results)
#     105         return None
#     106     else:
# --> 107         raise e
#     108 # in some cases, images are not read successfully, the img would be
#     109 # `None`, refer to https://github.com/open-mmlab/mmpretrain/issues/1427
#     110 assert img is not None, f'failed to load image: {filename}'
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmcv\transforms\loading.py:99, in LoadImageFromFile.transform(self, results)
#      97         img_bytes = file_client.get(filename)
#      98     else:
# ---> 99         img_bytes = fileio.get(
#     100             filename, backend_args=self.backend_args)
#     101     img = mmcv.imfrombytes(
#     102         img_bytes, flag=self.color_type, backend=self.imdecode_backend)
#     103 except Exception as e:
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmengine\fileio\io.py:181, in get(filepath, backend_args)
#     164 """Read bytes from a given ``filepath`` with 'rb' mode.
#     165
#     166 Args:
#    (...)
#     177     b'hello world'
#     178 """
#     179 backend = get_file_backend(
#     180     filepath, backend_args=backend_args, enable_singleton=True)
# --> 181 return backend.get(filepath)
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmengine\fileio\backends\local_backend.py:33, in LocalBackend.get(self, filepath)
#      18 def get(self, filepath: Union[str, Path]) -> bytes:
#      19     """Read bytes from a given ``filepath`` with 'rb' mode.
#      20
#      21     Args:
#    (...)
#      31         b'hello world'
#      32     """
# ---> 33     with open(filepath, 'rb') as f:
#      34         value = f.read()
#      35     return value
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demo/demo.jpg'
