# %%
from mmdet.apis import init_detector, inference_detector
import mmcv
import matplotlib.pyplot as plt

# Path to config and checkpoint file
config_file = 'configs/htc/htc_r50_fpn_1x_coco.py'
checkpoint_file = 'path_to_checkpoint_file.pth'

# Initialize the model
model = init_detector(config_file, checkpoint_file, device='cuda:0')

# Inference
img = 'test_image.jpg'
result = inference_detector(model, img)

# Display result
model.show_result(img, result, out_file='result.jpg')

# Show the output image
result_img = mmcv.imread('result.jpg')
plt.imshow(mmcv.bgr2rgb(result_img))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mmdet.apis import init_detector, inference_detector
#       2 import mmcv
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'mmdet'
