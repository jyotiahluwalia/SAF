# %%
from mmdet.apis import init_detector, inference_detector
import mmcv
import matplotlib.pyplot as plt

config_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco.py'
checkpoint_file = 'mmdetection/configs/htc/metafile.yml'
model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
inference_detector(model, 'demo/demo.jpg')
# Out:
# c:\users\ahluw\onedrive - university of sussex\sem 2\saf2\mmdetection\mmdet\models\losses\cross_entropy_loss.py:240: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: mmdetection/configs/htc/metafile.yml
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[1], line 7
#       5 config_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco.py'
#       6 checkpoint_file = 'mmdetection/configs/htc/metafile.yml'
# ----> 7 model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
#       8 inference_detector(model, 'demo/demo.jpg')
#
# File c:\users\ahluw\onedrive - university of sussex\sem 2\saf2\mmdetection\mmdet\apis\inference.py:73, in init_detector(config, checkpoint, palette, device, cfg_options)
#      71     model.dataset_meta = {'classes': get_classes('coco')}
#      72 else:
# ---> 73     checkpoint = load_checkpoint(model, checkpoint, map_location='cpu')
#      74     # Weights converted from elsewhere may not have meta fields.
#      75     checkpoint_meta = checkpoint.get('meta', {})
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmengine\runner\checkpoint.py:636, in load_checkpoint(model, filename, map_location, strict, logger, revise_keys)
#     611 def load_checkpoint(model,
#     612                     filename,
#     613                     map_location=None,
#     614                     strict=False,
#     615                     logger=None,
#     616                     revise_keys=[(r'^module\.', '')]):
#     617     """Load checkpoint from a file or URI.
#     618
#     619     Args:
#    (...)
#     634         dict or OrderedDict: The loaded checkpoint.
#     635     """
# --> 636     checkpoint = _load_checkpoint(filename, map_location, logger)
#     637     # OrderedDict is a subclass of dict
#     638     if not isinstance(checkpoint, dict):
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmengine\runner\checkpoint.py:548, in _load_checkpoint(filename, map_location, logger)
#     531 def _load_checkpoint(filename, map_location=None, logger=None):
#     532     """Load checkpoint from somewhere (modelzoo, file, url).
#     533
#     534     Args:
#    (...)
#     546         information, which depends on the checkpoint.
#     547     """
# --> 548     return CheckpointLoader.load_checkpoint(filename, map_location, logger)
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmengine\runner\checkpoint.py:330, in CheckpointLoader.load_checkpoint(cls, filename, map_location, logger)
#     325 class_name = checkpoint_loader.__name__
#     326 print_log(
#     327     f'Loads checkpoint by {class_name[10:]} backend from path: '
#     328     f'{filename}',
#     329     logger=logger)
# --> 330 return checkpoint_loader(filename, map_location)
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\mmengine\runner\checkpoint.py:347, in load_from_local(filename, map_location)
#     345 if not osp.isfile(filename):
#     346     raise FileNotFoundError(f'{filename} can not be found.')
# --> 347 checkpoint = torch.load(filename, map_location=map_location)
#     348 return checkpoint
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\torch\serialization.py:1040, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1038     except RuntimeError as e:
#    1039         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# -> 1040 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~\OneDrive - University of Sussex\Sem 2\SAF2\myenv2\Lib\site-packages\torch\serialization.py:1262, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#    1256 if not hasattr(f, 'readinto') and (3, 8, 0) <= sys.version_info < (3, 8, 2):
#    1257     raise RuntimeError(
#    1258         "torch.load does not work with file-like objects that do not implement readinto on Python 3.8.0 and 3.8.1. "
#    1259         f"Received object of type \"{type(f)}\". Please update to Python 3.8.2 or newer to restore this "
#    1260         "functionality.")
# -> 1262 magic_number = pickle_module.load(f, **pickle_load_args)
#    1263 if magic_number != MAGIC_NUMBER:
#    1264     raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, 'w'.
