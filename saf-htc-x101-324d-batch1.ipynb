# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# PyTorch version: 2.3.1
# CUDA available: True
# CUDA version: 12.1

# %%
# Check mmengine installation
import mmengine
print(f"MMengine: {mmengine.__version__}")

# Check Openmim installation
from importlib.metadata import version
print(f"Openmim: {version('openmim')}")

# Check mmcv installation
import mmcv
print("mmcv:",mmcv.__version__)

# Check MMDetection installation
import mmdet
print("mmdetection:",mmdet.__version__)
# Out:
# MMengine: 0.10.4
# Openmim: 0.3.9
# mmcv: 2.0.0rc4
# mmdetection: 3.3.0

# %%
from pycocotools.coco import COCO

# Path to load the COCO annotation file
annotation_file = 'mmdetection/data/saf22/train/annotation_coco.json'

# Initialise the COCO object
coco = COCO(annotation_file)

# Get all category tags and corresponding category IDs
categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}

# Print all category IDs and corresponding category names
for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")
# Out:
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# Category ID: 1, Category Name: ClassicalEvaporation
# Category ID: 2, Category Name: TansitionalMixing
# Category ID: 3, Category Name: DiffusiveMixing
# Category ID: 4, Category Name: spray

# %%
import mmcv
import mmengine
from mmdet.apis import init_detector, inference_detector
from mmdet.utils import register_all_modules
# Choose to use a config and initialize the detector
config_file = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco.py'
# Setup a checkpoint file to load
checkpoint_file = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'

# register all modules in mmdet into the registries
register_all_modules()

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')  # or device='cuda:0'
# Out:
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias

# %% [markdown]
# ### Wandb integration

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# True

# %%
# Weights and Biases version
print(wandb.__version__)
# Out:
# 0.17.5

# %% [markdown]
# # Medium with epoch size - 500

# %% [markdown]
# ## Modify the config

# %% [markdown]
# In the next step, we need to modify the config for the training. To accelerate the process, we finetune a detector using a pre-trained detector.

# %%
from mmengine.runner import set_random_seed
from mmengine import Config
import random
import numpy as np
import matplotlib.pyplot as plt
from mmdet.visualization import DetLocalVisualizer
import os
import cv2

# %%
# Load the configuration
cfg = Config.fromfile('mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco.py')

# Modify dataset classes and color
cfg.metainfo = {
    'classes': ('ClassicalEvaporation', 'TansitionalMixing', 'DiffusiveMixing', 'spray'),
    'palette': [
        (13,24,103), (167,13,13), (91,117,249), (203,173,55),
    ]
}

# Modify dataset type and path
cfg.data_root = 'mmdetection/data/saf22/'
cfg.train_dataloader.dataset.ann_file = 'train/annotation_coco.json'
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = {'img': 'train/'}
cfg.train_dataloader.dataset.metainfo = cfg.metainfo

cfg.val_dataloader.dataset.ann_file = 'val/annotation_coco.json'
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = {'img': 'val/'}
cfg.val_dataloader.dataset.metainfo = cfg.metainfo

cfg.test_dataloader = cfg.val_dataloader

# Modify metric config
cfg.val_evaluator.ann_file = f'{cfg.data_root}val/annotation_coco.json'
cfg.test_evaluator = cfg.val_evaluator

################################################################################################

# Modify num classes of the model in box head and mask head
if isinstance(cfg.model.roi_head.bbox_head, list):
    for head in cfg.model.roi_head.bbox_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.bbox_head.num_classes = 4

if isinstance(cfg.model.roi_head.mask_head, list):
    for head in cfg.model.roi_head.mask_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.mask_head.num_classes = 4

################################################################################################

# Configure checkpoint saving
cfg.default_hooks.checkpoint = dict(
    type='CheckpointHook',
    interval=1,
    save_optimizer=True,
    save_best = ['coco/bbox_mAP','coco/segm_mAP'],
    save_last=True,
    rule='greater',
    max_keep_ckpts=1
)

cfg.test_evaluator.update(dict(classwise=True))

# Use the pre-trained HTC model
cfg.load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'

# Set up working dir to save files and logs
cfg.work_dir = './tutorial_exps/500-epochs-batch1'

# Set the number of epochs
cfg.train_cfg.max_epochs = 500

# Set the evaluation interval
cfg.train_cfg.val_interval = 3

# Set the checkpoint saving interval to reduce the storage cost
cfg.default_hooks.checkpoint.interval = 3

# Adjust learning rate for single GPU
cfg.optim_wrapper.optimizer.lr = 0.02 / 8

# Set logging interval
cfg.default_hooks.logger.interval = 10

# Set seed for reproducibility
set_random_seed(0, deterministic=False)

# Use Tensorboard to log the training process
cfg.visualizer.vis_backends.append({"type": 'TensorboardVisBackend'})

# Configure WandB logger
cfg.visualizer.vis_backends.append(dict(type='WandbVisBackend', init_kwargs=dict(
    project='SAF_Project',
    entity='ahluwaliajyoti50-university-of-sussex',
    config={
        'learning_rate': cfg.optim_wrapper.optimizer.lr,
        'architecture': 'HTC_resnext101_32x4d',
        'dataset': 'SAF22',
        'epochs': cfg.train_cfg.max_epochs,
        'batch_size': cfg.train_dataloader.batch_size,
        'optimizer': cfg.optim_wrapper.optimizer.type,
        'classes': cfg.metainfo['classes'],
        'seed': 0,
    }
)))

# Save the modified config
config = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1.py'
with open(config, 'w') as f:
    f.write(cfg.pretty_text)

# Train using train.py
# %run mmdetection/tools/train.py {config}

# [Optional] Finish the wandb run
wandb.finish()
# Out:
# 08/08 11:55:08 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 209652396
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#     MSVC: n/a, reason: fileno
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 209652396
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/08 11:55:08 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch1'
# wandb version 0.17.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch1\20240808_115501\vis_data\wandb\run-20240808_115509-pqecpje0</code>
# Syncing run <strong><a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/pqecpje0' target="_blank">stoic-totem-60</a></strong> to <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a>
#  View run at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/pqecpje0' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/pqecpje0</a>
# 08/08 11:55:22 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/08 11:55:22 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# 08/08 11:55:28 - mmengine - INFO - load model from: open-mmlab://resnext101_32x4d
# 08/08 11:55:28 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_32x4d
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias
#
# 08/08 11:55:28 - mmengine - INFO - Load checkpoint from mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# 08/08 11:55:28 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/08 11:55:28 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/08 11:55:28 - mmengine - INFO - Checkpoints will be saved to C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch1.
# 08/08 11:56:31 - mmengine - INFO - Epoch(train)   [1][10/36]  lr: 4.7545e-05  eta: 1 day, 7:08:35  time: 6.2321  data_time: 4.4402  memory: 4879  loss: 4.0696  loss_rpn_cls: 0.0025  loss_rpn_bbox: 0.0017  s0.loss_cls: 1.4570  s0.acc: 87.8906  s0.loss_bbox: 0.0124  s0.loss_mask: 0.6809  s1.loss_cls: 0.8469  s1.acc: 6.0547  s1.loss_bbox: 0.0135  s1.loss_mask: 0.4034  s2.loss_cls: 0.3915  s2.acc: 18.9453  s2.loss_bbox: 0.0087  s2.loss_mask: 0.2512
# 08/08 11:56:34 - mmengine - INFO - Epoch(train)   [1][20/36]  lr: 9.7595e-05  eta: 16:19:24  time: 3.2683  data_time: 2.2263  memory: 4171  loss: 3.7553  loss_rpn_cls: 0.0031  loss_rpn_bbox: 0.0014  s0.loss_cls: 1.2761  s0.acc: 97.0703  s0.loss_bbox: 0.0119  s0.loss_mask: 0.6867  s1.loss_cls: 0.7625  s1.acc: 97.0703  s1.loss_bbox: 0.0132  s1.loss_mask: 0.3967  s2.loss_cls: 0.3601  s2.acc: 97.0703  s2.loss_bbox: 0.0079  s2.loss_mask: 0.2355
# 08/08 11:56:37 - mmengine - INFO - Epoch(train)   [1][30/36]  lr: 1.4765e-04  eta: 11:27:16  time: 2.2947  data_time: 1.4916  memory: 4472  loss: 3.3752  loss_rpn_cls: 0.0391  loss_rpn_bbox: 0.0014  s0.loss_cls: 1.0528  s0.acc: 96.0938  s0.loss_bbox: 0.0106  s0.loss_mask: 0.6793  s1.loss_cls: 0.6360  s1.acc: 96.0938  s1.loss_bbox: 0.0127  s1.loss_mask: 0.3925  s2.loss_cls: 0.3108  s2.acc: 96.6797  s2.loss_bbox: 0.0077  s2.loss_mask: 0.2322
# 08/08 11:56:39 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:56:43 - mmengine - INFO - Epoch(train)   [2][10/36]  lr: 2.2773e-04  eta: 8:04:00  time: 1.6175  data_time: 0.9845  memory: 4878  loss: 2.8536  loss_rpn_cls: 0.0482  loss_rpn_bbox: 0.0015  s0.loss_cls: 0.7905  s0.acc: 92.9688  s0.loss_bbox: 0.0105  s0.loss_mask: 0.6675  s1.loss_cls: 0.4776  s1.acc: 91.7969  s1.loss_bbox: 0.0140  s1.loss_mask: 0.3796  s2.loss_cls: 0.2385  s2.acc: 91.4062  s2.loss_bbox: 0.0094  s2.loss_mask: 0.2162
# 08/08 11:56:46 - mmengine - INFO - Epoch(train)   [2][20/36]  lr: 2.7778e-04  eta: 6:54:23  time: 0.3297  data_time: 0.0210  memory: 4614  loss: 2.4380  loss_rpn_cls: 0.0451  loss_rpn_bbox: 0.0014  s0.loss_cls: 0.5846  s0.acc: 99.4141  s0.loss_bbox: 0.0093  s0.loss_mask: 0.6499  s1.loss_cls: 0.3640  s1.acc: 99.2188  s1.loss_bbox: 0.0142  s1.loss_mask: 0.3674  s2.loss_cls: 0.1876  s2.acc: 99.4141  s2.loss_bbox: 0.0099  s2.loss_mask: 0.2046
# 08/08 11:56:49 - mmengine - INFO - Epoch(train)   [2][30/36]  lr: 3.2783e-04  eta: 6:06:14  time: 0.3346  data_time: 0.0225  memory: 4130  loss: 1.9658  loss_rpn_cls: 0.0446  loss_rpn_bbox: 0.0015  s0.loss_cls: 0.3536  s0.acc: 95.7031  s0.loss_bbox: 0.0084  s0.loss_mask: 0.6287  s1.loss_cls: 0.2319  s1.acc: 93.5547  s1.loss_bbox: 0.0143  s1.loss_mask: 0.3535  s2.loss_cls: 0.1274  s2.acc: 93.3594  s2.loss_bbox: 0.0108  s2.loss_mask: 0.1910
# 08/08 11:56:52 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:56:55 - mmengine - INFO - Epoch(train)   [3][10/36]  lr: 4.0791e-04  eta: 5:16:08  time: 0.3425  data_time: 0.0257  memory: 5002  loss: 1.5298  loss_rpn_cls: 0.0080  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.1887  s0.acc: 94.5312  s0.loss_bbox: 0.0097  s0.loss_mask: 0.5741  s1.loss_cls: 0.1401  s1.acc: 92.7734  s1.loss_bbox: 0.0191  s1.loss_mask: 0.3225  s2.loss_cls: 0.0834  s2.acc: 92.7734  s2.loss_bbox: 0.0158  s2.loss_mask: 0.1676
# 08/08 11:56:58 - mmengine - INFO - Epoch(train)   [3][20/36]  lr: 4.5796e-04  eta: 4:52:31  time: 0.3394  data_time: 0.0204  memory: 4610  loss: 1.4046  loss_rpn_cls: 0.0021  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.1595  s0.acc: 95.5078  s0.loss_bbox: 0.0095  s0.loss_mask: 0.5370  s1.loss_cls: 0.1261  s1.acc: 92.7734  s1.loss_bbox: 0.0197  s1.loss_mask: 0.3007  s2.loss_cls: 0.0766  s2.acc: 92.7734  s2.loss_bbox: 0.0163  s2.loss_mask: 0.1564
# 08/08 11:57:02 - mmengine - INFO - Epoch(train)   [3][30/36]  lr: 5.0801e-04  eta: 4:34:10  time: 0.3484  data_time: 0.0216  memory: 5071  loss: 1.3340  loss_rpn_cls: 0.0024  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.1554  s0.acc: 96.0938  s0.loss_bbox: 0.0104  s0.loss_mask: 0.5000  s1.loss_cls: 0.1254  s1.acc: 93.5547  s1.loss_bbox: 0.0234  s1.loss_mask: 0.2756  s2.loss_cls: 0.0771  s2.acc: 92.9688  s2.loss_bbox: 0.0194  s2.loss_mask: 0.1436
# 08/08 11:57:04 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:57:04 - mmengine - INFO - Saving checkpoint at 3 epochs
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 08/08 11:57:20 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.045
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.044
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.816
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.272
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.055
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 11:57:20 - mmengine - INFO - bbox_mAP_copypaste: 0.045 0.071 0.044 0.032 0.650 0.816
# 08/08 11:57:20 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.078
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.750
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.674
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.241
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.058
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.767
# 08/08 11:57:20 - mmengine - INFO - segm_mAP_copypaste: 0.042 0.078 0.052 0.033 0.750 0.674
# 08/08 11:57:20 - mmengine - INFO - Epoch(val) [3][8/8]    coco/bbox_mAP: 0.0450  coco/bbox_mAP_50: 0.0710  coco/bbox_mAP_75: 0.0440  coco/bbox_mAP_s: 0.0320  coco/bbox_mAP_m: 0.6500  coco/bbox_mAP_l: 0.8160  coco/segm_mAP: 0.0420  coco/segm_mAP_50: 0.0780  coco/segm_mAP_75: 0.0520  coco/segm_mAP_s: 0.0330  coco/segm_mAP_m: 0.7500  coco/segm_mAP_l: 0.6740  data_time: 1.0652  time: 1.6461
# 08/08 11:57:21 - mmengine - INFO - The best checkpoint with 0.0450 coco/bbox_mAP at 3 epoch is saved to best_coco_bbox_mAP_epoch_3.pth.
# 08/08 11:57:23 - mmengine - INFO - The best checkpoint with 0.0420 coco/segm_mAP at 3 epoch is saved to best_coco_segm_mAP_epoch_3.pth.
# 08/08 11:57:29 - mmengine - INFO - Epoch(train)   [4][10/36]  lr: 5.8809e-04  eta: 4:12:26  time: 0.3655  data_time: 0.0275  memory: 4633  loss: 1.1994  loss_rpn_cls: 0.0015  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.1471  s0.acc: 97.2656  s0.loss_bbox: 0.0110  s0.loss_mask: 0.4448  s1.loss_cls: 0.1171  s1.acc: 94.1406  s1.loss_bbox: 0.0266  s1.loss_mask: 0.2339  s2.loss_cls: 0.0744  s2.acc: 93.7500  s2.loss_bbox: 0.0227  s2.loss_mask: 0.1196
# 08/08 11:57:32 - mmengine - INFO - Epoch(train)   [4][20/36]  lr: 6.3814e-04  eta: 4:00:29  time: 0.3555  data_time: 0.0224  memory: 5067  loss: 1.1199  loss_rpn_cls: 0.0013  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.1372  s0.acc: 97.4609  s0.loss_bbox: 0.0117  s0.loss_mask: 0.4226  s1.loss_cls: 0.1066  s1.acc: 95.7031  s1.loss_bbox: 0.0286  s1.loss_mask: 0.2122  s2.loss_cls: 0.0677  s2.acc: 93.3594  s2.loss_bbox: 0.0240  s2.loss_mask: 0.1072
# 08/08 11:57:36 - mmengine - INFO - Epoch(train)   [4][30/36]  lr: 6.8819e-04  eta: 3:49:58  time: 0.3553  data_time: 0.0218  memory: 4919  loss: 1.0455  loss_rpn_cls: 0.0017  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.1297  s0.acc: 95.7031  s0.loss_bbox: 0.0119  s0.loss_mask: 0.3899  s1.loss_cls: 0.1021  s1.acc: 94.5312  s1.loss_bbox: 0.0320  s1.loss_mask: 0.1898  s2.loss_cls: 0.0658  s2.acc: 93.5547  s2.loss_bbox: 0.0273  s2.loss_mask: 0.0945
# 08/08 11:57:38 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:57:42 - mmengine - INFO - Epoch(train)   [5][10/36]  lr: 7.6827e-04  eta: 3:37:26  time: 0.3640  data_time: 0.0246  memory: 5070  loss: 0.9593  loss_rpn_cls: 0.0012  loss_rpn_bbox: 0.0007  s0.loss_cls: 0.1254  s0.acc: 93.7500  s0.loss_bbox: 0.0131  s0.loss_mask: 0.3499  s1.loss_cls: 0.0970  s1.acc: 90.4297  s1.loss_bbox: 0.0322  s1.loss_mask: 0.1654  s2.loss_cls: 0.0646  s2.acc: 89.2578  s2.loss_bbox: 0.0287  s2.loss_mask: 0.0811
# 08/08 11:57:45 - mmengine - INFO - Epoch(train)   [5][20/36]  lr: 8.1832e-04  eta: 3:30:38  time: 0.3505  data_time: 0.0191  memory: 4797  loss: 0.9366  loss_rpn_cls: 0.0011  loss_rpn_bbox: 0.0006  s0.loss_cls: 0.1216  s0.acc: 93.5547  s0.loss_bbox: 0.0150  s0.loss_mask: 0.3375  s1.loss_cls: 0.0913  s1.acc: 91.9922  s1.loss_bbox: 0.0376  s1.loss_mask: 0.1612  s2.loss_cls: 0.0603  s2.acc: 92.5781  s2.loss_bbox: 0.0318  s2.loss_mask: 0.0784
# 08/08 11:57:49 - mmengine - INFO - Epoch(train)   [5][30/36]  lr: 8.6837e-04  eta: 3:25:06  time: 0.3633  data_time: 0.0203  memory: 5069  loss: 0.9219  loss_rpn_cls: 0.0012  loss_rpn_bbox: 0.0005  s0.loss_cls: 0.1284  s0.acc: 93.3594  s0.loss_bbox: 0.0152  s0.loss_mask: 0.3213  s1.loss_cls: 0.0927  s1.acc: 92.7734  s1.loss_bbox: 0.0376  s1.loss_mask: 0.1547  s2.loss_cls: 0.0620  s2.acc: 84.9609  s2.loss_bbox: 0.0323  s2.loss_mask: 0.0759
# 08/08 11:57:51 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:57:55 - mmengine - INFO - Epoch(train)   [6][10/36]  lr: 9.4845e-04  eta: 3:17:00  time: 0.3743  data_time: 0.0277  memory: 5070  loss: 0.8826  loss_rpn_cls: 0.0008  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.1229  s0.acc: 94.9219  s0.loss_bbox: 0.0160  s0.loss_mask: 0.3065  s1.loss_cls: 0.0864  s1.acc: 93.7500  s1.loss_bbox: 0.0360  s1.loss_mask: 0.1487  s2.loss_cls: 0.0589  s2.acc: 92.1875  s2.loss_bbox: 0.0320  s2.loss_mask: 0.0736
# 08/08 11:57:59 - mmengine - INFO - Epoch(train)   [6][20/36]  lr: 9.9850e-04  eta: 3:12:24  time: 0.3667  data_time: 0.0240  memory: 5062  loss: 0.8560  loss_rpn_cls: 0.0009  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.1148  s0.acc: 95.8984  s0.loss_bbox: 0.0147  s0.loss_mask: 0.3024  s1.loss_cls: 0.0815  s1.acc: 95.5078  s1.loss_bbox: 0.0331  s1.loss_mask: 0.1482  s2.loss_cls: 0.0559  s2.acc: 93.9453  s2.loss_bbox: 0.0305  s2.loss_mask: 0.0733
# 08/08 11:58:02 - mmengine - INFO - Epoch(train)   [6][30/36]  lr: 1.0485e-03  eta: 3:07:45  time: 0.3645  data_time: 0.0232  memory: 4557  loss: 0.8325  loss_rpn_cls: 0.0009  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.1116  s0.acc: 99.0234  s0.loss_bbox: 0.0133  s0.loss_mask: 0.2981  s1.loss_cls: 0.0780  s1.acc: 97.0703  s1.loss_bbox: 0.0284  s1.loss_mask: 0.1468  s2.loss_cls: 0.0540  s2.acc: 97.0703  s2.loss_bbox: 0.0277  s2.loss_mask: 0.0730
# 08/08 11:58:04 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:58:04 - mmengine - INFO - Saving checkpoint at 6 epochs
# 08/08 11:58:12 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.258
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.280
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.911
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.306
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.933
# 08/08 11:58:12 - mmengine - INFO - bbox_mAP_copypaste: 0.258 0.303 0.280 0.043 0.900 0.911
# 08/08 11:58:12 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.242
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.312
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.285
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.046
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.837
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.105
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/08 11:58:12 - mmengine - INFO - segm_mAP_copypaste: 0.242 0.312 0.285 0.046 0.800 0.837
# 08/08 11:58:12 - mmengine - INFO - Epoch(val) [6][8/8]    coco/bbox_mAP: 0.2580  coco/bbox_mAP_50: 0.3030  coco/bbox_mAP_75: 0.2800  coco/bbox_mAP_s: 0.0430  coco/bbox_mAP_m: 0.9000  coco/bbox_mAP_l: 0.9110  coco/segm_mAP: 0.2420  coco/segm_mAP_50: 0.3120  coco/segm_mAP_75: 0.2850  coco/segm_mAP_s: 0.0460  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.8370  data_time: 0.1083  time: 0.6602
# 08/08 11:58:12 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch1\best_coco_bbox_mAP_epoch_3.pth is removed
# 08/08 11:58:14 - mmengine - INFO - The best checkpoint with 0.2580 coco/bbox_mAP at 6 epoch is saved to best_coco_bbox_mAP_epoch_6.pth.
# 08/08 11:58:14 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch1\best_coco_segm_mAP_epoch_3.pth is removed
# 08/08 11:58:15 - mmengine - INFO - The best checkpoint with 0.2420 coco/segm_mAP at 6 epoch is saved to best_coco_segm_mAP_epoch_6.pth.
# 08/08 11:58:21 - mmengine - INFO - Epoch(train)   [7][10/36]  lr: 1.1286e-03  eta: 3:02:17  time: 0.3656  data_time: 0.0249  memory: 5070  loss: 0.7790  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.0951  s0.acc: 96.4844  s0.loss_bbox: 0.0119  s0.loss_mask: 0.2892  s1.loss_cls: 0.0686  s1.acc: 93.9453  s1.loss_bbox: 0.0266  s1.loss_mask: 0.1414  s2.loss_cls: 0.0484  s2.acc: 95.5078  s2.loss_bbox: 0.0270  s2.loss_mask: 0.0692
# 08/08 11:58:25 - mmengine - INFO - Epoch(train)   [7][20/36]  lr: 1.1787e-03  eta: 2:58:49  time: 0.3563  data_time: 0.0191  memory: 4715  loss: 0.7562  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0008  s0.loss_cls: 0.0876  s0.acc: 97.8516  s0.loss_bbox: 0.0101  s0.loss_mask: 0.2865  s1.loss_cls: 0.0650  s1.acc: 96.6797  s1.loss_bbox: 0.0254  s1.loss_mask: 0.1401  s2.loss_cls: 0.0460  s2.acc: 94.7266  s2.loss_bbox: 0.0260  s2.loss_mask: 0.0685
# 08/08 11:58:29 - mmengine - INFO - Epoch(train)   [7][30/36]  lr: 1.2287e-03  eta: 2:55:56  time: 0.3562  data_time: 0.0187  memory: 5070  loss: 0.7431  loss_rpn_cls: 0.0006  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0837  s0.acc: 96.6797  s0.loss_bbox: 0.0096  s0.loss_mask: 0.2842  s1.loss_cls: 0.0619  s1.acc: 95.3125  s1.loss_bbox: 0.0246  s1.loss_mask: 0.1398  s2.loss_cls: 0.0443  s2.acc: 93.7500  s2.loss_bbox: 0.0253  s2.loss_mask: 0.0682
# 08/08 11:58:30 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 11:58:34 - mmengine - INFO - Epoch(train)   [8][10/36]  lr: 1.3088e-03  eta: 2:51:22  time: 0.3644  data_time: 0.0217  memory: 4602  loss: 0.7108  loss_rpn_cls: 0.0010  loss_rpn_bbox: 0.0009  s0.loss_cls: 0.0796  s0.acc: 98.4375  s0.loss_bbox: 0.0098  s0.loss_mask: 0.2693  s1.loss_cls: 0.0601  s1.acc: 99.8047  s1.loss_bbox: 0.0248  s1.loss_mask: 0.1318  s2.loss_cls: 0.0430  s2.acc: 99.8047  s2.loss_bbox: 0.0261  s2.loss_mask: 0.0645
# 08/08 11:58:38 - mmengine - INFO - Epoch(train)   [8][20/36]  lr: 1.3589e-03  eta: 2:48:51  time: 0.3538  data_time: 0.0191  memory: 5070  loss: 0.7045  loss_rpn_cls: 0.0010  loss_rpn_bbox: 0.0005  s0.loss_cls: 0.0760  s0.acc: 99.4141  s0.loss_bbox: 0.0086  s0.loss_mask: 0.2743  s1.loss_cls: 0.0570  s1.acc: 99.0234  s1.loss_bbox: 0.0222  s1.loss_mask: 0.1336  s2.loss_cls: 0.0411  s2.acc: 97.0703  s2.loss_bbox: 0.0246  s2.loss_mask: 0.0657
# ...
# 08/08 14:08:05 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 14:08:09 - mmengine - INFO - Epoch(train) [498][10/36]  lr: 2.5000e-05  eta: 0:00:37  time: 0.3811  data_time: 0.0246  memory: 5062  loss: 0.2704  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0102  s0.acc: 99.6094  s0.loss_bbox: 0.0024  s0.loss_mask: 0.1277  s1.loss_cls: 0.0073  s1.acc: 99.8047  s1.loss_bbox: 0.0073  s1.loss_mask: 0.0641  s2.loss_cls: 0.0066  s2.acc: 99.8047  s2.loss_bbox: 0.0130  s2.loss_mask: 0.0316
# 08/08 14:08:13 - mmengine - INFO - Epoch(train) [498][20/36]  lr: 2.5000e-05  eta: 0:00:33  time: 0.3774  data_time: 0.0207  memory: 5061  loss: 0.2742  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0103  s0.acc: 99.4141  s0.loss_bbox: 0.0023  s0.loss_mask: 0.1296  s1.loss_cls: 0.0074  s1.acc: 99.2032  s1.loss_bbox: 0.0076  s1.loss_mask: 0.0650  s2.loss_cls: 0.0070  s2.acc: 98.9837  s2.loss_bbox: 0.0129  s2.loss_mask: 0.0320
# 08/08 14:08:17 - mmengine - INFO - Epoch(train) [498][30/36]  lr: 2.5000e-05  eta: 0:00:29  time: 0.3751  data_time: 0.0210  memory: 5068  loss: 0.2690  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0099  s0.acc: 99.4141  s0.loss_bbox: 0.0023  s0.loss_mask: 0.1263  s1.loss_cls: 0.0075  s1.acc: 99.4141  s1.loss_bbox: 0.0076  s1.loss_mask: 0.0638  s2.loss_cls: 0.0070  s2.acc: 99.8047  s2.loss_bbox: 0.0130  s2.loss_mask: 0.0314
# 08/08 14:08:19 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 14:08:19 - mmengine - INFO - Saving checkpoint at 498 epochs
# 08/08 14:08:25 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.360
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.365
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:08:25 - mmengine - INFO - bbox_mAP_copypaste: 0.300 0.360 0.332 0.100 0.850 0.900
# 08/08 14:08:25 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/08 14:08:25 - mmengine - INFO - segm_mAP_copypaste: 0.281 0.362 0.328 0.090 0.800 0.855
# 08/08 14:08:25 - mmengine - INFO - Epoch(val) [498][8/8]    coco/bbox_mAP: 0.3000  coco/bbox_mAP_50: 0.3600  coco/bbox_mAP_75: 0.3320  coco/bbox_mAP_s: 0.1000  coco/bbox_mAP_m: 0.8500  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2810  coco/segm_mAP_50: 0.3620  coco/segm_mAP_75: 0.3280  coco/segm_mAP_s: 0.0900  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.8550  data_time: 0.1467  time: 0.3839
# 08/08 14:08:29 - mmengine - INFO - Epoch(train) [499][10/36]  lr: 2.5000e-05  eta: 0:00:23  time: 0.3875  data_time: 0.0277  memory: 5061  loss: 0.2732  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0099  s0.acc: 100.0000  s0.loss_bbox: 0.0023  s0.loss_mask: 0.1278  s1.loss_cls: 0.0078  s1.acc: 99.0234  s1.loss_bbox: 0.0079  s1.loss_mask: 0.0648  s2.loss_cls: 0.0071  s2.acc: 97.8516  s2.loss_bbox: 0.0136  s2.loss_mask: 0.0318
# 08/08 14:08:33 - mmengine - INFO - Epoch(train) [499][20/36]  lr: 2.5000e-05  eta: 0:00:19  time: 0.3828  data_time: 0.0234  memory: 4694  loss: 0.2704  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0102  s0.acc: 100.0000  s0.loss_bbox: 0.0022  s0.loss_mask: 0.1266  s1.loss_cls: 0.0078  s1.acc: 99.6094  s1.loss_bbox: 0.0077  s1.loss_mask: 0.0639  s2.loss_cls: 0.0070  s2.acc: 99.8047  s2.loss_bbox: 0.0136  s2.loss_mask: 0.0313
# 08/08 14:08:37 - mmengine - INFO - Epoch(train) [499][30/36]  lr: 2.5000e-05  eta: 0:00:15  time: 0.3867  data_time: 0.0254  memory: 5067  loss: 0.2744  loss_rpn_cls: 0.0001  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0119  s0.acc: 99.8047  s0.loss_bbox: 0.0025  s0.loss_mask: 0.1271  s1.loss_cls: 0.0085  s1.acc: 99.6094  s1.loss_bbox: 0.0079  s1.loss_mask: 0.0641  s2.loss_cls: 0.0072  s2.acc: 99.8047  s2.loss_bbox: 0.0134  s2.loss_mask: 0.0315
# 08/08 14:08:39 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 14:08:43 - mmengine - INFO - Epoch(train) [500][10/36]  lr: 2.5000e-05  eta: 0:00:09  time: 0.3783  data_time: 0.0268  memory: 4617  loss: 0.2679  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0110  s0.acc: 100.0000  s0.loss_bbox: 0.0022  s0.loss_mask: 0.1246  s1.loss_cls: 0.0077  s1.acc: 100.0000  s1.loss_bbox: 0.0076  s1.loss_mask: 0.0630  s2.loss_cls: 0.0070  s2.acc: 99.8047  s2.loss_bbox: 0.0134  s2.loss_mask: 0.0310
# 08/08 14:08:46 - mmengine - INFO - Epoch(train) [500][20/36]  lr: 2.5000e-05  eta: 0:00:06  time: 0.3712  data_time: 0.0198  memory: 4863  loss: 0.2683  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0111  s0.acc: 100.0000  s0.loss_bbox: 0.0022  s0.loss_mask: 0.1256  s1.loss_cls: 0.0079  s1.acc: 99.4141  s1.loss_bbox: 0.0074  s1.loss_mask: 0.0628  s2.loss_cls: 0.0070  s2.acc: 98.4375  s2.loss_bbox: 0.0132  s2.loss_mask: 0.0308
# 08/08 14:08:50 - mmengine - INFO - Epoch(train) [500][30/36]  lr: 2.5000e-05  eta: 0:00:02  time: 0.3734  data_time: 0.0193  memory: 5067  loss: 0.2674  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0002  s0.loss_cls: 0.0108  s0.acc: 99.6094  s0.loss_bbox: 0.0021  s0.loss_mask: 0.1247  s1.loss_cls: 0.0077  s1.acc: 99.0234  s1.loss_bbox: 0.0073  s1.loss_mask: 0.0628  s2.loss_cls: 0.0069  s2.acc: 99.6094  s2.loss_bbox: 0.0135  s2.loss_mask: 0.0309
# 08/08 14:08:53 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1_20240808_115501
# 08/08 14:08:53 - mmengine - INFO - Saving checkpoint at 500 epochs
# 08/08 14:08:59 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.361
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.099
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.364
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.364
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.364
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.178
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:08:59 - mmengine - INFO - bbox_mAP_copypaste: 0.299 0.361 0.332 0.099 0.850 0.900
# 08/08 14:08:59 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.362
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.091
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.345
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.164
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/08 14:08:59 - mmengine - INFO - segm_mAP_copypaste: 0.282 0.362 0.328 0.091 0.800 0.855
# 08/08 14:08:59 - mmengine - INFO - Epoch(val) [500][8/8]    coco/bbox_mAP: 0.2990  coco/bbox_mAP_50: 0.3610  coco/bbox_mAP_75: 0.3320  coco/bbox_mAP_s: 0.0990  coco/bbox_mAP_m: 0.8500  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2820  coco/segm_mAP_50: 0.3620  coco/segm_mAP_75: 0.3280  coco/segm_mAP_s: 0.0910  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.8550  data_time: 0.1459  time: 0.3912
# W&B sync reduced upload amount by 5.1%
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>▁▃▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███▇▇▇███████</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁▆▆▇▇▇▇▇▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁▅▆▆▇▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████▇████▇██▇</td></tr><tr><td>coco/bbox_mAP_l</td><td>█▁▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>coco/bbox_mAP_m</td><td>█████▂██▆▆▆▆▆▆▆▆▁▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>coco/bbox_mAP_s</td><td>▁▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>coco/segm_mAP</td><td>▁▆▅▆▆▆▆▆▆▆███▆█▆▇████████▆▆▆▇▇▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>coco/segm_mAP_50</td><td>▁▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>coco/segm_mAP_75</td><td>▁▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████▇██▇█▇▇▇▇▇▇▇▇</td></tr><tr><td>coco/segm_mAP_l</td><td>▁▃▁▃▃▃▃▃▃▃███▃█▃▄████████▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>coco/segm_mAP_m</td><td>▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>coco/segm_mAP_s</td><td>▁▆▇▇▇▇▇▇▇▇█▇█▇██████▇███████████████████</td></tr><tr><td>data_time</td><td>▁▁▁▁▁▁▁▂▁▁▁█▁▇▂▇▁█▁▁▁▁▂▁▁▁▂▁▁▁█▁█▂█▂▁▂▁▂</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>iter</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_rpn_bbox</td><td>▇█▃▂▃▃▃▂▂▂▃▂▂▂▂▁▂▂▂▂▂▂▂▁▂▂▂▂▂▂▁▁▁▂▁▁▁▁▁▁</td></tr><tr><td>loss_rpn_cls</td><td>▇▆▂▃▂▃▃▂▁▃█▂▃▂▄▄▅█▁▂▁▅▄▂▁▂▂▃▂▂▂▂▁▂▁▂▅▁▂▁</td></tr><tr><td>lr</td><td>▄█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>memory</td><td>█▃▅█████▇██▇███▁▁▄███████▆████████▄█████</td></tr><tr><td>s0.acc</td><td>▁██▅▇▆▆▇▇█▇▇▇▇▇▇█████▇██████▇▇▇▇▇███▇█▇█</td></tr><tr><td>s0.loss_bbox</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s0.loss_cls</td><td>█▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s0.loss_mask</td><td>█▄▃▃▃▃▃▃▂▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s1.acc</td><td>▁██▆▇▇▆▇▇█▇█▆▆██▇█▇█████▇█████▇▇████████</td></tr><tr><td>s1.loss_bbox</td><td>█▃▁▂▂▁▁▁▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s1.loss_cls</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s1.loss_mask</td><td>█▅▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s2.acc</td><td>▁█▇▅▆▅▇▇█▇▆▇▅▇█▇▆▇▇▇█▇▇▇▇██▇█▇█▇▇▇█▇████</td></tr><tr><td>s2.loss_bbox</td><td>█▄▂▂▂▂▂▂▁▁▂▂▂▂▂▂▂▁▂▂▂▁▁▂▂▂▂▁▂▂▂▂▁▂▁▁▁▁▁▁</td></tr><tr><td>s2.loss_cls</td><td>█▃▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s2.loss_mask</td><td>█▅▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time</td><td>▂▁▁▃▄▄▃▄▄▄▄█▃▆▂▅▁▆▂▂▃▂▃▂▂▂▃▃▃▂▅▃▃▃▃▄▂▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>0.299</td></tr><tr><td>coco/bbox_mAP_50</td><td>0.361</td></tr><tr><td>coco/bbox_mAP_75</td><td>0.332</td></tr><tr><td>coco/bbox_mAP_l</td><td>0.9</td></tr><tr><td>coco/bbox_mAP_m</td><td>0.85</td></tr><tr><td>coco/bbox_mAP_s</td><td>0.099</td></tr><tr><td>coco/segm_mAP</td><td>0.282</td></tr><tr><td>coco/segm_mAP_50</td><td>0.362</td></tr><tr><td>coco/segm_mAP_75</td><td>0.328</td></tr><tr><td>coco/segm_mAP_l</td><td>0.855</td></tr><tr><td>coco/segm_mAP_m</td><td>0.8</td></tr><tr><td>coco/segm_mAP_s</td><td>0.091</td></tr><tr><td>data_time</td><td>0.14585</td></tr><tr><td>epoch</td><td>500</td></tr><tr><td>iter</td><td>17994</td></tr><tr><td>loss</td><td>0.26735</td></tr><tr><td>loss_rpn_bbox</td><td>0.00015</td></tr><tr><td>loss_rpn_cls</td><td>0.00054</td></tr><tr><td>lr</td><td>2e-05</td></tr><tr><td>memory</td><td>5067</td></tr><tr><td>s0.acc</td><td>99.60938</td></tr><tr><td>s0.loss_bbox</td><td>0.00214</td></tr><tr><td>s0.loss_cls</td><td>0.01085</td></tr><tr><td>s0.loss_mask</td><td>0.1247</td></tr><tr><td>s1.acc</td><td>99.02344</td></tr><tr><td>s1.loss_bbox</td><td>0.00731</td></tr><tr><td>s1.loss_cls</td><td>0.0077</td></tr><tr><td>s1.loss_mask</td><td>0.06275</td></tr><tr><td>s2.acc</ ...
#  View run <strong style="color:#cdcd00">stoic-totem-60</strong> at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/pqecpje0' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/pqecpje0</a><br/> View project at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a><br/>Synced 6 W&B file(s), 0 media file(s), 2179 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\tutorial_exps\500-epochs-batch1\20240808_115501\vis_data\wandb\run-20240808_115509-pqecpje0\logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
config = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch1.py'

# %%
from glob import glob
ckpt = 'tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth'

# %%
ckpt_b  = 'tutorial_exps/500-epochs-batch1/best_coco_bbox_mAP_epoch_345.pth'

# %% [markdown]
# ## Test HTC on best checkpointfile and save the painted images for future visualization

# %%
# !python mmdetection/tools/test.py {config} {ckpt} --show-dir output/segm
# Out:
# 08/08 14:15:41 - mmengine -
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# INFO
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
#  -
# wandb:  $ pip install wandb --upgrade
# ------------------------------------------------------------
# System environment:
# wandb: Tracking run with wandb version 0.17.5
#     sys.platform: win32
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch1\20240808_141535\vis_data\wandb\run-20240808_141544-4u31inqj
# wandb: Run `wandb offline` to turn off syncing.
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb: Syncing run fresh-rain-61
#     CUDA available: True
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     MUSA available: False
#     numpy_random_seed: 901198563
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/4u31inqj
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     GPU 0: NVIDIA RTX A4000
#   mask_preds = bboxes.new_tensor(mask_preds)
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#   warnings.warn(
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#     GCC: n/a
#   warnings.warn(
#     PyTorch: 2.3.1
# wandb: - 9.688 MB of 9.688 MB uploaded (9.534 MB deduped)
#     PyTorch compiling details: PyTorch built with:
# wandb: \ 9.688 MB of 9.688 MB uploaded (9.534 MB deduped)
#   - C++ Version: 201703
# wandb: | 9.721 MB of 9.721 MB uploaded (9.534 MB deduped)
#   - MSVC 192930154
# wandb:
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
# wandb: W&B sync reduced upload amount by 98.1%
#   - OpenMP 2019
# wandb:  View run fresh-rain-61 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/4u31inqj
#   - LAPACK is enabled (usually provided by MKL)
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#   - CPU capability usage: AVX2
# wandb: Synced 6 W&B file(s), 0 media file(s), 2179 artifact file(s) and 0 other file(s)
#   - CUDA Runtime 12.1
# wandb: Find logs at: .\tutorial_exps\500-epochs-batch1\20240808_141535\vis_data\wandb\run-20240808_141544-4u31inqj\logs
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 901198563
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/08 14:15:42 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(
#         draw=True, test_out_dir='output/segm', type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch1'
#
# 08/08 14:15:55 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/08 14:15:55 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth
# 08/08 14:15:56 - mmengine - INFO - Load checkpoint from tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth
# 08/08 14:16:26 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:16:26 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.088 | 0.113  | 0.106  | 0.074 | 0.85  | nan   |
# | TansitionalMixing    | 0.144 | 0.216  | 0.182  | 0.157 | nan   | nan   |
# | DiffusiveMixing      | 0.044 | 0.095  | 0.037  | 0.045 | nan   | nan   |
# | spray                | 0.9   | 1.0    | 1.0    | nan   | nan   | 0.9   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/08 14:16:26 - mmengine - INFO - bbox_mAP_copypaste: 0.294 0.356 0.331 0.092 0.850 0.900
# 08/08 14:16:26 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:16:26 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.086 | 0.114  | 0.114  | 0.071 | 0.8   | nan   |
# | TansitionalMixing    | 0.142 | 0.22   | 0.181  | 0.154 | nan   | nan   |
# | DiffusiveMixing      | 0.038 | 0.087  | 0.033  | 0.039 | nan   | nan   |
# | spray                | 0.9   | 1.0    | 1.0    | nan   | nan   | 0.9   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/08 14:16:26 - mmengine - INFO - segm_mAP_copypaste: 0.292 0.355 0.332 0.088 0.800 0.900
# 08/08 14:16:26 - mmengine - INFO - Epoch(test) [8/8]    coco/ClassicalEvaporation_precision: 0.0860  coco/TansitionalMixing_precision: 0.1420  coco/DiffusiveMixing_precision: 0.0380  coco/spray_precision: 0.9000  coco/bbox_mAP: 0.2940  coco/bbox_mAP_50: 0.3560  coco/bbox_mAP_75: 0.3310  coco/bbox_mAP_s: 0.0920  coco/bbox_mAP_m: 0.8500  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2920  coco/segm_mAP_50: 0.3550  coco/segm_mAP_75: 0.3320  coco/segm_mAP_s: 0.0880  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.9000  data_time: 2.7714  time: 3.7082

# %% [markdown]
# ## Inference on trained Model

# %%
import os
from mmdet.apis import init_detector, inference_detector
import mmcv
import cv2
from mmdet.registry import VISUALIZERS

model = init_detector(config, ckpt, device='cuda:0')

image_folder = 'mmdetection/data/saf22/test/'
output_folder = 'tutorial_exps/500-epochs-batch1/inference-results/segm'
image_paths = [os.path.join(image_folder, img_name) for img_name in os.listdir(image_folder) if img_name.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'tiff'))]

visualizer = VISUALIZERS.build(model.cfg.visualizer)
visualizer.dataset_meta = model.dataset_meta
# Out:
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\utils\manager.py:113: UserWarning: <class 'mmdet.visualization.local_visualizer.DetLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(

# %%
for img_path in image_paths:
    img = mmcv.imread(img_path)
    if img is None:
        print(f"Failed to read image at {img_path}")
        continue
    
    new_result_segm = inference_detector(model, img)
    os.makedirs(output_folder, exist_ok=True)
    output_file = os.path.join(output_folder, os.path.basename(img_path))
    
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    visualizer.add_datasample(
        'new_result_segm',
        img_rgb,
        data_sample=new_result_segm,        draw_gt=None,
        wait_time=0,
        out_file=output_file
    )

# %% [markdown]
# ## Save results.pkl

# %%
# !python mmdetection/tools/test.py {config} {ckpt}  --out ./results/500-epochs-batch1/results.pkl
# Out:
# 08/08 14:19:42 - mmengine -
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# INFO -
# ------------------------------------------------------------
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# System environment:
# wandb:  $ pip install wandb --upgrade
#     sys.platform: win32
# wandb: Tracking run with wandb version 0.17.5
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch1\20240808_141937\vis_data\wandb\run-20240808_141944-ouoypzfo
# wandb: Run `wandb offline` to turn off syncing.
#     CUDA available: True
#     MUSA available: False
# wandb: Syncing run breezy-terrain-62
#     numpy_random_seed: 248600946
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     GPU 0: NVIDIA RTX A4000
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ouoypzfo
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#   mask_preds = bboxes.new_tensor(mask_preds)
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# wandb: - 9.706 MB of 9.706 MB uploaded (9.686 MB deduped)
#     GCC: n/a
# wandb: \ 9.706 MB of 9.706 MB uploaded (9.686 MB deduped)
#     PyTorch: 2.3.1
# wandb: | 9.706 MB of 9.739 MB uploaded (9.686 MB deduped)
#     PyTorch compiling details: PyTorch built with:
# wandb: / 9.706 MB of 9.739 MB uploaded (9.686 MB deduped)
#   - C++ Version: 201703
# wandb: - 9.739 MB of 9.739 MB uploaded (9.686 MB deduped)
#   - MSVC 192930154
# wandb:
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# wandb: W&B sync reduced upload amount by 99.5%
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
# wandb:  View run breezy-terrain-62 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ouoypzfo
#   - OpenMP 2019
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#   - LAPACK is enabled (usually provided by MKL)
# wandb: Synced 6 W&B file(s), 0 media file(s), 2180 artifact file(s) and 0 other file(s)
#   - CPU capability usage: AVX2
# wandb: Find logs at: .\tutorial_exps\500-epochs-batch1\20240808_141937\vis_data\wandb\run-20240808_141944-ouoypzfo\logs
#   - CUDA Runtime 12.1
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 248600946
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/08 14:19:42 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch1'
#
# 08/08 14:19:55 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/08 14:19:55 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/08 14:19:55 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth
# 08/08 14:19:56 - mmengine - INFO - Load checkpoint from tutorial_exps/500-epochs-batch1/best_coco_segm_mAP_epoch_261.pth
# 08/08 14:20:13 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:20:13 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.088 | 0.113  | 0.106  | 0.074 | 0.85  | nan   |
# | TansitionalMixing    | 0.144 | 0.216  | 0.182  | 0.157 | nan   | nan   |
# | DiffusiveMixing      | 0.044 | 0.095  | 0.037  | 0.045 | nan   | nan   |
# | spray                | 0.9   | 1.0    | 1.0    | nan   | nan   | 0.9   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/08 14:20:13 - mmengine - INFO - bbox_mAP_copypaste: 0.294 0.356 0.331 0.092 0.850 0.900
# 08/08 14:20:13 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:20:13 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.086 | 0.114  | 0.114  | 0.071 | 0.8   | nan   |
# | TansitionalMixing    | 0.142 | 0.22   | 0.181  | 0.154 | nan   | nan   |
# | DiffusiveMixing      | 0.038 | 0.087  | 0.033  | 0.039 | nan   | nan   |
# | spray                | 0.9   | 1.0    | 1.0    | nan   | nan   | 0.9   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/08 14:20:13 - mmengine - INFO - segm_mAP_copypaste: 0.292 0.355 0.332 0.088 0.800 0.900
# 08/08 14:20:13 - mmengine - INFO - Results has been saved to ./results/500-epochs-batch1/results.pkl.
# 08/08 14:20:13 - mmengine - INFO - Epoch(test) [8/8]    coco/ClassicalEvaporation_precision: 0.0860  coco/TansitionalMixing_precision: 0.1420  coco/DiffusiveMixing_precision: 0.0380  coco/spray_precision: 0.9000  coco/bbox_mAP: 0.2940  coco/bbox_mAP_50: 0.3560  coco/bbox_mAP_75: 0.3310  coco/bbox_mAP_s: 0.0920  coco/bbox_mAP_m: 0.8500  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2920  coco/segm_mAP_50: 0.3550  coco/segm_mAP_75: 0.3320  coco/segm_mAP_s: 0.0880  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.9000  data_time: 1.0698  time: 2.1363

# %% [markdown]
# The masks are represented as a tensor of boolean values, these boolean tensors represent the masks directly, rather than as coordinates.

# %% [markdown]
# ## Log Analysis

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.1
# Summary: Python plotting package
# Home-page:
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
#         =========================================================
#
#         1. This LICENSE AGREEMENT is between the Matplotlib Development Team
#         ("MDT"), and the Individual or Organization ("Licensee") accessing and
#         otherwise using matplotlib software in source or binary form and its
#         associated documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, MDT
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that MDT's
#         License Agreement and MDT's notice of copyright, i.e., "Copyright (c)
#         2012- Matplotlib Development Team; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib .
#
#         4. MDT is making matplotlib available to Licensee on an "AS
#         IS" basis.  MDT MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, MDT MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. MDT SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between MDT and
#         Licensee.  This License Agreement does not grant permission to use MDT
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib ,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
#
#         License agreement for matplotlib versions prior to 1.3.0
#         ========================================================
#
#         1. This LICENSE AGREEMENT is between John D. Hunter ("JDH"), and the
#         Individual or Organization ("Licensee") accessing and otherwise using
#         matplotlib software in source or binary form and its associated
#         documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, JDH
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that JDH's
#         License Agreement and JDH's notice of copyright, i.e., "Copyright (c)
#         2002-2011 John D. Hunter; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib  or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib.
#
#         4. JDH is making matplotlib  available to Licensee on an "AS
#         IS" basis.  JDH MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, JDH MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. JDH SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between JDH and
#         Licensee.  This License Agreement does not grant permission to use JDH
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
# Location: c:\users\ja683\appdata\roaming\python\python310\site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: mmdet, mmengine, pycocotools, seaborn

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib
print(matplotlib.rcParams['backend'])
# Out:
# module://matplotlib_inline.backend_inline

# %%
json_log = 'tutorial_exps/500-epochs-batch1/20240808_115501/vis_data/20240808_115501.json'

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py plot_curve \
  --keys loss \
  --title "Training Metrics" \
  --legend "Loss" \
  --backend TkAgg \
  --style darkgrid \
  --out tutorial_exps/500-epochs-batch1/20240808_115501/training_curves.png \
  {json_log}
# Out:
# plot curve of tutorial_exps/500-epochs-batch1/20240808_115501/vis_data/20240808_115501.json, metric is loss
# save curve to: tutorial_exps/500-epochs-batch1/20240808_115501/training_curves.png

# %% [markdown]
# ### Compute the average training speed.

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py cal_train_time {json_log} --include-outliers
# Out:
# -----Analyze train time of tutorial_exps/500-epochs-batch1/20240808_115501/vis_data/20240808_115501.json-----
# slowest epoch 1, average time is 3.3532 s/iter
# fastest epoch 2, average time is 0.3356 s/iter
# time std over epochs is 0.1333
# average iter time: 0.3832 s/iter

# %% [markdown]
# ## Result Analysis

# %%
# !python mmdetection/tools/analysis_tools/analyze_results.py \
       {config} \
       ./results/500-epochs-batch1/results.pkl \
       ./results/500-epochs-batch1/vis_data \
       --show
# [Optional] Finish the wandb run
wandb.finish()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# loading annotations into memory...
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# Done (t=0.02s)
# creating index...
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.5
# index created!
# 08/08 14:24:14 - mmengine -
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\results\500-epochs-batch1\vis_data\20240808_142407\vis_data\wandb\run-20240808_142416-uryzcehi
# INFO
# wandb: Run `wandb offline` to turn off syncing.
#  -
# wandb: Syncing run polished-sun-63
# ------------------------------------------------------------
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
# System environment:
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/uryzcehi
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1927330238
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
#     GCC: n/a
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1927330238
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/08 14:24:14 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0025, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.0025,
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './results/500-epochs-batch1/vis_data'
#
# 08/08 14:24:26 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/08 14:24:26 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [                                                  ] 0/8, elapsed: 0s, ETA:
# [>>>>                               ] 1/8, 0.1 task/s, elapsed: 8s, ETA:    58s
# [>>>>>>>>                          ] 2/8, 0.1 task/s, elapsed: 15s, ETA:    44s
# [>>>>>>>>>>>>                      ] 3/8, 0.1 task/s, elapsed: 25s, ETA:    42s
# [>>>>>>>>>>>>>>>>>                 ] 4/8, 0.1 task/s, elapsed: 33s, ETA:    33s
# [>>>>>>>>>>>>>>>>>>>>>             ] 5/8, 0.1 task/s, elapsed: 38s, ETA:    23s
# [>>>>>>>>>>>>>>>>>>>>>>>>>         ] 6/8, 0.1 task/s, elapsed: 42s, ETA:    14s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>     ] 7/8, 0.1 task/s, elapsed: 51s, ETA:     7s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 8/8, 0.1 task/s, elapsed: 55s, ETA:     0sImage shape: (1536, 2072)
# Resized masks shape: (38, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (7, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (12, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (7, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (85, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (44, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (60, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (40, 1536, 2072)

# %% [markdown]
# ## Confusion Matrix

# %%
# [Optional] Finish the wandb run
wandb.finish()
# !python mmdetection/tools/analysis_tools/confusion_matrix.py \
        {config} \
        results/500-epochs-batch1/results.pkl \
        results/500-epochs-batch1 --show
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [                                                  ] 0/8, elapsed: 0s, ETA:
# [>>>>                             ] 1/8, 334.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>                         ] 2/8, 501.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>                     ] 3/8, 602.0 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>                 ] 4/8, 668.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>             ] 5/8, 835.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>        ] 6/8, 1003.1 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 7/8, 1003.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 8/8, 1146.7 task/s, elapsed: 0s, ETA:     0sFigure(1500x956.25)

# %%
# !pip install scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: seaborn in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from scikit-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Eval Metric from results.pkl file

# %%
# !python mmdetection/tools/analysis_tools/eval_metric.py \
        {config} \
        results/500-epochs-batch1/results.pkl
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/08 14:28:49 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.092
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.362
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.175
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:28:49 - mmengine - INFO - bbox_mAP_copypaste: 0.294 0.356 0.331 0.092 0.850 0.900
# 08/08 14:28:49 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.355
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.357
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.168
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/08 14:28:49 - mmengine - INFO - segm_mAP_copypaste: 0.292 0.355 0.332 0.088 0.800 0.900
# {'coco/bbox_mAP': 0.294, 'coco/bbox_mAP_50': 0.356, 'coco/bbox_mAP_75': 0.331, 'coco/bbox_mAP_s': 0.092, 'coco/bbox_mAP_m': 0.85, 'coco/bbox_mAP_l': 0.9, 'coco/segm_mAP': 0.292, 'coco/segm_mAP_50': 0.355, 'coco/segm_mAP_75': 0.332, 'coco/segm_mAP_s': 0.088, 'coco/segm_mAP_m': 0.8, 'coco/segm_mAP_l': 0.9}
