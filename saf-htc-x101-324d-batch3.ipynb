# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# PyTorch version: 2.3.1
# CUDA available: True
# CUDA version: 12.1

# %%
# Check mmengine installation
import mmengine
print(f"MMengine: {mmengine.__version__}")

# Check Openmim installation
from importlib.metadata import version
print(f"Openmim: {version('openmim')}")

# Check mmcv installation
import mmcv
print("mmcv:",mmcv.__version__)

# Check MMDetection installation
import mmdet
print("mmdetection:",mmdet.__version__)
# Out:
# MMengine: 0.10.4
# Openmim: 0.3.9
# mmcv: 2.0.0rc4
# mmdetection: 3.3.0

# %%
import mmcv
import mmengine
from mmdet.apis import init_detector, inference_detector
from mmdet.utils import register_all_modules
# Choose to use a config and initialize the detector
config_file = 'mmdetection/configs/htc/htc_res2net-101_fpn_20e_coco.py'
# Setup a checkpoint file to load
checkpoint_file = 'mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth'

# register all modules in mmdet into the registries
register_all_modules()

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')  # or device='cuda:0'
# Out:
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias

# %%
from pycocotools.coco import COCO

# Path to load the COCO annotation file
annotation_file = 'mmdetection/data/saf22/train/annotation_coco.json'

# Initialise the COCO object
coco = COCO(annotation_file)

# Get all category tags and corresponding category IDs
categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}

# Print all category IDs and corresponding category names
for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Category ID: 1, Category Name: ClassicalEvaporation
# Category ID: 2, Category Name: TansitionalMixing
# Category ID: 3, Category Name: DiffusiveMixing
# Category ID: 4, Category Name: spray

# %% [markdown]
# ### Wandb integration

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# True

# %%
# Weights and Biases version
print(wandb.__version__)
# Out:
# 0.17.5

# %% [markdown]
# ## Hypertuning the Parameters

# %%
from mmengine.runner import set_random_seed
from mmengine import Config
import random
import numpy as np
import matplotlib.pyplot as plt
from mmdet.visualization import DetLocalVisualizer
import os
import cv2

# %%
cfg = Config.fromfile('mmdetection/configs/htc/htc_res2net-101_fpn_20e_coco.py')

# Modify dataset classes and color
cfg.metainfo = {
    'classes': ('ClassicalEvaporation', 'TansitionalMixing', 'DiffusiveMixing', 'spray'),
    'palette': [
        (13,24,103), (167,13,13), (91,117,249), (203,173,55),
    ]
}

# Modify dataset type and path
cfg.data_root = 'mmdetection/data/saf22/'

cfg.train_dataloader.dataset.ann_file = 'train/annotation_coco.json'
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = {'img': 'train/'}
cfg.train_dataloader.dataset.metainfo = cfg.metainfo

cfg.val_dataloader.dataset.ann_file = 'val/annotation_coco.json'
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = {'img': 'val/'}
cfg.val_dataloader.dataset.metainfo = cfg.metainfo

cfg.test_dataloader = cfg.val_dataloader

# Modify metric config
cfg.val_evaluator.ann_file = f'{cfg.data_root}val/annotation_coco.json'
cfg.test_evaluator = cfg.val_evaluator

#############################################################################################

# Modify num classes of the model in box head and mask head
if isinstance(cfg.model.roi_head.bbox_head, list):
    for head in cfg.model.roi_head.bbox_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.bbox_head.num_classes = 4

if isinstance(cfg.model.roi_head.mask_head, list):
    for head in cfg.model.roi_head.mask_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.mask_head.num_classes = 4

#############################################################################################

# Configure checkpoint saving
cfg.default_hooks.checkpoint = dict(
    type='CheckpointHook',
    interval=1,
    save_optimizer=True,
    save_best = ['coco/bbox_mAP','coco/segm_mAP'],
    save_last=True,
    rule='greater',
    max_keep_ckpts=1
)

cfg.test_evaluator.update(dict(classwise=True))

# Use the pre-trained HTC model
cfg.load_from = 'mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth'

# Set up working dir to save files and logs.
cfg.work_dir = './tutorial_exps/500-epochs-batch3'

# Set the number of epochs
cfg.train_cfg.max_epochs = 500

#############################################################################################

# Set neck as FPN_CARAFE
cfg.model.neck.type = 'FPN_CARAFE'

##################################################################################################

# Set the evaluation interval to reduce the evaluation times
cfg.train_cfg.val_interval = 3

# Set the checkpoint saving interval to reduce the storage cost
cfg.default_hooks.checkpoint.interval = 3

# Adjust learning rate for single GPU
cfg.optim_wrapper.optimizer.lr = 0.03 / 8

# Set logging interval
cfg.default_hooks.logger.interval = 10

# Set seed for reproducibility
set_random_seed(0, deterministic=False)

# Use Tensorboard to log the training process
cfg.visualizer.vis_backends.append({"type": 'TensorboardVisBackend'})

# Configure WandB logger
cfg.visualizer.vis_backends.append(dict(type='WandbVisBackend', init_kwargs=dict(
    project='SAF_Project',
    entity='ahluwaliajyoti50-university-of-sussex',
    config={
        'learning_rate': cfg.optim_wrapper.optimizer.lr,
        'architecture': 'htc_res2net',
        'dataset': 'SAF22',
        'neck': cfg.model.neck.type,
        'epochs': cfg.train_cfg.max_epochs,
        'backbone': cfg.model.backbone.type,
        'batch_size': cfg.train_dataloader.batch_size,
        'filter': cfg.train_dataloader.dataset.filter_cfg.min_size,
        'optimizer': cfg.optim_wrapper.optimizer.type,
        'classes': cfg.metainfo['classes'],
        'seed': 0,
    }
)))

# Save the modified config
config = 'mmdetection/configs/htc/htc_res2net-101_fpn_20e_coco_saf-500-batch3.py'
with open(config, 'w') as f:
    f.write(cfg.pretty_text)

# %run mmdetection/tools/train.py {config}
# [Optional] Finish the wandb run
wandb.finish()
# Out:
# 08/14 21:14:30 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 209652396
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#     MSVC: n/a, reason: fileno
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 209652396
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/14 21:14:30 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# lr_config = dict(step=[
#     16,
#     19,
# ])
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=26,
#         depth=101,
#         frozen_stages=1,
#         init_cfg=dict(
#             checkpoint='open-mmlab://res2net101_v1d_26w_4s',
#             type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         scales=4,
#         style='pytorch',
#         type='Res2Net'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00375, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# runner = dict(max_epochs=20, type='EpochBasedRunner')
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='htc_res2net',
#                     backbone='Res2Net',
#                     batch_size=2,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     filter=32,
#                     learning_rate=0.00375,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch3'
# wandb version 0.17.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\20240814_211422\vis_data\wandb\run-20240814_211431-ds0d1hyx</code>
# Syncing run <strong><a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ds0d1hyx' target="_blank">zesty-smoke-94</a></strong> to <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a>
#  View run at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ds0d1hyx' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ds0d1hyx</a>
# 08/14 21:14:46 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/14 21:14:46 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# 08/14 21:14:52 - mmengine - INFO - load model from: open-mmlab://res2net101_v1d_26w_4s
# 08/14 21:14:52 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://res2net101_v1d_26w_4s
# 08/14 21:14:53 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias
#
# missing keys in source state_dict: neck.lateral_convs.4.conv.weight, neck.lateral_convs.4.conv.bias, neck.fpn_convs.4.conv.weight, neck.fpn_convs.4.conv.bias, neck.upsample_modules.0.channel_compressor.weight, neck.upsample_modules.0.channel_compressor.bias, neck.upsample_modules.0.content_encoder.weight, neck.upsample_modules.0.content_encoder.bias, neck.upsample_modules.1.channel_compressor.weight, neck.upsample_modules.1.channel_compressor.bias, neck.upsample_modules.1.content_encoder.weight, neck.upsample_modules.1.content_encoder.bias, neck.upsample_modules.2.channel_compressor.weight, neck.upsample_modules.2.channel_compressor.bias, neck.upsample_modules.2.content_encoder.weight, neck.upsample_modules.2.content_encoder.bias, neck.upsample_modules.3.channel_compressor.weight, neck.upsample_modules.3.channel_compressor.bias, neck.upsample_modules.3.content_encoder.weight, neck.upsample_modules.3.content_encoder.bias
#
# 08/14 21:14:53 - mmengine - INFO - Load checkpoint from mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth
# 08/14 21:14:53 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/14 21:14:53 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/14 21:14:53 - mmengine - INFO - Checkpoints will be saved to C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3.
# 08/14 21:16:48 - mmengine - INFO - Epoch(train)   [1][10/18]  lr: 7.1318e-05  eta: 1 day, 4:44:10  time: 11.5073  data_time: 2.6024  memory: 6817  loss: 3.9944  loss_rpn_cls: 0.0027  loss_rpn_bbox: 0.0020  s0.loss_cls: 1.5775  s0.acc: 73.7305  s0.loss_bbox: 0.0041  s0.loss_mask: 0.7123  s1.loss_cls: 0.7659  s1.acc: 83.3984  s1.loss_bbox: 0.0022  s1.loss_mask: 0.3343  s2.loss_cls: 0.4055  s2.acc: 29.2969  s2.loss_bbox: 0.0014  s2.loss_mask: 0.1866
# 08/14 21:18:27 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:19:59 - mmengine - INFO - Epoch(train)   [2][10/18]  lr: 2.0645e-04  eta: 1 day, 3:10:16  time: 10.9024  data_time: 0.9896  memory: 7618  loss: 3.3264  loss_rpn_cls: 0.0477  loss_rpn_bbox: 0.0057  s0.loss_cls: 1.1168  s0.acc: 94.9219  s0.loss_bbox: 0.0049  s0.loss_mask: 0.7014  s1.loss_cls: 0.5917  s1.acc: 94.9219  s1.loss_bbox: 0.0025  s1.loss_mask: 0.3298  s2.loss_cls: 0.3440  s2.acc: 95.2148  s2.loss_bbox: 0.0011  s2.loss_mask: 0.1808
# 08/14 21:21:08 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:22:01 - mmengine - INFO - Epoch(train)   [3][10/18]  lr: 3.4159e-04  eta: 23:08:33  time: 9.3047  data_time: 0.6259  memory: 7472  loss: 2.7175  loss_rpn_cls: 0.0321  loss_rpn_bbox: 0.0042  s0.loss_cls: 0.8083  s0.acc: 96.6797  s0.loss_bbox: 0.0081  s0.loss_mask: 0.6891  s1.loss_cls: 0.4246  s1.acc: 96.6797  s1.loss_bbox: 0.0039  s1.loss_mask: 0.3207  s2.loss_cls: 0.2513  s2.acc: 96.7773  s2.loss_bbox: 0.0013  s2.loss_mask: 0.1739
# 08/14 21:22:42 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:22:42 - mmengine - INFO - Saving checkpoint at 3 epochs
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 08/14 21:25:31 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.006
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.000
# 08/14 21:25:31 - mmengine - INFO - bbox_mAP_copypaste: 0.000 0.000 0.000 0.000 0.005 0.000
# 08/14 21:25:31 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.005
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.005
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.000
# 08/14 21:25:31 - mmengine - INFO - segm_mAP_copypaste: 0.000 0.000 0.000 0.000 0.005 0.000
# 08/14 21:25:31 - mmengine - INFO - Epoch(val) [3][8/8]    coco/bbox_mAP: 0.0000  coco/bbox_mAP_50: 0.0000  coco/bbox_mAP_75: 0.0000  coco/bbox_mAP_s: 0.0000  coco/bbox_mAP_m: 0.0050  coco/bbox_mAP_l: 0.0000  coco/segm_mAP: 0.0000  coco/segm_mAP_50: 0.0000  coco/segm_mAP_75: 0.0000  coco/segm_mAP_s: 0.0000  coco/segm_mAP_m: 0.0050  coco/segm_mAP_l: 0.0000  data_time: 1.3099  time: 20.7394
# 08/14 21:25:33 - mmengine - INFO - The best checkpoint with 0.0000 coco/bbox_mAP at 3 epoch is saved to best_coco_bbox_mAP_epoch_3.pth.
# 08/14 21:25:34 - mmengine - INFO - The best checkpoint with 0.0000 coco/segm_mAP at 3 epoch is saved to best_coco_segm_mAP_epoch_3.pth.
# 08/14 21:26:52 - mmengine - INFO - Epoch(train)   [4][10/18]  lr: 4.7672e-04  eta: 21:02:35  time: 7.8056  data_time: 0.0758  memory: 7542  loss: 1.9423  loss_rpn_cls: 0.0308  loss_rpn_bbox: 0.0044  s0.loss_cls: 0.4091  s0.acc: 95.4102  s0.loss_bbox: 0.0103  s0.loss_mask: 0.6547  s1.loss_cls: 0.2291  s1.acc: 95.4102  s1.loss_bbox: 0.0061  s1.loss_mask: 0.2950  s2.loss_cls: 0.1446  s2.acc: 95.4102  s2.loss_bbox: 0.0025  s2.loss_mask: 0.1557
# 08/14 21:27:52 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:28:56 - mmengine - INFO - Epoch(train)   [5][10/18]  lr: 6.1186e-04  eta: 20:08:36  time: 6.4834  data_time: 0.0609  memory: 7925  loss: 1.4986  loss_rpn_cls: 0.0130  loss_rpn_bbox: 0.0027  s0.loss_cls: 0.2610  s0.acc: 93.5547  s0.loss_bbox: 0.0132  s0.loss_mask: 0.5920  s1.loss_cls: 0.1354  s1.acc: 93.8477  s1.loss_bbox: 0.0093  s1.loss_mask: 0.2600  s2.loss_cls: 0.0749  s2.acc: 95.5078  s2.loss_bbox: 0.0039  s2.loss_mask: 0.1331
# 08/14 21:29:32 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:29:39 - mmengine - INFO - Epoch(train)   [6][10/18]  lr: 7.4699e-04  eta: 17:33:48  time: 5.2559  data_time: 0.0689  memory: 8063  loss: 1.3086  loss_rpn_cls: 0.0110  loss_rpn_bbox: 0.0025  s0.loss_cls: 0.2175  s0.acc: 96.0938  s0.loss_bbox: 0.0120  s0.loss_mask: 0.5148  s1.loss_cls: 0.1256  s1.acc: 95.8008  s1.loss_bbox: 0.0118  s1.loss_mask: 0.2259  s2.loss_cls: 0.0684  s2.acc: 95.9961  s2.loss_bbox: 0.0059  s2.loss_mask: 0.1132
# 08/14 21:29:44 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:29:44 - mmengine - INFO - Saving checkpoint at 6 epochs
# 08/14 21:29:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.028
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.015
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.451
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.135
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.029
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.433
# 08/14 21:29:53 - mmengine - INFO - bbox_mAP_copypaste: 0.028 0.057 0.018 0.015 0.451 0.350
# 08/14 21:29:53 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.031
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.073
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.019
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.650
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.316
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.133
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.048
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.367
# 08/14 21:29:53 - mmengine - INFO - segm_mAP_copypaste: 0.031 0.073 0.019 0.021 0.650 0.316
# 08/14 21:29:53 - mmengine - INFO - Epoch(val) [6][8/8]    coco/bbox_mAP: 0.0280  coco/bbox_mAP_50: 0.0570  coco/bbox_mAP_75: 0.0180  coco/bbox_mAP_s: 0.0150  coco/bbox_mAP_m: 0.4510  coco/bbox_mAP_l: 0.3500  coco/segm_mAP: 0.0310  coco/segm_mAP_50: 0.0730  coco/segm_mAP_75: 0.0190  coco/segm_mAP_s: 0.0210  coco/segm_mAP_m: 0.6500  coco/segm_mAP_l: 0.3160  data_time: 0.1291  time: 2.7845
# 08/14 21:29:53 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\best_coco_bbox_mAP_epoch_3.pth is removed
# 08/14 21:29:55 - mmengine - INFO - The best checkpoint with 0.0280 coco/bbox_mAP at 6 epoch is saved to best_coco_bbox_mAP_epoch_6.pth.
# 08/14 21:29:55 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\best_coco_segm_mAP_epoch_3.pth is removed
# 08/14 21:29:56 - mmengine - INFO - The best checkpoint with 0.0310 coco/segm_mAP at 6 epoch is saved to best_coco_segm_mAP_epoch_6.pth.
# 08/14 21:30:06 - mmengine - INFO - Epoch(train)   [7][10/18]  lr: 8.8213e-04  eta: 15:05:43  time: 2.9030  data_time: 0.0616  memory: 7950  loss: 1.1703  loss_rpn_cls: 0.0077  loss_rpn_bbox: 0.0021  s0.loss_cls: 0.1866  s0.acc: 92.0898  s0.loss_bbox: 0.0121  s0.loss_mask: 0.4398  s1.loss_cls: 0.1205  s1.acc: 88.4766  s1.loss_bbox: 0.0181  s1.loss_mask: 0.2015  s2.loss_cls: 0.0691  s2.acc: 85.5469  s2.loss_bbox: 0.0108  s2.loss_mask: 0.1022
# 08/14 21:30:12 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:30:19 - mmengine - INFO - Epoch(train)   [8][10/18]  lr: 1.0173e-03  eta: 13:17:40  time: 0.7855  data_time: 0.0647  memory: 8375  loss: 1.0216  loss_rpn_cls: 0.0047  loss_rpn_bbox: 0.0019  s0.loss_cls: 0.1462  s0.acc: 96.1914  s0.loss_bbox: 0.0137  s0.loss_mask: 0.3742  s1.loss_cls: 0.1059  s1.acc: 95.3125  s1.loss_bbox: 0.0257  s1.loss_mask: 0.1760  s2.loss_cls: 0.0657  s2.acc: 94.9219  s2.loss_bbox: 0.0179  s2.loss_mask: 0.0896
# 08/14 21:30:24 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:30:31 - mmengine - INFO - Epoch(train)   [9][10/18]  lr: 1.1524e-04  eta: 11:54:35  time: 0.6713  data_time: 0.0587  memory: 8334  loss: 0.9153  loss_rpn_cls: 0.0034  loss_rpn_bbox: 0.0014  s0.loss_cls: 0.1221  s0.acc: 97.7539  s0.loss_bbox: 0.0147  s0.loss_mask: 0.3325  s1.loss_cls: 0.0914  s1.acc: 95.8984  s1.loss_bbox: 0.0285  s1.loss_mask: 0.1596  s2.loss_cls: 0.0600  s2.acc: 92.7734  s2.loss_bbox: 0.0214  s2.loss_mask: 0.0803
# 08/14 21:30:36 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:30:36 - mmengine - INFO - Saving checkpoint at 9 epochs
# 08/14 21:30:44 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.241
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.292
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.267
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.027
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.889
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.286
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.072
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 21:30:44 - mmengine - INFO - bbox_mAP_copypaste: 0.241 0.292 0.267 0.027 0.400 0.889
# 08/14 21:30:44 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.222
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.300
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.789
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.283
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.102
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.800
# 08/14 21:30:45 - mmengine - INFO - segm_mAP_copypaste: 0.222 0.300 0.270 0.034 0.800 0.789
# 08/14 21:30:45 - mmengine - INFO - Epoch(val) [9][8/8]    coco/bbox_mAP: 0.2410  coco/bbox_mAP_50: 0.2920  coco/bbox_mAP_75: 0.2670  coco/bbox_mAP_s: 0.0270  coco/bbox_mAP_m: 0.4000  coco/bbox_mAP_l: 0.8890  coco/segm_mAP: 0.2220  coco/segm_mAP_50: 0.3000  coco/segm_mAP_75: 0.2700  coco/segm_mAP_s: 0.0340  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.7890  data_time: 0.1261  time: 0.6798
# 08/14 21:30:45 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\best_coco_bbox_mAP_epoch_6.pth is removed
# 08/14 21:30:46 - mmengine - INFO - The best checkpoint with 0.2410 coco/bbox_mAP at 9 epoch is saved to best_coco_bbox_mAP_epoch_9.pth.
# 08/14 21:30:46 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\best_coco_segm_mAP_epoch_6.pth is removed
# 08/14 21:30:48 - mmengine - INFO - The best checkpoint with 0.2220 coco/segm_mAP at 9 epoch is saved to best_coco_segm_mAP_epoch_9.pth.
# 08/14 21:30:58 - mmengine - INFO - Epoch(train)  [10][10/18]  lr: 1.2875e-04  eta: 10:49:16  time: 0.6835  data_time: 0.0672  memory: 8409  loss: 0.8438  loss_rpn_cls: 0.0018  loss_rpn_bbox: 0.0012  s0.loss_cls: 0.1083  s0.acc: 96.6797  s0.loss_bbox: 0.0133  s0.loss_mask: 0.3130  s1.loss_cls: 0.0788  s1.acc: 94.8242  s1.loss_bbox: 0.0249  s1.loss_mask: 0.1524  s2.loss_cls: 0.0528  s2.acc: 93.2617  s2.loss_bbox: 0.0217  s2.loss_mask: 0.0757
# 08/14 21:31:04 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 21:31:11 - mmengine - INFO - Epoch(train)  [11][10/18]  lr: 1.4227e-04  eta: 9:56:11  time: 0.6949  data_time: 0.0677  memory: 8494  loss: 0.8070  loss_rpn_cls: 0.0015  loss_rpn_bbox: 0.0011  s0.loss_cls: 0.1038  s0.acc: 98.8281  s0.loss_bbox: 0.0112  s0.loss_mask: 0.3027  s1.loss_cls: 0.0742  s1.acc: 98.2422  s1.loss_bbox: 0.0213  s1.loss_mask: 0.1475  s2.loss_cls: 0.0506  s2.acc: 97.2656  s2.loss_bbox: 0.0199  s2.loss_mask: 0.0732
# 08/14 21:31:16 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# ...
# 08/14 23:45:49 - mmengine - INFO - bbox_mAP_copypaste: 0.254 0.295 0.282 0.035 0.900 0.900
# 08/14 23:45:49 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 23:45:50 - mmengine - INFO - segm_mAP_copypaste: 0.239 0.303 0.279 0.033 0.850 0.844
# 08/14 23:45:50 - mmengine - INFO - Epoch(val) [495][8/8]    coco/bbox_mAP: 0.2540  coco/bbox_mAP_50: 0.2950  coco/bbox_mAP_75: 0.2820  coco/bbox_mAP_s: 0.0350  coco/bbox_mAP_m: 0.9000  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2390  coco/segm_mAP_50: 0.3030  coco/segm_mAP_75: 0.2790  coco/segm_mAP_s: 0.0330  coco/segm_mAP_m: 0.8500  coco/segm_mAP_l: 0.8440  data_time: 0.1644  time: 1.1624
# 08/14 23:45:57 - mmengine - INFO - Epoch(train) [496][10/18]  lr: 3.7500e-05  eta: 0:01:01  time: 0.6963  data_time: 0.0757  memory: 8414  loss: 0.4198  loss_rpn_cls: 0.0005  loss_rpn_bbox: 0.0003  s0.loss_cls: 0.0433  s0.acc: 96.8750  s0.loss_bbox: 0.0062  s0.loss_mask: 0.1719  s1.loss_cls: 0.0305  s1.acc: 95.7031  s1.loss_bbox: 0.0119  s1.loss_mask: 0.0812  s2.loss_cls: 0.0208  s2.acc: 94.7266  s2.loss_bbox: 0.0130  s2.loss_mask: 0.0402
# 08/14 23:46:02 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 23:46:09 - mmengine - INFO - Epoch(train) [497][10/18]  lr: 3.7500e-05  eta: 0:00:47  time: 0.6963  data_time: 0.0761  memory: 8594  loss: 0.4192  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0003  s0.loss_cls: 0.0438  s0.acc: 98.5352  s0.loss_bbox: 0.0062  s0.loss_mask: 0.1716  s1.loss_cls: 0.0307  s1.acc: 97.8516  s1.loss_bbox: 0.0118  s1.loss_mask: 0.0810  s2.loss_cls: 0.0208  s2.acc: 97.5586  s2.loss_bbox: 0.0128  s2.loss_mask: 0.0400
# 08/14 23:46:14 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 23:46:21 - mmengine - INFO - Epoch(train) [498][10/18]  lr: 3.7500e-05  eta: 0:00:33  time: 0.6855  data_time: 0.0734  memory: 8314  loss: 0.4105  loss_rpn_cls: 0.0003  loss_rpn_bbox: 0.0003  s0.loss_cls: 0.0415  s0.acc: 97.6562  s0.loss_bbox: 0.0057  s0.loss_mask: 0.1703  s1.loss_cls: 0.0297  s1.acc: 97.1680  s1.loss_bbox: 0.0109  s1.loss_mask: 0.0804  s2.loss_cls: 0.0202  s2.acc: 96.6634  s2.loss_bbox: 0.0114  s2.loss_mask: 0.0398
# 08/14 23:46:26 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 23:46:26 - mmengine - INFO - Saving checkpoint at 498 epochs
# 08/14 23:46:39 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.06s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.282
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.064
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 23:46:39 - mmengine - INFO - bbox_mAP_copypaste: 0.254 0.296 0.282 0.035 0.900 0.900
# 08/14 23:46:39 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.240
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.304
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.277
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.034
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 23:46:40 - mmengine - INFO - segm_mAP_copypaste: 0.240 0.304 0.277 0.034 0.850 0.844
# 08/14 23:46:40 - mmengine - INFO - Epoch(val) [498][8/8]    coco/bbox_mAP: 0.2540  coco/bbox_mAP_50: 0.2960  coco/bbox_mAP_75: 0.2820  coco/bbox_mAP_s: 0.0350  coco/bbox_mAP_m: 0.9000  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2400  coco/segm_mAP_50: 0.3040  coco/segm_mAP_75: 0.2770  coco/segm_mAP_s: 0.0340  coco/segm_mAP_m: 0.8500  coco/segm_mAP_l: 0.8440  data_time: 0.1634  time: 1.1259
# 08/14 23:46:47 - mmengine - INFO - Epoch(train) [499][10/18]  lr: 3.7500e-05  eta: 0:00:20  time: 0.6709  data_time: 0.0645  memory: 8237  loss: 0.4113  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0003  s0.loss_cls: 0.0407  s0.acc: 98.6328  s0.loss_bbox: 0.0057  s0.loss_mask: 0.1701  s1.loss_cls: 0.0296  s1.acc: 98.9258  s1.loss_bbox: 0.0115  s1.loss_mask: 0.0805  s2.loss_cls: 0.0200  s2.acc: 98.9258  s2.loss_bbox: 0.0125  s2.loss_mask: 0.0400
# 08/14 23:46:52 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 23:46:59 - mmengine - INFO - Epoch(train) [500][10/18]  lr: 3.7500e-05  eta: 0:00:06  time: 0.6791  data_time: 0.0693  memory: 8430  loss: 0.4142  loss_rpn_cls: 0.0004  loss_rpn_bbox: 0.0003  s0.loss_cls: 0.0410  s0.acc: 98.2422  s0.loss_bbox: 0.0058  s0.loss_mask: 0.1698  s1.loss_cls: 0.0303  s1.acc: 97.4609  s1.loss_bbox: 0.0122  s1.loss_mask: 0.0806  s2.loss_cls: 0.0207  s2.acc: 97.0703  s2.loss_bbox: 0.0129  s2.loss_mask: 0.0402
# 08/14 23:47:04 - mmengine - INFO - Exp name: htc_res2net-101_fpn_20e_coco_saf-500-batch3_20240814_211422
# 08/14 23:47:04 - mmengine - INFO - Saving checkpoint at 500 epochs
# 08/14 23:47:17 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.05s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.254
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.294
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.279
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 23:47:17 - mmengine - INFO - bbox_mAP_copypaste: 0.254 0.294 0.278 0.035 0.900 0.900
# 08/14 23:47:17 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.239
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.278
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.032
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.060
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 23:47:17 - mmengine - INFO - segm_mAP_copypaste: 0.239 0.303 0.278 0.032 0.850 0.844
# 08/14 23:47:17 - mmengine - INFO - Epoch(val) [500][8/8]    coco/bbox_mAP: 0.2540  coco/bbox_mAP_50: 0.2940  coco/bbox_mAP_75: 0.2780  coco/bbox_mAP_s: 0.0350  coco/bbox_mAP_m: 0.9000  coco/bbox_mAP_l: 0.9000  coco/segm_mAP: 0.2390  coco/segm_mAP_50: 0.3030  coco/segm_mAP_75: 0.2780  coco/segm_mAP_s: 0.0320  coco/segm_mAP_m: 0.8500  coco/segm_mAP_l: 0.8440  data_time: 0.1653  time: 1.0908
# W&B sync reduced upload amount by 4.8%
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>▁▇▇▇▇▇██████████▇█████▇▇████████████████</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁███████████████████████████████████████</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁▇██████████████████████████████████████</td></tr><tr><td>coco/bbox_mAP_l</td><td>▁▇▇▇▇▇████▇▇▇█▇▇▇█████▇▇████████████████</td></tr><tr><td>coco/bbox_mAP_m</td><td>▁▂▂▂▄█▇▇▇▇██████████████████████████████</td></tr><tr><td>coco/bbox_mAP_s</td><td>▁▄▅▅▅▆▇▇▇▇████▇▇▇▇▇▇▆▆▇▇▆▇▇█▇▆▆▇▇▇▇▇▇▇█▇</td></tr><tr><td>coco/segm_mAP</td><td>▁▇▇▇▇███████████████████████████████████</td></tr><tr><td>coco/segm_mAP_50</td><td>▁█▇▇▇▇██████████████▇███████████████████</td></tr><tr><td>coco/segm_mAP_75</td><td>▁███████████████████████████████████████</td></tr><tr><td>coco/segm_mAP_l</td><td>▁███████████████████████████████████████</td></tr><tr><td>coco/segm_mAP_m</td><td>▁▅▅▇▇▇▇▇▇▇▇▇█▇███████▇▇████▇███▇█▇▇███▇▇</td></tr><tr><td>coco/segm_mAP_s</td><td>▁▄▅▅▅▆▆▆▇▇█▇█▇▆▆▇▆▆▅▃▄▅▅▄▅▅▅▅▄▄▅▄▄▄▄▅▄▅▅</td></tr><tr><td>data_time</td><td>▁▂▃▃▂▂▂▃▁▂▂▂▂▂▂▃▂▂▂▃▂▁▁▂▂▆▄▄▅▅▅▇▆█▆▆▇▇▇▇</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>iter</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_rpn_bbox</td><td>█▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss_rpn_cls</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>memory</td><td>▁▄▃▄▃▄▄▄▇▆▅▆▅▆▄▄▆▇▅▆▄▆▅█▄▆▄▄▆▆▄▅▄█▃▇▅▅▆▆</td></tr><tr><td>s0.acc</td><td>▁▁▃▂▂▄▅▁▅▂▁▄▃▇▆▃▆▃▅▂▅▅▄▄▇█▆▇▃▆▅▇▆▆▇█▆▇▄▄</td></tr><tr><td>s0.loss_bbox</td><td>█▇▇▇▆▅▄▄▄▃▂▃▂▃▃▃▂▄▃▃▃▃▃▃▂▂▄▃▃▃▂▂▂▂▁▁▁▁▁▂</td></tr><tr><td>s0.loss_cls</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s0.loss_mask</td><td>█▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s1.acc</td><td>▄▃▅▂▄▄▅▁▄▃▁▄▅▇▆▅▆▄▅▃▅▅▆▅▆▇▇▇▅▆▄▇▅▆██▆█▅▅</td></tr><tr><td>s1.loss_bbox</td><td>▁▇██▇▇▇▇▆▆▆▆▅▆▆▅▅▆▅▅▅▅▅▅▅▄▅▅▄▄▄▄▄▄▃▄▃▃▃▃</td></tr><tr><td>s1.loss_cls</td><td>█▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s1.loss_mask</td><td>█▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s2.acc</td><td>▅▃▂▃▄▄▅▂▃▂▁▃▅▇▆▆▄▅▆▄▅▅▅▅▇▇▇▇▄▅▄▇▆▆██▇▇▅▅</td></tr><tr><td>s2.loss_bbox</td><td>▁▇███████▇▇▇▇▇▇▆▆▇▆▇▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅▅▄▅▅▅</td></tr><tr><td>s2.loss_cls</td><td>█▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>s2.loss_mask</td><td>█▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>time</td><td>█▂▂▂▂▂▂▂▂▂▂▂▂▂▇█▆▄▆▄▃▅▄▄▂▄▃▃▂▂▁▁▁▁▁▁▃▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>0.254</td></tr><tr><td>coco/bbox_mAP_50</td><td>0.294</td></tr><tr><td>coco/bbox_mAP_75</td><td>0.278</td></tr><tr><td>coco/bbox_mAP_l</td><td>0.9</td></tr><tr><td>coco/bbox_mAP_m</td><td>0.9</td></tr><tr><td>coco/bbox_mAP_s</td><td>0.035</td></tr><tr><td>coco/segm_mAP</td><td>0.239</td></tr><tr><td>coco/segm_mAP_50</td><td>0.303</td></tr><tr><td>coco/segm_mAP_75</td><td>0.278</td></tr><tr><td>coco/segm_mAP_l</td><td>0.844</td></tr><tr><td>coco/segm_mAP_m</td><td>0.85</td></tr><tr><td>coco/segm_mAP_s</td><td>0.032</td></tr><tr><td>data_time</td><td>0.16527</td></tr><tr><td>epoch</td><td>500</td></tr><tr><td>iter</td><td>8992</td></tr><tr><td>loss</td><td>0.41422</td></tr><tr><td>loss_rpn_bbox</td><td>0.00027</td></tr><tr><td>loss_rpn_cls</td><td>0.0004</td></tr><tr><td>lr</td><td>4e-05</td></tr><tr><td>memory</td><td>8430</td></tr><tr><td>s0.acc</td><td>98.24219</td></tr><tr><td>s0.loss_bbox</td><td>0.00577</td></tr><tr><td>s0.loss_cls</td><td>0.04104</td></tr><tr><td>s0.loss_mask</td><td>0.16981</td></tr><tr><td>s1.acc</td><td>97.46094</td></tr><tr><td>s1.loss_bbox</td><td>0.01222</td></tr><tr><td>s1.loss_cls</td><td>0.03035</td></tr><tr><td>s1.loss_mask</td><td>0.08063</td></tr><tr><td>s2.acc</ ...
#  View run <strong style="color:#cdcd00">zesty-smoke-94</strong> at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ds0d1hyx' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ds0d1hyx</a><br/> View project at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a><br/>Synced 6 W&B file(s), 0 media file(s), 2157 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\tutorial_exps\500-epochs-batch3\20240814_211422\vis_data\wandb\run-20240814_211431-ds0d1hyx\logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
config = 'mmdetection/configs/htc/htc_res2net-101_fpn_20e_coco_saf-500-batch3.py'

# %%
from glob import glob
ckpt = 'tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth'

# %%
ckpt_b  = 'tutorial_exps/500-epochs-batch3/best_coco_bbox_mAP_epoch_477.pth'

# %% [markdown]
# ## Test HTC on best checkpointfile and save the painted images for future visualization

# %%
# !python mmdetection/tools/test.py {config} {ckpt} --show-dir output/segm
# Out:
# 08/15 06:17:56 - mmengine -
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# INFO
# wandb: - Waiting for wandb.init()...
#  -
# wandb: \ Waiting for wandb.init()...
# ------------------------------------------------------------
# System environment:
# wandb: | Waiting for wandb.init()...
#     sys.platform: win32
# wandb: / Waiting for wandb.init()...
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
# wandb:  $ pip install wandb --upgrade
#     MUSA available: False
# wandb: Tracking run with wandb version 0.17.5
#     numpy_random_seed: 1460492512
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\20240815_061749\vis_data\wandb\run-20240815_061759-vytgz6ju
#     GPU 0: NVIDIA RTX A4000
# wandb: Run `wandb offline` to turn off syncing.
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
# wandb: Syncing run robust-armadillo-95
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/vytgz6ju
#     GCC: n/a
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     PyTorch: 2.3.1
#   mask_preds = bboxes.new_tensor(mask_preds)
#     PyTorch compiling details: PyTorch built with:
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   - C++ Version: 201703
#   warnings.warn(
#   - MSVC 192930154
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   warnings.warn(
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
# wandb: - 10.123 MB of 10.160 MB uploaded (9.989 MB deduped)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
# wandb: \ 10.123 MB of 10.160 MB uploaded (9.989 MB deduped)
#   - CPU capability usage: AVX2
# wandb: | 10.160 MB of 10.160 MB uploaded (9.989 MB deduped)
#   - CUDA Runtime 12.1
# wandb:
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
# wandb: W&B sync reduced upload amount by 98.3%
#   - CuDNN 8.9.7  (built against CUDA 12.2)
# wandb:  View run robust-armadillo-95 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/vytgz6ju
#   - Magma 2.5.4
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
# wandb: Synced 6 W&B file(s), 0 media file(s), 2151 artifact file(s) and 0 other file(s)
# wandb: Find logs at: .\tutorial_exps\500-epochs-batch3\20240815_061749\vis_data\wandb\run-20240815_061759-vytgz6ju\logs
#     TorchVision: 0.18.1
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1460492512
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/15 06:17:57 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(
#         draw=True, test_out_dir='output/segm', type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# lr_config = dict(step=[
#     16,
#     19,
# ])
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=26,
#         depth=101,
#         frozen_stages=1,
#         init_cfg=dict(
#             checkpoint='open-mmlab://res2net101_v1d_26w_4s',
#             type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         scales=4,
#         style='pytorch',
#         type='Res2Net'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00375, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# runner = dict(max_epochs=20, type='EpochBasedRunner')
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='htc_res2net',
#                     backbone='Res2Net',
#                     batch_size=2,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     filter=32,
#                     learning_rate=0.00375,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch3'
#
# 08/15 06:18:19 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/15 06:18:19 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth
# 08/15 06:18:20 - mmengine - INFO - Load checkpoint from tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth
# 08/15 06:18:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/15 06:18:53 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.045 | 0.079  | 0.05   | 0.035 | 0.9   | nan   |
# | TansitionalMixing    | 0.066 | 0.109  | 0.067  | 0.077 | nan   | nan   |
# | DiffusiveMixing      | 0.004 | 0.008  | 0.006  | 0.005 | nan   | nan   |
# | spray                | 0.855 | 1.0    | 1.0    | nan   | nan   | 0.855 |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/15 06:18:53 - mmengine - INFO - bbox_mAP_copypaste: 0.243 0.299 0.281 0.039 0.900 0.855
# 08/15 06:18:53 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/15 06:18:53 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.068 | 0.114  | 0.065  | 0.056 | 0.85  | nan   |
# | TansitionalMixing    | 0.073 | 0.118  | 0.075  | 0.08  | nan   | nan   |
# | DiffusiveMixing      | 0.005 | 0.009  | 0.006  | 0.005 | nan   | nan   |
# | spray                | 0.855 | 1.0    | 1.0    | nan   | nan   | 0.855 |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/15 06:18:53 - mmengine - INFO - segm_mAP_copypaste: 0.250 0.310 0.286 0.047 0.850 0.855
# 08/15 06:18:53 - mmengine - INFO - Epoch(test) [8/8]    coco/ClassicalEvaporation_precision: 0.0680  coco/TansitionalMixing_precision: 0.0730  coco/DiffusiveMixing_precision: 0.0050  coco/spray_precision: 0.8550  coco/bbox_mAP: 0.2430  coco/bbox_mAP_50: 0.2990  coco/bbox_mAP_75: 0.2810  coco/bbox_mAP_s: 0.0390  coco/bbox_mAP_m: 0.9000  coco/bbox_mAP_l: 0.8550  coco/segm_mAP: 0.2500  coco/segm_mAP_50: 0.3100  coco/segm_mAP_75: 0.2860  coco/segm_mAP_s: 0.0470  coco/segm_mAP_m: 0.8500  coco/segm_mAP_l: 0.8550  data_time: 2.7779  time: 4.0178

# %% [markdown]
# ## Inference on trained Model

# %%
import os
from mmdet.apis import init_detector, inference_detector
import mmcv
import cv2
from mmdet.registry import VISUALIZERS

model = init_detector(config, ckpt, device='cuda:0')

image_folder = 'mmdetection/data/saf22/test/'
output_folder = 'tutorial_exps/500-epochs-batch3/inference-results/segm'
image_paths = [os.path.join(image_folder, img_name) for img_name in os.listdir(image_folder) if img_name.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'tiff'))]

visualizer = VISUALIZERS.build(model.cfg.visualizer)
visualizer.dataset_meta = model.dataset_meta
# Out:
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.TensorboardVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.WandbVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '

# %%
for img_path in image_paths:
    img = mmcv.imread(img_path)
    if img is None:
        print(f"Failed to read image at {img_path}")
        continue
    
    new_result_segm = inference_detector(model, img)
    os.makedirs(output_folder, exist_ok=True)
    output_file = os.path.join(output_folder, os.path.basename(img_path))
    
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    visualizer.add_datasample(
        'new_result_segm',
        img_rgb,
        data_sample=new_result_segm,        draw_gt=None,
        wait_time=0,
        out_file=output_file
    )
# Out:
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)

# %% [markdown]
# ## Save results.pkl

# %%
# !python mmdetection/tools/test.py {config} {ckpt}  --out ./results/500-epochs-batch3/results.pkl
# Out:
# 08/15 06:28:13 - mmengine -
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# INFO -
# wandb:  $ pip install wandb --upgrade
# ------------------------------------------------------------
# System environment:
# wandb: Tracking run with wandb version 0.17.5
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch3\20240815_062807\vis_data\wandb\run-20240815_062815-iznqosz7
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb: Run `wandb offline` to turn off syncing.
#     CUDA available: True
# wandb: Syncing run fresh-sun-96
#     MUSA available: False
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     numpy_random_seed: 887569152
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/iznqosz7
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#   mask_preds = bboxes.new_tensor(mask_preds)
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
# wandb: - 10.058 MB of 10.058 MB uploaded (10.038 MB deduped)
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# wandb: \ 10.058 MB of 10.058 MB uploaded (10.038 MB deduped)
# wandb: | 10.142 MB of 10.178 MB uploaded (10.043 MB deduped)
#     GCC: n/a
# wandb: / 10.157 MB of 10.178 MB uploaded (10.043 MB deduped)
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
# wandb: - 10.157 MB of 10.178 MB uploaded (10.043 MB deduped)
# wandb: \ 10.178 MB of 10.178 MB uploaded (10.043 MB deduped)
#   - C++ Version: 201703
#   - MSVC 192930154
# wandb:
# wandb: W&B sync reduced upload amount by 98.7%
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# wandb:  View run fresh-sun-96 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/iznqosz7
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#   - OpenMP 2019
# wandb: Synced 6 W&B file(s), 0 media file(s), 2152 artifact file(s) and 0 other file(s)
#   - LAPACK is enabled (usually provided by MKL)
# wandb: Find logs at: .\tutorial_exps\500-epochs-batch3\20240815_062807\vis_data\wandb\run-20240815_062815-iznqosz7\logs
#   - CPU capability usage: AVX2
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 887569152
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/15 06:28:13 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# lr_config = dict(step=[
#     16,
#     19,
# ])
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=26,
#         depth=101,
#         frozen_stages=1,
#         init_cfg=dict(
#             checkpoint='open-mmlab://res2net101_v1d_26w_4s',
#             type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         scales=4,
#         style='pytorch',
#         type='Res2Net'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00375, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# runner = dict(max_epochs=20, type='EpochBasedRunner')
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='htc_res2net',
#                     backbone='Res2Net',
#                     batch_size=2,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     filter=32,
#                     learning_rate=0.00375,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch3'
#
# 08/15 06:28:34 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/15 06:28:34 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/15 06:28:34 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth
# 08/15 06:28:34 - mmengine - INFO - Load checkpoint from tutorial_exps/500-epochs-batch3/best_coco_segm_mAP_epoch_165.pth
# 08/15 06:28:53 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/15 06:28:53 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.045 | 0.079  | 0.05   | 0.035 | 0.9   | nan   |
# | TansitionalMixing    | 0.066 | 0.109  | 0.067  | 0.077 | nan   | nan   |
# | DiffusiveMixing      | 0.004 | 0.008  | 0.006  | 0.005 | nan   | nan   |
# | spray                | 0.855 | 1.0    | 1.0    | nan   | nan   | 0.855 |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/15 06:28:53 - mmengine - INFO - bbox_mAP_copypaste: 0.243 0.299 0.281 0.039 0.900 0.855
# 08/15 06:28:53 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/15 06:28:53 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.068 | 0.114  | 0.065  | 0.056 | 0.85  | nan   |
# | TansitionalMixing    | 0.073 | 0.118  | 0.075  | 0.08  | nan   | nan   |
# | DiffusiveMixing      | 0.005 | 0.009  | 0.006  | 0.005 | nan   | nan   |
# | spray                | 0.855 | 1.0    | 1.0    | nan   | nan   | 0.855 |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/15 06:28:53 - mmengine - INFO - segm_mAP_copypaste: 0.250 0.310 0.286 0.047 0.850 0.855
# 08/15 06:28:53 - mmengine - INFO - Results has been saved to ./results/500-epochs-batch3/results.pkl.
# 08/15 06:28:53 - mmengine - INFO - Epoch(test) [8/8]    coco/ClassicalEvaporation_precision: 0.0680  coco/TansitionalMixing_precision: 0.0730  coco/DiffusiveMixing_precision: 0.0050  coco/spray_precision: 0.8550  coco/bbox_mAP: 0.2430  coco/bbox_mAP_50: 0.2990  coco/bbox_mAP_75: 0.2810  coco/bbox_mAP_s: 0.0390  coco/bbox_mAP_m: 0.9000  coco/bbox_mAP_l: 0.8550  coco/segm_mAP: 0.2500  coco/segm_mAP_50: 0.3100  coco/segm_mAP_75: 0.2860  coco/segm_mAP_s: 0.0470  coco/segm_mAP_m: 0.8500  coco/segm_mAP_l: 0.8550  data_time: 1.2102  time: 2.2649

# %% [markdown]
# The masks are represented as a tensor of boolean values, these boolean tensors represent the masks directly, rather than as coordinates.

# %% [markdown]
# ## Log Analysis

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.1
# Summary: Python plotting package
# Home-page:
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
#         =========================================================
#
#         1. This LICENSE AGREEMENT is between the Matplotlib Development Team
#         ("MDT"), and the Individual or Organization ("Licensee") accessing and
#         otherwise using matplotlib software in source or binary form and its
#         associated documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, MDT
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that MDT's
#         License Agreement and MDT's notice of copyright, i.e., "Copyright (c)
#         2012- Matplotlib Development Team; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib .
#
#         4. MDT is making matplotlib available to Licensee on an "AS
#         IS" basis.  MDT MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, MDT MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. MDT SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between MDT and
#         Licensee.  This License Agreement does not grant permission to use MDT
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.

# %%
# !pip install matplotlib
# Out:
#
#         8. By copying, installing or otherwise using matplotlib ,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
#
#         License agreement for matplotlib versions prior to 1.3.0
#         ========================================================
#
#         1. This LICENSE AGREEMENT is between John D. Hunter ("JDH"), and the
#         Individual or Organization ("Licensee") accessing and otherwise using
#         matplotlib software in source or binary form and its associated
#         documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, JDH
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that JDH's
#         License Agreement and JDH's notice of copyright, i.e., "Copyright (c)
#         2002-2011 John D. Hunter; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib  or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib.
#
#         4. JDH is making matplotlib  available to Licensee on an "AS
#         IS" basis.  JDH MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, JDH MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. JDH SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between JDH and
#         Licensee.  This License Agreement does not grant permission to use JDH
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
# Location: c:\users\ja683\appdata\roaming\python\python310\site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: fiftyone, mmdet, mmengine, pycocotools, seaborn
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib
print(matplotlib.rcParams['backend'])
# Out:
# module://matplotlib_inline.backend_inline

# %%
json_log = 'tutorial_exps/500-epochs-batch3/20240814_211422/vis_data/20240814_211422.json'

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py plot_curve \
  --keys loss \
  --title "Training Metrics" \
  --legend "Loss" \
  --backend TkAgg \
  --style darkgrid \
  --out tutorial_exps/500-epochs-batch3/20240814_211422/training_curves.png \
  {json_log}
# Out:
# plot curve of tutorial_exps/500-epochs-batch3/20240814_211422/vis_data/20240814_211422.json, metric is loss
# save curve to: tutorial_exps/500-epochs-batch3/20240814_211422/training_curves.png

# %% [markdown]
# ## Result Analysis

# %%
# !python mmdetection/tools/analysis_tools/analyze_results.py \
       {config} \
       ./results/500-epochs-batch3/results.pkl \
       ./results/500-epochs-batch3/vis_data \
       --show
# [Optional] Finish the wandb run
wandb.finish()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# loading annotations into memory...
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# Done (t=0.02s)
# wandb:  $ pip install wandb --upgrade
# creating index...
# wandb: Tracking run with wandb version 0.17.5
# index created!
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\results\500-epochs-batch3\vis_data\20240815_065756\vis_data\wandb\run-20240815_065805-27n9rq2j
# 08/15 06:58:02 - mmengine -
# wandb: Run `wandb offline` to turn off syncing.
# INFO
#  -
# wandb: Syncing run major-night-97
# ------------------------------------------------------------
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
# System environment:
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/27n9rq2j
#     sys.platform: win32
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#   warnings.warn(
#     CUDA available: True
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#     MUSA available: False
#   warnings.warn(
#     numpy_random_seed: 824528368
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:508: UserWarning: Warning: The text is out of bounds, the drawn text may not be in the image
#     GPU 0: NVIDIA RTX A4000
#   warnings.warn(
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
#   warnings.warn(
#     GCC: n/a
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:508: UserWarning: Warning: The text is out of bounds, the drawn text may not be in the image
#     PyTorch: 2.3.1
#   warnings.warn(
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 824528368
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/15 06:58:02 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=10, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = 'mmdetection/configs/htc/htc_r2_101_fpn_20e_coco-3a8d2112.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# lr_config = dict(step=[
#     16,
#     19,
# ])
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=26,
#         depth=101,
#         frozen_stages=1,
#         init_cfg=dict(
#             checkpoint='open-mmlab://res2net101_v1d_26w_4s',
#             type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         scales=4,
#         style='pytorch',
#         type='Res2Net'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00375, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=12,
#         gamma=0.1,
#         milestones=[
#             8,
#             11,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# runner = dict(max_epochs=20, type='EpochBasedRunner')
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='htc_res2net',
#                     backbone='Res2Net',
#                     batch_size=2,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     filter=32,
#                     learning_rate=0.00375,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './results/500-epochs-batch3/vis_data'
#
# 08/15 06:58:20 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/15 06:58:20 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.16s)
# creating index...
# index created!
# [                                                  ] 0/8, elapsed: 0s, ETA:
# [>>>>                              ] 1/8, 0.0 task/s, elapsed: 25s, ETA:   176s
# [>>>>>>>>                          ] 2/8, 0.0 task/s, elapsed: 44s, ETA:   131s
# [>>>>>>>>>>>>                      ] 3/8, 0.0 task/s, elapsed: 67s, ETA:   112s
# [>>>>>>>>>>>>>>>>>                 ] 4/8, 0.1 task/s, elapsed: 76s, ETA:    76s
# [>>>>>>>>>>>>>>>>>>>>>             ] 5/8, 0.1 task/s, elapsed: 81s, ETA:    49s
# [>>>>>>>>>>>>>>>>>>>>>>>>>         ] 6/8, 0.1 task/s, elapsed: 87s, ETA:    29s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>     ] 7/8, 0.1 task/s, elapsed: 96s, ETA:    14s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 8/8, 0.1 task/s, elapsed: 101s, ETA:     0sImage shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (100, 1536, 2072)

# %% [markdown]
# ## Confusion Matrix

# %%
# !python mmdetection/tools/analysis_tools/confusion_matrix.py \
        {config} \
        results/500-epochs-batch3/results.pkl \
        results/500-epochs-batch3 --show
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [                                                  ] 0/8, elapsed: 0s, ETA:
# [>>>>                             ] 1/8, 501.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>                        ] 2/8, 1003.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>                     ] 3/8, 752.5 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>                 ] 4/8, 802.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>            ] 5/8, 1003.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>        ] 6/8, 1204.0 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 7/8, 1169.7 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 8/8, 1146.7 task/s, elapsed: 0s, ETA:     0sFigure(1500x956.25)

# %%
# !pip install scikit-learn matplotlib seaborn

# %% [markdown]
# ## Eval Metric from results.pkl file

# %%
# !python mmdetection/tools/analysis_tools/eval_metric.py \
        {config} \
        results/500-epochs-batch3/results.pkl
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/15 07:19:09 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.07s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.243
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.299
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.281
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.039
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.290
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.089
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/15 07:19:09 - mmengine - INFO - bbox_mAP_copypaste: 0.243 0.299 0.281 0.039 0.900 0.855
# 08/15 07:19:09 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.250
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.310
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.286
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.047
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.855
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.312
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.120
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/15 07:19:10 - mmengine - INFO - segm_mAP_copypaste: 0.250 0.310 0.286 0.047 0.850 0.855
# {'coco/bbox_mAP': 0.243, 'coco/bbox_mAP_50': 0.299, 'coco/bbox_mAP_75': 0.281, 'coco/bbox_mAP_s': 0.039, 'coco/bbox_mAP_m': 0.9, 'coco/bbox_mAP_l': 0.855, 'coco/segm_mAP': 0.25, 'coco/segm_mAP_50': 0.31, 'coco/segm_mAP_75': 0.286, 'coco/segm_mAP_s': 0.047, 'coco/segm_mAP_m': 0.85, 'coco/segm_mAP_l': 0.855}
