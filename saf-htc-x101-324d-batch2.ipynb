# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# PyTorch version: 2.3.1
# CUDA available: True
# CUDA version: 12.1

# %%
# Check mmengine installation
import mmengine
print(f"MMengine: {mmengine.__version__}")

# Check Openmim installation
from importlib.metadata import version
print(f"Openmim: {version('openmim')}")

# Check mmcv installation
import mmcv
print("mmcv:",mmcv.__version__)

# Check MMDetection installation
import mmdet
print("mmdetection:",mmdet.__version__)
# Out:
# MMengine: 0.10.4
# Openmim: 0.3.9
# mmcv: 2.0.0rc4
# mmdetection: 3.3.0

# %%
import mmcv
import mmengine
from mmdet.apis import init_detector, inference_detector
from mmdet.utils import register_all_modules
# Choose to use a config and initialize the detector
config_file = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco.py'
# Setup a checkpoint file to load
checkpoint_file = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'

# register all modules in mmdet into the registries
register_all_modules()

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')  # or device='cuda:0'
# Out:
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias

# %%
from pycocotools.coco import COCO

# Path to load the COCO annotation file
annotation_file = 'mmdetection/data/saf22/train/annotation_coco.json'

# Initialise the COCO object
coco = COCO(annotation_file)

# Get all category tags and corresponding category IDs
categories = coco.loadCats(coco.getCatIds())
category_id_to_name = {cat['id']: cat['name'] for cat in categories}

# Print all category IDs and corresponding category names
for category_id, category_name in category_id_to_name.items():
    print(f"Category ID: {category_id}, Category Name: {category_name}")
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Category ID: 1, Category Name: ClassicalEvaporation
# Category ID: 2, Category Name: TansitionalMixing
# Category ID: 3, Category Name: DiffusiveMixing
# Category ID: 4, Category Name: spray

# %% [markdown]
# ### Wandb integration

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# True

# %%
# Weights and Biases version
print(wandb.__version__)
# Out:
# 0.17.5

# %% [markdown]
# ## Hypertuning the Parameters

# %%
from mmengine.runner import set_random_seed
from mmengine import Config
import random
import numpy as np
import matplotlib.pyplot as plt
from mmdet.visualization import DetLocalVisualizer
import os
import cv2

# %%
# Load the configuration
cfg = Config.fromfile('mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco.py')

# Modify dataset classes and color
cfg.metainfo = {
    'classes': ('ClassicalEvaporation', 'TansitionalMixing', 'DiffusiveMixing', 'spray'),
    'palette': [
        (13,24,103), (167,13,13), (91,117,249), (203,173,55),
    ]
}

# Modify dataset type and path
cfg.data_root = 'mmdetection/data/saf22/'

cfg.train_dataloader.dataset.ann_file = 'train/annotation_coco.json'
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = {'img': 'train/'}
cfg.train_dataloader.dataset.metainfo = cfg.metainfo

cfg.val_dataloader.dataset.ann_file = 'val/annotation_coco.json'
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = {'img': 'val/'}
cfg.val_dataloader.dataset.metainfo = cfg.metainfo

cfg.test_dataloader = cfg.val_dataloader

# Modify metric config
cfg.val_evaluator.ann_file = f'{cfg.data_root}val/annotation_coco.json'
cfg.test_evaluator = cfg.val_evaluator

########################################################################################################

# Modify num classes of the model in box head and mask head
if isinstance(cfg.model.roi_head.bbox_head, list):
    for head in cfg.model.roi_head.bbox_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.bbox_head.num_classes = 4

if isinstance(cfg.model.roi_head.mask_head, list):
    for head in cfg.model.roi_head.mask_head:
        head.num_classes = 4
else:
    cfg.model.roi_head.mask_head.num_classes = 4

########################################################################################################

# Configure checkpoint saving
cfg.default_hooks.checkpoint = dict(
    type='CheckpointHook',
    interval=1,
    save_optimizer=True,
    save_best = ['coco/bbox_mAP','coco/segm_mAP'],
    save_last=True,
    rule='greater',
    max_keep_ckpts=1
)

cfg.test_evaluator.update(dict(classwise=True))

# Use the pre-trained HTC model
cfg.load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'

# Set up working dir to save files and logs.
cfg.work_dir = './tutorial_exps/500-epochs-batch2'

# Set the number of epochs
cfg.train_cfg.max_epochs = 500

# Set neck as FPN_CARAFE
cfg.model.neck.type = 'FPN_CARAFE'

# Set the evaluation interval to reduce the evaluation times
cfg.train_cfg.val_interval = 3

# Set the checkpoint saving interval to reduce the storage cost
cfg.default_hooks.checkpoint.interval = 3

# Adjust learning rate for single GPU
cfg.optim_wrapper.optimizer.lr = 0.05 / 8

# Set logging interval
cfg.default_hooks.logger.interval = 8

# Set seed for reproducibility
set_random_seed(0, deterministic=False)

# Use Tensorboard to log the training process
cfg.visualizer.vis_backends.append({"type": 'TensorboardVisBackend'})

# Configure WandB logger
cfg.visualizer.vis_backends.append(dict(type='WandbVisBackend', init_kwargs=dict(
    project='SAF_Project',
    entity='ahluwaliajyoti50-university-of-sussex',
    config={
        'learning_rate': cfg.optim_wrapper.optimizer.lr,
        'architecture': 'HTC_resnext101_32x4d',
        'dataset': 'SAF22',
        'neck': cfg.model.neck.type,
        'epochs': cfg.train_cfg.max_epochs,
        'batch_size': cfg.train_dataloader.batch_size,
        'optimizer': cfg.optim_wrapper.optimizer.type,
        'classes': cfg.metainfo['classes'],
        'seed': 0,
    }
)))

# Save the modified config
config = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2.py'
with open(config, 'w') as f:
    f.write(cfg.pretty_text)

# Train using train.py
# %run mmdetection/tools/train.py {config}

# [Optional] Finish the wandb run
wandb.finish()
# Out:
# 08/14 18:35:36 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 209652396
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#     MSVC: n/a, reason: fileno
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 209652396
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/14 18:35:37 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=8, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00625, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.00625,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch2'
# wandb version 0.17.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.5
# Run data is saved locally in <code>C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch2\20240814_183529\vis_data\wandb\run-20240814_183537-ubo7ecmp</code>
# Syncing run <strong><a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ubo7ecmp' target="_blank">solar-shadow-90</a></strong> to <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a>
#  View run at <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ubo7ecmp' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ubo7ecmp</a>
# 08/14 18:35:53 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/14 18:35:54 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/14 18:35:55 - mmengine - INFO - load model from: open-mmlab://resnext101_32x4d
# 08/14 18:35:55 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnext101_32x4d
# Loads checkpoint by local backend from path: mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.0.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.0.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.1.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.1.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.bbox_head.2.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([5, 1024]).
# size mismatch for roi_head.bbox_head.2.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([5]).
# size mismatch for roi_head.mask_head.0.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.0.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.1.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.1.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# size mismatch for roi_head.mask_head.2.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([4, 256, 1, 1]).
# size mismatch for roi_head.mask_head.2.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([4]).
# unexpected key in source state_dict: roi_head.semantic_head.lateral_convs.0.conv.weight, roi_head.semantic_head.lateral_convs.0.conv.bias, roi_head.semantic_head.lateral_convs.1.conv.weight, roi_head.semantic_head.lateral_convs.1.conv.bias, roi_head.semantic_head.lateral_convs.2.conv.weight, roi_head.semantic_head.lateral_convs.2.conv.bias, roi_head.semantic_head.lateral_convs.3.conv.weight, roi_head.semantic_head.lateral_convs.3.conv.bias, roi_head.semantic_head.lateral_convs.4.conv.weight, roi_head.semantic_head.lateral_convs.4.conv.bias, roi_head.semantic_head.convs.0.conv.weight, roi_head.semantic_head.convs.0.conv.bias, roi_head.semantic_head.convs.1.conv.weight, roi_head.semantic_head.convs.1.conv.bias, roi_head.semantic_head.convs.2.conv.weight, roi_head.semantic_head.convs.2.conv.bias, roi_head.semantic_head.convs.3.conv.weight, roi_head.semantic_head.convs.3.conv.bias, roi_head.semantic_head.conv_embedding.conv.weight, roi_head.semantic_head.conv_embedding.conv.bias, roi_head.semantic_head.conv_logits.weight, roi_head.semantic_head.conv_logits.bias
#
# missing keys in source state_dict: neck.lateral_convs.4.conv.weight, neck.lateral_convs.4.conv.bias, neck.fpn_convs.4.conv.weight, neck.fpn_convs.4.conv.bias, neck.upsample_modules.0.channel_compressor.weight, neck.upsample_modules.0.channel_compressor.bias, neck.upsample_modules.0.content_encoder.weight, neck.upsample_modules.0.content_encoder.bias, neck.upsample_modules.1.channel_compressor.weight, neck.upsample_modules.1.channel_compressor.bias, neck.upsample_modules.1.content_encoder.weight, neck.upsample_modules.1.content_encoder.bias, neck.upsample_modules.2.channel_compressor.weight, neck.upsample_modules.2.channel_compressor.bias, neck.upsample_modules.2.content_encoder.weight, neck.upsample_modules.2.content_encoder.bias, neck.upsample_modules.3.channel_compressor.weight, neck.upsample_modules.3.channel_compressor.bias, neck.upsample_modules.3.content_encoder.weight, neck.upsample_modules.3.content_encoder.bias
#
# 08/14 18:35:55 - mmengine - INFO - Load checkpoint from mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth
# 08/14 18:35:55 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 08/14 18:35:55 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 08/14 18:35:55 - mmengine - INFO - Checkpoints will be saved to C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch2.
# 08/14 18:36:21 - mmengine - INFO - Epoch(train)   [1][ 8/36]  lr: 9.3838e-05  eta: 16:06:24  time: 3.2228  data_time: 2.3428  memory: 4461  loss: 4.0126  loss_rpn_cls: 0.0016  loss_rpn_bbox: 0.0019  s0.loss_cls: 1.6016  s0.acc: 72.4609  s0.loss_bbox: 0.0044  s0.loss_mask: 0.6708  s1.loss_cls: 0.7667  s1.acc: 44.7266  s1.loss_bbox: 0.0045  s1.loss_mask: 0.3753  s2.loss_cls: 0.3783  s2.acc: 74.2188  s2.loss_bbox: 0.0036  s2.loss_mask: 0.2038
# 08/14 18:36:54 - mmengine - INFO - Epoch(train)   [3][32/36]  lr: 1.2950e-03  eta: 2:48:04  time: 0.3466  data_time: 0.0253  memory: 4092  loss: 1.1676  loss_rpn_cls: 0.0095  loss_rpn_bbox: 0.0021  s0.loss_cls: 0.1701  s0.acc: 97.0703  s0.loss_bbox: 0.0111  s0.loss_mask: 0.4405  s1.loss_cls: 0.1180  s1.acc: 95.7031  s1.loss_bbox: 0.0196  s1.loss_mask: 0.2086  s2.loss_cls: 0.0671  s2.acc: 95.3125  s2.loss_bbox: 0.0117  s2.loss_mask: 0.1094
# 08/14 18:36:55 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2_20240814_183529
# 08/14 18:36:55 - mmengine - INFO - Saving checkpoint at 3 epochs
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#   mask_preds = bboxes.new_tensor(mask_preds)
# 08/14 18:37:13 - mmengine - INFO - Epoch(val)   [3][8/8]    eta: 0:00:00  time: 1.8487  data_time: 1.2416  memory: 4635
# 08/14 18:37:13 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.129
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.188
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.168
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.014
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.417
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.755
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.235
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.037
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.850
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.800
# 08/14 18:37:13 - mmengine - INFO - bbox_mAP_copypaste: 0.129 0.188 0.168 0.014 0.417 0.755
# 08/14 18:37:13 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.08s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.131
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.195
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.171
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.018
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.744
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.233
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.047
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.767
# 08/14 18:37:13 - mmengine - INFO - segm_mAP_copypaste: 0.131 0.195 0.171 0.018 0.800 0.744
# 08/14 18:37:13 - mmengine - INFO - Epoch(val) [3][8/8]    coco/bbox_mAP: 0.1290  coco/bbox_mAP_50: 0.1880  coco/bbox_mAP_75: 0.1680  coco/bbox_mAP_s: 0.0140  coco/bbox_mAP_m: 0.4170  coco/bbox_mAP_l: 0.7550  coco/segm_mAP: 0.1310  coco/segm_mAP_50: 0.1950  coco/segm_mAP_75: 0.1710  coco/segm_mAP_s: 0.0180  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.7440  data_time: 1.2416  time: 1.8487
# 08/14 18:37:15 - mmengine - INFO - The best checkpoint with 0.1290 coco/bbox_mAP at 3 epoch is saved to best_coco_bbox_mAP_epoch_3.pth.
# 08/14 18:37:17 - mmengine - INFO - The best checkpoint with 0.1310 coco/segm_mAP at 3 epoch is saved to best_coco_segm_mAP_epoch_3.pth.
# 08/14 18:37:23 - mmengine - INFO - Epoch(train)   [4][ 8/36]  lr: 1.4452e-03  eta: 2:42:56  time: 0.3657  data_time: 0.0328  memory: 4230  loss: 1.0630  loss_rpn_cls: 0.0074  loss_rpn_bbox: 0.0015  s0.loss_cls: 0.1557  s0.acc: 96.4844  s0.loss_bbox: 0.0115  s0.loss_mask: 0.3919  s1.loss_cls: 0.1117  s1.acc: 95.7031  s1.loss_bbox: 0.0202  s1.loss_mask: 0.1860  s2.loss_cls: 0.0668  s2.acc: 95.3125  s2.loss_bbox: 0.0134  s2.loss_mask: 0.0969
# 08/14 18:37:41 - mmengine - INFO - Epoch(train)   [5][24/36]  lr: 2.0958e-03  eta: 2:24:07  time: 0.3500  data_time: 0.0252  memory: 4723  loss: 0.7937  loss_rpn_cls: 0.0018  loss_rpn_bbox: 0.0015  s0.loss_cls: 0.0965  s0.acc: 95.8984  s0.loss_bbox: 0.0082  s0.loss_mask: 0.3082  s1.loss_cls: 0.0661  s1.acc: 96.0938  s1.loss_bbox: 0.0212  s1.loss_mask: 0.1501  s2.loss_cls: 0.0448  s2.acc: 96.0938  s2.loss_bbox: 0.0202  s2.loss_mask: 0.0754
# 08/14 18:37:44 - mmengine - INFO - Epoch(train)   [5][32/36]  lr: 2.1959e-03  eta: 2:22:49  time: 0.3580  data_time: 0.0264  memory: 4962  loss: 0.7922  loss_rpn_cls: 0.0015  loss_rpn_bbox: 0.0013  s0.loss_cls: 0.1000  s0.acc: 95.8984  s0.loss_bbox: 0.0085  s0.loss_mask: 0.3037  s1.loss_cls: 0.0679  s1.acc: 94.3359  s1.loss_bbox: 0.0216  s1.loss_mask: 0.1478  s2.loss_cls: 0.0455  s2.acc: 92.3828  s2.loss_bbox: 0.0207  s2.loss_mask: 0.0737
# 08/14 18:37:45 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2_20240814_183529
# 08/14 18:37:49 - mmengine - INFO - Epoch(train)   [6][ 8/36]  lr: 2.3461e-03  eta: 2:20:58  time: 0.3754  data_time: 0.0351  memory: 5145  loss: 0.7959  loss_rpn_cls: 0.0020  loss_rpn_bbox: 0.0022  s0.loss_cls: 0.1039  s0.acc: 95.8984  s0.loss_bbox: 0.0092  s0.loss_mask: 0.2987  s1.loss_cls: 0.0706  s1.acc: 95.8984  s1.loss_bbox: 0.0231  s1.loss_mask: 0.1457  s2.loss_cls: 0.0469  s2.acc: 95.5078  s2.loss_bbox: 0.0209  s2.loss_mask: 0.0727
# 08/14 18:37:52 - mmengine - INFO - Epoch(train)   [6][16/36]  lr: 2.4462e-03  eta: 2:19:53  time: 0.3739  data_time: 0.0333  memory: 5058  loss: 0.7864  loss_rpn_cls: 0.0023  loss_rpn_bbox: 0.0018  s0.loss_cls: 0.0961  s0.acc: 98.4375  s0.loss_bbox: 0.0076  s0.loss_mask: 0.3030  s1.loss_cls: 0.0680  s1.acc: 95.3125  s1.loss_bbox: 0.0212  s1.loss_mask: 0.1477  s2.loss_cls: 0.0452  s2.acc: 93.1641  s2.loss_bbox: 0.0199  s2.loss_mask: 0.0735
# 08/14 18:37:54 - mmengine - INFO - Epoch(train)   [6][24/36]  lr: 2.5463e-03  eta: 2:18:03  time: 0.3676  data_time: 0.0297  memory: 4101  loss: 0.7735  loss_rpn_cls: 0.0024  loss_rpn_bbox: 0.0016  s0.loss_cls: 0.0891  s0.acc: 97.8516  s0.loss_bbox: 0.0065  s0.loss_mask: 0.3054  s1.loss_cls: 0.0625  s1.acc: 97.2656  s1.loss_bbox: 0.0197  s1.loss_mask: 0.1503  s2.loss_cls: 0.0417  s2.acc: 96.2891  s2.loss_bbox: 0.0194  s2.loss_mask: 0.0748
# 08/14 18:37:57 - mmengine - INFO - Epoch(train)   [6][32/36]  lr: 2.6464e-03  eta: 2:16:32  time: 0.3635  data_time: 0.0287  memory: 4563  loss: 0.7506  loss_rpn_cls: 0.0023  loss_rpn_bbox: 0.0018  s0.loss_cls: 0.0905  s0.acc: 98.2422  s0.loss_bbox: 0.0065  s0.loss_mask: 0.2953  s1.loss_cls: 0.0613  s1.acc: 97.8516  s1.loss_bbox: 0.0177  s1.loss_mask: 0.1442  s2.loss_cls: 0.0411  s2.acc: 99.0234  s2.loss_bbox: 0.0177  s2.loss_mask: 0.0721
# 08/14 18:37:58 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2_20240814_183529
# 08/14 18:37:58 - mmengine - INFO - Saving checkpoint at 6 epochs
# 08/14 18:38:07 - mmengine - INFO - Epoch(val)   [6][8/8]    eta: 0:00:00  time: 1.2823  data_time: 0.6940  memory: 4508
# 08/14 18:38:07 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.209
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.290
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.268
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.033
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.279
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.755
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.261
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.767
# 08/14 18:38:07 - mmengine - INFO - bbox_mAP_copypaste: 0.209 0.290 0.268 0.033 0.279 0.755
# 08/14 18:38:07 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.167
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.302
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.165
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.037
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.247
# ...
# 08/14 20:48:51 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2_20240814_183529
# 08/14 20:48:51 - mmengine - INFO - Saving checkpoint at 498 epochs
# 08/14 20:48:57 - mmengine - INFO - Epoch(val) [498][8/8]    eta: 0:00:00  time: 0.4148  data_time: 0.2039  memory: 4892
# 08/14 20:48:57 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 20:48:57 - mmengine - INFO - bbox_mAP_copypaste: 0.261 0.322 0.306 0.061 0.950 0.844
# 08/14 20:48:57 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 20:48:57 - mmengine - INFO - segm_mAP_copypaste: 0.272 0.319 0.305 0.057 0.800 0.900
# 08/14 20:48:57 - mmengine - INFO - Epoch(val) [498][8/8]    coco/bbox_mAP: 0.2610  coco/bbox_mAP_50: 0.3220  coco/bbox_mAP_75: 0.3060  coco/bbox_mAP_s: 0.0610  coco/bbox_mAP_m: 0.9500  coco/bbox_mAP_l: 0.8440  coco/segm_mAP: 0.2720  coco/segm_mAP_50: 0.3190  coco/segm_mAP_75: 0.3050  coco/segm_mAP_s: 0.0570  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.9000  data_time: 0.1805  time: 0.3825
# 08/14 20:48:57 - mmengine - INFO - The previous best checkpoint C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch2\best_coco_segm_mAP_epoch_384.pth is removed
# 08/14 20:48:59 - mmengine - INFO - The best checkpoint with 0.2720 coco/segm_mAP at 498 epoch is saved to best_coco_segm_mAP_epoch_498.pth.
# 08/14 20:49:06 - mmengine - INFO - Epoch(train) [499][ 8/36]  lr: 6.2500e-05  eta: 0:00:24  time: 0.3876  data_time: 0.0343  memory: 5135  loss: 0.2668  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.
loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0087  s0.acc: 98.6328  s0.loss_bbox: 0.0011  s0.loss_mask: 0.1283  s1.loss_cls: 0.0078  s1.acc: 99.1803  s1.loss_bbox: 0.0044  s1.loss_mask: 0.0647  s2.loss_cls: 0.0061  s2.acc: 97.9080  s2.loss_bbox: 0.0078  s2.loss_mask: 0.0320
# 08/14 20:49:29 - mmengine - INFO - Epoch(train) [500][32/36]  lr: 6.2500e-05  eta: 0:00:01  time: 0.3841  data_time: 0.0251  memory: 5093  loss: 0.2637  loss_rpn_cls: 0.0002  loss_rpn_bbox: 0.0001  s0.loss_cls: 0.0085  s0.acc: 99.8047  s0.loss_bbox: 0.0010  s0.loss_mask: 0.1307  s1.loss_cls: 0.0077  s1.acc: 100.0000  s1.loss_bbox: 0.0043  s1.loss_mask: 0.0655  s2.loss_cls: 0.0059  s2.acc: 99.8047  s2.loss_bbox: 0.0075  s2.loss_mask: 0.0324
# 08/14 20:49:30 - mmengine - INFO - Exp name: htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2_20240814_183529
# 08/14 20:49:30 - mmengine - INFO - Saving checkpoint at 500 epochs
# 08/14 20:49:37 - mmengine - INFO - Epoch(val) [500][8/8]    eta: 0:00:00  time: 0.4137  data_time: 0.2019  memory: 5134
# 08/14 20:49:37 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.262
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 20:49:37 - mmengine - INFO - bbox_mAP_copypaste: 0.262 0.322 0.306 0.061 0.950 0.844
# 08/14 20:49:37 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.320
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 20:49:37 - mmengine - INFO - segm_mAP_copypaste: 0.272 0.320 0.306 0.057 0.800 0.900
# 08/14 20:49:37 - mmengine - INFO - Epoch(val) [500][8/8]    coco/bbox_mAP: 0.2620  coco/bbox_mAP_50: 0.3220  coco/bbox_mAP_75: 0.3060  coco/bbox_mAP_s: 0.0610  coco/bbox_mAP_m: 0.9500  coco/bbox_mAP_l: 0.8440  coco/segm_mAP: 0.2720  coco/segm_mAP_50: 0.3200  coco/segm_mAP_75: 0.3060  coco/segm_mAP_s: 0.0570  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.9000  data_time: 0.1853  time: 0.3901
# W&B sync reduced upload amount by 85.8%
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>coco/bbox_mAP</td><td>▁▇▇▇▆▇▆▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇█████████████</td></tr><tr><td>coco/bbox_mAP_50</td><td>▁▃▄▄▃▄▃▄▃▃▄▄▄▄▄▄▄▅▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█▇▇█</td></tr><tr><td>coco/bbox_mAP_75</td><td>▁▅▆▆▆▆▆▆▆▆▆▆▇▆▆▆▇▇▆▇▇▇▇▇▇█▇██████▇██████</td></tr><tr><td>coco/bbox_mAP_l</td><td>▁█▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td
mAP_s</td><td>0.057</td></tr><tr><td>data_time</td><td>0.18532</td></tr><tr><td>epoch</td><td>500</td></tr><tr><td>iter</td><td>17996</td></tr><tr><td>loss</td><td>0.26371</td></tr><tr><td>loss_rpn_bbox</td><td>0.0001</td></tr><tr><td>loss_rpn_cls</td><td>0.00016</td></tr><tr><td>lr</td><td>6e-05</td></tr><tr><td>memory</td><td>5093</td></tr><tr><td>s0.acc</td><td>99.80469</td></tr><tr><td>s0.loss_bbox</td><td>0.00103</td></tr><tr><td>s0.loss_cls</td><td>0.00851</td></tr><tr><td>s0.loss_mask</td><td>0.13065</td></tr><tr><td>s1.acc</td><td>100.0</td></tr><tr><td>s1.loss_bbox</td><td>0.00426</td></tr><tr><td>s1.loss_cls</td><td>0.00768</td></tr><tr><td>s1.loss_mask</td><td>0.06549</td></tr><tr><td>s2.acc</td> ...
#  View run <strong style="color:#cdcd00">solar-shadow-90</strong> at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ubo7ecmp' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ubo7ecmp</a><br/> View project at: <a href='https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project' target="_blank">https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project</a><br/>Synced 6 W&B file(s), 0 media file(s), 2153 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\tutorial_exps\500-epochs-batch2\20240814_183529\vis_data\wandb\run-20240814_183537-ubo7ecmp\logs</code>
# The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %%
config = 'mmdetection/configs/htc/htc_x101-32x4d_fpn_16xb1-20e_coco_saf-500-batch2.py'

# %%
from glob import glob
ckpt = 'tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth'

# %%
ckpt_b  = 'tutorial_exps/500-epochs-batch2/best_coco_bbox_mAP_epoch_348.pth'

# %% [markdown]
# ## Test HTC on best checkpointfile and save the painted images for future visualization

# %%
# !python mmdetection/tools/test.py {config} {ckpt} --show-dir output/segm
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# 08/14 21:02:47 - mmengine - INFO
#  -
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# ------------------------------------------------------------
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.5
# System environment:
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch2\20240814_210241\vis_data\wandb\run-20240814_210250-s6wnvhrz
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run crimson-dream-91
#     CUDA available: True
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     MUSA available: False
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/s6wnvhrz
#     numpy_random_seed: 1065455555
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     GPU 0: NVIDIA RTX A4000
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#   mask_preds = bboxes.new_tensor(mask_preds)
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#   warnings.warn(
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#     GCC: n/a
#     PyTorch: 2.3.1
#   warnings.warn(
# wandb: - 10.123 MB of 10.123 MB uploaded (9.994 MB deduped)
#     PyTorch compiling details: PyTorch built with:
# wandb: \ 10.123 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - C++ Version: 201703
#   - MSVC 192930154
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - LAPACK is enabled (usually provided by MKL)
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - CPU capability usage: AVX2
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - CuDNN 8.9.7  (built against CUDA 12.2)
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     TorchVision: 0.18.1
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     OpenCV: 4.10.0
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     MMEngine: 0.10.4
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# Runtime environment:
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1065455555
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     Distributed launcher: none
#     Distributed training: False
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     GPU number: 1
# ------------------------------------------------------------
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# 08/14 21:02:48 - mmengine -
# INFO
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#  - Config:
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# backend_args = None
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# data_root = 'mmdetection/data/saf22/'
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# dataset_type = 'CocoDataset'
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# default_hooks = dict(
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     checkpoint=dict(
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         interval=3,
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         max_keep_ckpts=1,
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         rule='greater',
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         save_best=[
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#             'coco/bbox_mAP',
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#             'coco/segm_mAP',
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         ],
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         save_last=True,
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         save_optimizer=True,
#         type='CheckpointHook'),
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     logger=dict(interval=8, type='LoggerHook'),
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     param_scheduler=dict(type='ParamSchedulerHook'),
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     sampler_seed=dict(type='DistSamplerSeedHook'),
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     timer=dict(type='IterTimerHook'),
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     visualization=dict(
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#         draw=True, test_out_dir='output/segm', type='DetVisualizationHook'))
# wandb: | 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# default_scope = 'mmdet'
# env_cfg = dict(
# wandb: / 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb: - 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
# wandb: \ 10.160 MB of 10.160 MB uploaded (9.994 MB deduped)
# wandb:
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# wandb: W&B sync reduced upload amount by 98.4%
# wandb:  View run crimson-dream-91 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/s6wnvhrz
# load_from = 'tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth'
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# wandb: Synced 6 W&B file(s), 0 media file(s), 2154 artifact file(s) and 0 other file(s)
# max_epochs = 20
# wandb: Find logs at: .\tutorial_exps\500-epochs-batch2\20240814_210241\vis_data\wandb\run-20240814_210250-s6wnvhrz\logs
# metainfo = dict(
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00625, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.00625,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch2'
#
# 08/14 21:03:06 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/14 21:03:06 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth
# 08/14 21:03:07 - mmengine - INFO - Load checkpoint from tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth
# 08/14 21:03:34 - mmengine - INFO - Epoch(test) [8/8]    eta: 0:00:00  time: 3.3857  data_time: 2.9121  memory: 1905
# 08/14 21:03:34 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 21:03:35 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.074 | 0.102  | 0.082  | 0.045 | 0.95  | nan   |
# | TansitionalMixing    | 0.115 | 0.157  | 0.129  | 0.124 | nan   | nan   |
# | DiffusiveMixing      | 0.013 | 0.03   | 0.012  | 0.013 | nan   | nan   |
# | spray                | 0.844 | 1.0    | 1.0    | nan   | nan   | 0.844 |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/14 21:03:35 - mmengine - INFO - bbox_mAP_copypaste: 0.261 0.322 0.306 0.061 0.950 0.844
# 08/14 21:03:35 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 21:03:35 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.069 | 0.102  | 0.082  | 0.044 | 0.8   | nan   |
# | TansitionalMixing    | 0.106 | 0.157  | 0.127  | 0.115 | nan   | nan   |
# | DiffusiveMixing      | 0.011 | 0.018  | 0.012  | 0.011 | nan   | nan   |
# | spray                | 0.9   | 1.0    | 1.0    | nan   | nan   | 0.9   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/14 21:03:35 - mmengine - INFO - segm_mAP_copypaste: 0.272 0.319 0.305 0.057 0.800 0.900
# 08/14 21:03:35 - mmengine - INFO - Epoch(test) [8/8]    coco/ClassicalEvaporation_precision: 0.0690  coco/TansitionalMixing_precision: 0.1060  coco/DiffusiveMixing_precision: 0.0110  coco/spray_precision: 0.9000  coco/bbox_mAP: 0.2610  coco/bbox_mAP_50: 0.3220  coco/bbox_mAP_75: 0.3060  coco/bbox_mAP_s: 0.0610  coco/bbox_mAP_m: 0.9500  coco/bbox_mAP_l: 0.8440  coco/segm_mAP: 0.2720  coco/segm_mAP_50: 0.3190  coco/segm_mAP_75: 0.3050  coco/segm_mAP_s: 0.0570  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.9000  data_time: 2.9121  time: 3.3857

# %% [markdown]
# ## Inference on trained Model

# %%
import os
from mmdet.apis import init_detector, inference_detector
import mmcv
import cv2
from mmdet.registry import VISUALIZERS

model = init_detector(config, ckpt, device='cuda:0')

image_folder = 'mmdetection/data/saf22/test/'
output_folder = 'tutorial_exps/500-epochs-batch2/inference-results/segm'
image_paths = [os.path.join(image_folder, img_name) for img_name in os.listdir(image_folder) if img_name.lower().endswith(('png', 'jpg', 'jpeg', 'bmp', 'tiff'))]

visualizer = VISUALIZERS.build(model.cfg.visualizer)
visualizer.dataset_meta = model.dataset_meta
# Out:
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\utils\manager.py:113: UserWarning: <class 'mmdet.visualization.local_visualizer.DetLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(

# %%
for img_path in image_paths:
    img = mmcv.imread(img_path)
    if img is None:
        print(f"Failed to read image at {img_path}")
        continue
    
    new_result_segm = inference_detector(model, img)
    os.makedirs(output_folder, exist_ok=True)
    output_file = os.path.join(output_folder, os.path.basename(img_path))
    
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    visualizer.add_datasample(
        'new_result_segm',
        img_rgb,
        data_sample=new_result_segm,        draw_gt=None,
        wait_time=0,
        out_file=output_file
    )
# Out:
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#   warnings.warn(
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(

# %% [markdown]
# ## Save results.pkl

# %%
# !python mmdetection/tools/test.py {config} {ckpt}  --out ./results/500-epochs-batch2/results.pkl
# Out:
# 08/14 21:05:44 - mmengine -
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# INFO -
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# ------------------------------------------------------------
# wandb:  $ pip install wandb --upgrade
# System environment:
# wandb: Tracking run with wandb version 0.17.5
#     sys.platform: win32
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\tutorial_exps\500-epochs-batch2\20240814_210537\vis_data\wandb\run-20240814_210547-ypxjoeeb
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb: Run `wandb offline` to turn off syncing.
#     CUDA available: True
# wandb: Syncing run azure-dew-92
#     MUSA available: False
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#     numpy_random_seed: 1256580830
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ypxjoeeb
#     GPU 0: NVIDIA RTX A4000
# c:\users\ja683\downloads\saf\mmdetection\mmdet\models\roi_heads\mask_heads\fcn_mask_head.py:339: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than tensor.new_tensor(sourceTensor).
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
#   mask_preds = bboxes.new_tensor(mask_preds)
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
# wandb: - 10.141 MB of 10.141 MB uploaded (10.122 MB deduped)
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
# wandb: \ 10.141 MB of 10.141 MB uploaded (10.122 MB deduped)
#     GCC: n/a
# wandb: | 10.141 MB of 10.141 MB uploaded (10.122 MB deduped)
#     PyTorch: 2.3.1
# wandb: / 10.224 MB of 10.260 MB uploaded (10.126 MB deduped)
#     PyTorch compiling details: PyTorch built with:
# wandb: - 10.224 MB of 10.260 MB uploaded (10.126 MB deduped)
#   - C++ Version: 201703
# wandb: \ 10.260 MB of 10.260 MB uploaded (10.126 MB deduped)
#   - MSVC 192930154
# wandb:
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
# wandb: W&B sync reduced upload amount by 98.7%
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
# wandb:  View run azure-dew-92 at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/ypxjoeeb
#   - OpenMP 2019
# wandb:  View project at: https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
#   - LAPACK is enabled (usually provided by MKL)
# wandb: Synced 6 W&B file(s), 0 media file(s), 2157 artifact file(s) and 0 other file(s)
#   - CPU capability usage: AVX2
# wandb: Find logs at: .\tutorial_exps\500-epochs-batch2\20240814_210537\vis_data\wandb\run-20240814_210547-ypxjoeeb\logs
#   - CUDA Runtime 12.1
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1256580830
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/14 21:05:45 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=8, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# launcher = 'none'
# load_from = 'tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00625, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.00625,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './tutorial_exps/500-epochs-batch2'
#
# 08/14 21:06:03 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/14 21:06:03 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/14 21:06:03 - mmengine - WARNING - The prefix is not set in metric class DumpDetResults.
# Loads checkpoint by local backend from path: tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth
# 08/14 21:06:03 - mmengine - INFO - Load checkpoint from tutorial_exps/500-epochs-batch2/best_coco_segm_mAP_epoch_498.pth
# 08/14 21:06:17 - mmengine - INFO - Epoch(test) [8/8]    eta: 0:00:00  time: 1.6880  data_time: 1.2636  memory: 1905
# 08/14 21:06:17 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 21:06:17 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.074 | 0.102  | 0.082  | 0.045 | 0.95  | nan   |
# | TansitionalMixing    | 0.115 | 0.157  | 0.129  | 0.124 | nan   | nan   |
# | DiffusiveMixing      | 0.013 | 0.03   | 0.012  | 0.013 | nan   | nan   |
# | spray                | 0.844 | 1.0    | 1.0    | nan   | nan   | 0.844 |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/14 21:06:17 - mmengine - INFO - bbox_mAP_copypaste: 0.261 0.322 0.306 0.061 0.950 0.844
# 08/14 21:06:17 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 21:06:17 - mmengine - INFO -
# +----------------------+-------+--------+--------+-------+-------+-------+
# | category             | mAP   | mAP_50 | mAP_75 | mAP_s | mAP_m | mAP_l |
# +----------------------+-------+--------+--------+-------+-------+-------+
# | ClassicalEvaporation | 0.069 | 0.102  | 0.082  | 0.044 | 0.8   | nan   |
# | TansitionalMixing    | 0.106 | 0.157  | 0.127  | 0.115 | nan   | nan   |
# | DiffusiveMixing      | 0.011 | 0.018  | 0.012  | 0.011 | nan   | nan   |
# | spray                | 0.9   | 1.0    | 1.0    | nan   | nan   | 0.9   |
# +----------------------+-------+--------+--------+-------+-------+-------+
# 08/14 21:06:17 - mmengine - INFO - segm_mAP_copypaste: 0.272 0.319 0.305 0.057 0.800 0.900
# 08/14 21:06:17 - mmengine - INFO - Results has been saved to ./results/500-epochs-batch2/results.pkl.
# 08/14 21:06:17 - mmengine - INFO - Epoch(test) [8/8]    coco/ClassicalEvaporation_precision: 0.0690  coco/TansitionalMixing_precision: 0.1060  coco/DiffusiveMixing_precision: 0.0110  coco/spray_precision: 0.9000  coco/bbox_mAP: 0.2610  coco/bbox_mAP_50: 0.3220  coco/bbox_mAP_75: 0.3060  coco/bbox_mAP_s: 0.0610  coco/bbox_mAP_m: 0.9500  coco/bbox_mAP_l: 0.8440  coco/segm_mAP: 0.2720  coco/segm_mAP_50: 0.3190  coco/segm_mAP_75: 0.3050  coco/segm_mAP_s: 0.0570  coco/segm_mAP_m: 0.8000  coco/segm_mAP_l: 0.9000  data_time: 1.2636  time: 1.6880

# %% [markdown]
# The masks are represented as a tensor of boolean values, these boolean tensors represent the masks directly, rather than as coordinates.

# %% [markdown]
# ## Log Analysis

# %%
# !pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.1
# Summary: Python plotting package
# Home-page:
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
#         =========================================================
#
#         1. This LICENSE AGREEMENT is between the Matplotlib Development Team
#         ("MDT"), and the Individual or Organization ("Licensee") accessing and
#         otherwise using matplotlib software in source or binary form and its
#         associated documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, MDT
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that MDT's
#         License Agreement and MDT's notice of copyright, i.e., "Copyright (c)
#         2012- Matplotlib Development Team; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib .
#
#         4. MDT is making matplotlib available to Licensee on an "AS
#         IS" basis.  MDT MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, MDT MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. MDT SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between MDT and
#         Licensee.  This License Agreement does not grant permission to use MDT
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib ,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
#
#         License agreement for matplotlib versions prior to 1.3.0
#         ========================================================
#
#         1. This LICENSE AGREEMENT is between John D. Hunter ("JDH"), and the
#         Individual or Organization ("Licensee") accessing and otherwise using
#         matplotlib software in source or binary form and its associated
#         documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, JDH
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that JDH's
#         License Agreement and JDH's notice of copyright, i.e., "Copyright (c)
#         2002-2011 John D. Hunter; All Rights Reserved" are retained in
#         matplotlib  alone or in any derivative version prepared by
#         Licensee.
#
#         3. In the event Licensee prepares a derivative work that is based on or
#         incorporates matplotlib  or any part thereof, and wants to
#         make the derivative work available to others as provided herein, then
#         Licensee hereby agrees to include in any such work a brief summary of
#         the changes made to matplotlib.
#
#         4. JDH is making matplotlib  available to Licensee on an "AS
#         IS" basis.  JDH MAKES NO REPRESENTATIONS OR WARRANTIES, EXPRESS OR
#         IMPLIED.  BY WAY OF EXAMPLE, BUT NOT LIMITATION, JDH MAKES NO AND
#         DISCLAIMS ANY REPRESENTATION OR WARRANTY OF MERCHANTABILITY OR FITNESS
#         FOR ANY PARTICULAR PURPOSE OR THAT THE USE OF MATPLOTLIB
#         WILL NOT INFRINGE ANY THIRD PARTY RIGHTS.
#
#         5. JDH SHALL NOT BE LIABLE TO LICENSEE OR ANY OTHER USERS OF MATPLOTLIB
#          FOR ANY INCIDENTAL, SPECIAL, OR CONSEQUENTIAL DAMAGES OR
#         LOSS AS A RESULT OF MODIFYING, DISTRIBUTING, OR OTHERWISE USING
#         MATPLOTLIB , OR ANY DERIVATIVE THEREOF, EVEN IF ADVISED OF
#         THE POSSIBILITY THEREOF.
#
#         6. This License Agreement will automatically terminate upon a material
#         breach of its terms and conditions.
#
#         7. Nothing in this License Agreement shall be deemed to create any
#         relationship of agency, partnership, or joint venture between JDH and
#         Licensee.  This License Agreement does not grant permission to use JDH
#         trademarks or trade name in a trademark sense to endorse or promote
#         products or services of Licensee, or any third party.
#
#         8. By copying, installing or otherwise using matplotlib,
#         Licensee agrees to be bound by the terms and conditions of this License
#         Agreement.
# Location: c:\users\ja683\appdata\roaming\python\python310\site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: mmdet, mmengine, pycocotools, seaborn

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib
print(matplotlib.rcParams['backend'])
# Out:
# module://matplotlib_inline.backend_inline

# %%
json_log = 'tutorial_exps/500-epochs-batch2/20240814_183529/vis_data/20240814_183529.json'

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py plot_curve \
  --keys loss \
  --title "Training Metrics" \
  --legend "Loss" \
  --backend TkAgg \
  --style darkgrid \
  --out tutorial_exps/500-epochs-batch2/20240814_183529/training_curves.png \
  {json_log}
# Out:
# plot curve of tutorial_exps/500-epochs-batch2/20240814_183529/vis_data/20240814_183529.json, metric is loss
# save curve to: tutorial_exps/500-epochs-batch2/20240814_183529/training_curves.png

# %% [markdown]
# ### Compute the average training speed.

# %%
# !python mmdetection/tools/analysis_tools/analyze_logs.py cal_train_time {json_log} --include-outliers
# Out:
# -----Analyze train time of tutorial_exps/500-epochs-batch2/20240814_183529/vis_data/20240814_183529.json-----
# slowest epoch 1, average time is 1.6415 s/iter
# fastest epoch 2, average time is 0.3384 s/iter
# time std over epochs is 0.0571
# average iter time: 0.3771 s/iter

# %% [markdown]
# ## Result Analysis

# %%
# !python mmdetection/tools/analysis_tools/analyze_results.py \
       {config} \
       ./results/500-epochs-batch2/results.pkl \
       ./results/500-epochs-batch2/vis_data \
       --show
# [Optional] Finish the wandb run
wandb.finish()
# Out:
# wandb: Currently logged in as: ahluwaliajyoti50 (ahluwaliajyoti50-university-of-sussex). Use `wandb login --relogin` to force relogin
# loading annotations into memory...
# Done (t=0.02s)
# wandb: wandb version 0.17.6 is available!  To upgrade, please run:
# creating index...
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.5
# index created!
# wandb: Run data is saved locally in C:\Users\ja683\Downloads\saf\results\500-epochs-batch2\vis_data\20240814_211021\vis_data\wandb\run-20240814_211031-j0g88ws4
# 08/14 21:10:28 - mmengine - INFO
# wandb: Run `wandb offline` to turn off syncing.
#  -
# wandb: Syncing run balmy-sunset-93
# ------------------------------------------------------------
# wandb:  View project at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project
# System environment:
#     sys.platform: win32
#     Python: 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50) [MSC v.1916 64 bit (AMD64)]
# wandb:  View run at https://wandb.ai/ahluwaliajyoti50-university-of-sussex/SAF_Project/runs/j0g88ws4
#     CUDA available: True
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:760: UserWarning: Warning: The bbox is out of bounds, the drawn bbox may not be in the image
#     MUSA available: False
#   warnings.warn(
#     numpy_random_seed: 1486975600
#     GPU 0: NVIDIA RTX A4000
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:831: UserWarning: Warning: The polygon is out of bounds, the drawn polygon may not be in the image
#   warnings.warn(
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v12.1
# C:\Users\ja683\AppData\Roaming\Python\Python310\site-packages\mmengine\visualization\visualizer.py:508: UserWarning: Warning: The text is out of bounds, the drawn text may not be in the image
#     NVCC: Cuda compilation tools, release 12.1, V12.1.66
#   warnings.warn(
#     MSVC: Microsoft (R) C/C++ Optimizing Compiler Version 19.35.32216.1 for x64
#     GCC: n/a
#     PyTorch: 2.3.1
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 201703
#   - MSVC 192930154
#   - Intel(R) oneAPI Math Kernel Library Version 2021.4-Product Build 20210904 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.3.6 (Git Hash 86e6af5974177e513fd3fee58425e1063e7f1361)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX2
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.7  (built against CUDA 12.2)
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.7, CXX_COMPILER=C:/cb/pytorch_1000000000000/work/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /Zc:__cplusplus /bigobj /FS /utf-8 -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE /wd4624 /wd4068 /wd4067 /wd4267 /wd4661 /wd4717 /wd4244 /wd4804 /wd4273, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=2.3.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=OFF, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.18.1
#     OpenCV: 4.10.0
#     MMEngine: 0.10.4
#
# Runtime environment:
#     cudnn_benchmark: False
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 1486975600
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 08/14 21:10:28 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# data_root = 'mmdetection/data/saf22/'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3,
#         max_keep_ckpts=1,
#         rule='greater',
#         save_best=[
#             'coco/bbox_mAP',
#             'coco/segm_mAP',
#         ],
#         save_last=True,
#         save_optimizer=True,
#         type='CheckpointHook'),
#     logger=dict(interval=8, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = 'mmdetection/configs/htc/htc_x101_32x4d_fpn_16x1_20e_coco_20200318-de97ae01.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=50)
# max_epochs = 20
# metainfo = dict(
#     classes=(
#         'ClassicalEvaporation',
#         'TansitionalMixing',
#         'DiffusiveMixing',
#         'spray',
#     ),
#     palette=[
#         (
#             13,
#             24,
#             103,
#         ),
#         (
#             167,
#             13,
#             13,
#         ),
#         (
#             91,
#             117,
#             249,
#         ),
#         (
#             203,
#             173,
#             55,
#         ),
#     ])
# model = dict(
#     backbone=dict(
#         base_width=4,
#         depth=101,
#         frozen_stages=1,
#         groups=32,
#         init_cfg=dict(
#             checkpoint='open-mmlab://resnext101_32x4d', type='Pretrained'),
#         norm_cfg=dict(requires_grad=True, type='BN'),
#         norm_eval=True,
#         num_stages=4,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         style='pytorch',
#         type='ResNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_seg=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             256,
#             512,
#             1024,
#             2048,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN_CARAFE'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(beta=1.0, loss_weight=1.0, type='SmoothL1Loss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 num_classes=4,
#                 reg_class_agnostic=True,
#                 roi_feat_size=7,
#                 type='Shared2FCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         interleaved=True,
#         mask_head=[
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead',
#                 with_conv_res=False),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#             dict(
#                 conv_out_channels=256,
#                 in_channels=256,
#                 loss_mask=dict(
#                     loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#                 num_classes=4,
#                 num_convs=4,
#                 type='HTCMaskHead'),
#         ],
#         mask_info_flow=True,
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         semantic_head=None,
#         semantic_roi_extractor=None,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='HybridTaskCascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.001),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='HybridTaskCascade')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.00625, momentum=0.9, type='SGD', weight_decay=0.0001),
#     type='OptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=500, start_factor=0.001, type='LinearLR'),
#     dict(
#         begin=0,
#         by_epoch=True,
#         end=20,
#         gamma=0.1,
#         milestones=[
#             16,
#             19,
#         ],
#         type='MultiStepLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     classwise=True,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_epochs=500, type='EpochBasedTrainLoop', val_interval=3)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=1,
#     dataset=dict(
#         ann_file='train/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='train/'),
#         data_root='mmdetection/data/saf22/',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 with_seg=True),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True, with_seg=True),
#     dict(keep_ratio=True, scale=(
#         1333,
#         800,
#     ), type='Resize'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='val/annotation_coco.json',
#         backend_args=None,
#         data_prefix=dict(img='val/'),
#         data_root='mmdetection/data/saf22/',
#         metainfo=dict(
#             classes=(
#                 'ClassicalEvaporation',
#                 'TansitionalMixing',
#                 'DiffusiveMixing',
#                 'spray',
#             ),
#             palette=[
#                 (
#                     13,
#                     24,
#                     103,
#                 ),
#                 (
#                     167,
#                     13,
#                     13,
#                 ),
#                 (
#                     91,
#                     117,
#                     249,
#                 ),
#                 (
#                     203,
#                     173,
#                     55,
#                 ),
#             ]),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1333,
#                 800,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='mmdetection/data/saf22/val/annotation_coco.json',
#     backend_args=None,
#     format_only=False,
#     metric=[
#         'bbox',
#         'segm',
#     ],
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#         dict(type='TensorboardVisBackend'),
#         dict(
#             init_kwargs=dict(
#                 config=dict(
#                     architecture='HTC_resnext101_32x4d',
#                     batch_size=1,
#                     classes=(
#                         'ClassicalEvaporation',
#                         'TansitionalMixing',
#                         'DiffusiveMixing',
#                         'spray',
#                     ),
#                     dataset='SAF22',
#                     epochs=500,
#                     learning_rate=0.00625,
#                     neck='FPN_CARAFE',
#                     optimizer='SGD',
#                     seed=0),
#                 entity='ahluwaliajyoti50-university-of-sussex',
#                 project='SAF_Project'),
#             type='WandbVisBackend'),
#     ])
# work_dir = './results/500-epochs-batch2/vis_data'
#
# 08/14 21:11:08 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 08/14 21:11:08 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [                                                  ] 0/8, elapsed: 0s, ETA:
# [>>>>                              ] 1/8, 0.0 task/s, elapsed: 23s, ETA:   160s
# [>>>>>>>>                          ] 2/8, 0.0 task/s, elapsed: 43s, ETA:   130s
# [>>>>>>>>>>>>                      ] 3/8, 0.0 task/s, elapsed: 67s, ETA:   112s
# [>>>>>>>>>>>>>>>>>                 ] 4/8, 0.1 task/s, elapsed: 77s, ETA:    77s
# [>>>>>>>>>>>>>>>>>>>>>             ] 5/8, 0.1 task/s, elapsed: 82s, ETA:    49s
# [>>>>>>>>>>>>>>>>>>>>>>>>>         ] 6/8, 0.1 task/s, elapsed: 88s, ETA:    29s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>     ] 7/8, 0.1 task/s, elapsed: 97s, ETA:    14s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 8/8, 0.1 task/s, elapsed: 103s, ETA:     0sImage shape: (1536, 2072)
# Resized masks shape: (16, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (7, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (5, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (7, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (36, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (17, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (36, 1536, 2072)
# Image shape: (1536, 2072)
# Resized masks shape: (24, 1536, 2072)

# %% [markdown]
# ## Confusion Matrix

# %%
# !python mmdetection/tools/analysis_tools/confusion_matrix.py \
        {config} \
        results/500-epochs-batch2/results.pkl \
        results/500-epochs-batch2 --show
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [                                                  ] 0/8, elapsed: 0s, ETA:
# [>>>>                             ] 1/8, 334.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>                         ] 2/8, 668.8 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>                     ] 3/8, 752.4 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>                ] 4/8, 1003.2 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>            ] 5/8, 1003.3 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>        ] 6/8, 1203.9 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>    ] 7/8, 1404.6 task/s, elapsed: 0s, ETA:     0s
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 8/8, 1605.2 task/s, elapsed: 0s, ETA:     0sFigure(1500x956.25)

# %%
# !pip install scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\ja683\appdata\roaming\python\python310\site-packages (3.9.1)
# Requirement already satisfied: seaborn in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from scikit-learn) (2.0.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ja683\appdata\local\anaconda3\envs\mdet\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ja683\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# ## Eval Metric from results.pkl file

# %%
# !python mmdetection/tools/analysis_tools/eval_metric.py \
        {config} \
        results/500-epochs-batch2/results.pkl
# Out:
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# 08/14 21:13:46 - mmengine - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.322
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.306
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.061
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.844
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.302
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.104
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.950
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.867
# 08/14 21:13:46 - mmengine - INFO - bbox_mAP_copypaste: 0.261 0.322 0.306 0.061 0.950 0.844
# 08/14 21:13:46 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.03s).
# Accumulating evaluation results...
# DONE (t=0.01s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.272
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.057
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.304
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.098
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.900
# 08/14 21:13:46 - mmengine - INFO - segm_mAP_copypaste: 0.272 0.319 0.305 0.057 0.800 0.900
# {'coco/bbox_mAP': 0.261, 'coco/bbox_mAP_50': 0.322, 'coco/bbox_mAP_75': 0.306, 'coco/bbox_mAP_s': 0.061, 'coco/bbox_mAP_m': 0.95, 'coco/bbox_mAP_l': 0.844, 'coco/segm_mAP': 0.272, 'coco/segm_mAP_50': 0.319, 'coco/segm_mAP_75': 0.305, 'coco/segm_mAP_s': 0.057, 'coco/segm_mAP_m': 0.8, 'coco/segm_mAP_l': 0.9}
