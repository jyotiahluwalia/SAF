# %%
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# PyTorch version: 2.3.1
# CUDA available: True
# CUDA version: 12.1

# %%
# Check mmengine installation
import mmengine
print(f"MMengine: {mmengine.__version__}")

# Check Openmim installation
from importlib.metadata import version
print(f"Openmim: {version('openmim')}")

# Check mmcv installation
import mmcv
print("mmcv:",mmcv.__version__)

# Check MMDetection installation
import mmdet
print("mmdetection:",mmdet.__version__)
# Out:
# MMengine: 0.10.4
# Openmim: 0.3.9
# mmcv: 2.0.0rc4
# mmdetection: 3.3.0

# %%
#from mmdet.apis import init_detector, inference_detector
#import mmcv
#import matplotlib.pyplot as plt

#config_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco.py'
#checkpoint_file = 'mmdetection/configs/htc/checkpoint/htc_r50_fpn_1x_coco_20200317-7332cf16.pth'
#model = init_detector(config_file, checkpoint_file, device='cpu')  # or device='cuda:0'
#inference_detector(model, 'mmdetection/demo/demo.jpg')

import mmcv
import mmengine
from mmdet.apis import init_detector, inference_detector
from mmdet.utils import register_all_modules
# Choose to use a config and initialize the detector
config_file = 'mmdetection/configs/htc/htc_r50_fpn_1x_coco.py'
# Setup a checkpoint file to load
checkpoint_file = 'mmdetection/configs/htc/checkpoint/htc_r50_fpn_1x_coco_20200317-7332cf16.pth'

# register all modules in mmdet into the registries
register_all_modules()

# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')  # or device='cuda:0'
# Out:
# c:\users\ja683\onedrive - university of sussex\htc\mmdetection\mmdet\models\losses\cross_entropy_loss.py:240: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# Loads checkpoint by local backend from path: mmdetection/configs/htc/checkpoint/htc_r50_fpn_1x_coco_20200317-7332cf16.pth

# %%
# Check the label of a single image
import mmengine

annotation = mmengine.load('./data/saf22/Labels/SAF22_COCO_CorentinDoche.json')

# %%
annotation['images']
# Out:
# [{'id': 1,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS001_frame_23.png',
#   'file_path': 'ABCCWS001_frame_23.png',
#   'date_captured': '20-Oct-2023 17:51:56'},
#  {'id': 2,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS001_frame_25.png',
#   'file_path': 'ABCCWS001_frame_25.png',
#   'date_captured': '20-Oct-2023 17:51:56'},
#  {'id': 3,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'BBCCWS001_frame_14.png',
#   'file_path': 'BBCCWS001_frame_14.png',
#   'date_captured': '20-Oct-2023 17:52:14'},
#  {'id': 4,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'BBCCWS001_frame_21.png',
#   'file_path': 'BBCCWS001_frame_21.png',
#   'date_captured': '20-Oct-2023 17:52:17'},
#  {'id': 5,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBKAVS001_frame_21.png',
#   'file_path': 'FBKAVS001_frame_21.png',
#   'date_captured': '20-Oct-2023 17:52:39'},
#  {'id': 6,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBKAVS001_frame_23.png',
#   'file_path': 'FBKAVS001_frame_23.png',
#   'date_captured': '20-Oct-2023 17:52:40'},
#  {'id': 7,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBKAVS001_frame_25.png',
#   'file_path': 'FBKAVS001_frame_25.png',
#   'date_captured': '20-Oct-2023 17:52:40'},
#  {'id': 8,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBIDVS003_frame_20.png',
#   'file_path': 'JBIDVS003_frame_20.png',
#   'date_captured': '23-Oct-2023 10:23:43'},
#  {'id': 9,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBIDVS003_frame_22.png',
#   'file_path': 'JBIDVS003_frame_22.png',
#   'date_captured': '23-Oct-2023 10:23:45'},
#  {'id': 10,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBIDVS003_frame_28.png',
#   'file_path': 'JBIDVS003_frame_28.png',
#   'date_captured': '23-Oct-2023 10:23:50'},
#  {'id': 11,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBVCVS002_frame_20.png',
#   'file_path': 'SBVCVS002_frame_20.png',
#   'date_captured': '24-Oct-2023 10:43:26'},
#  {'id': 12,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBVCVS002_frame_21.png',
#   'file_path': 'SBVCVS002_frame_21.png',
#   'date_captured': '24-Oct-2023 10:43:26'},
#  {'id': 13,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBVCVS002_frame_23.png',
#   'file_path': 'SBVCVS002_frame_23.png',
#   'date_captured': '24-Oct-2023 10:43:27'},
#  {'id': 14,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBVDVS002_frame_20.png',
#   'file_path': 'JBVDVS002_frame_20.png',
#   'date_captured': '24-Oct-2023 11:23:45'},
#  {'id': 15,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBVDVS002_frame_21.png',
#   'file_path': 'JBVDVS002_frame_21.png',
#   'date_captured': '24-Oct-2023 11:23:45'},
#  {'id': 16,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBVDVS002_frame_23.png',
#   'file_path': 'JBVDVS002_frame_23.png',
#   'date_captured': '24-Oct-2023 11:23:46'},
#  {'id': 17,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS001_frame_26.png',
#   'file_path': 'ABCCWS001_frame_26.png',
#   'date_captured': '20-Oct-2023 17:51:57'},
#  {'id': 18,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_20.png',
#   'file_path': 'ABTCWS004_frame_20.png',
#   'date_captured': '24-Oct-2023 14:24:21'},
#  {'id': 19,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_21.png',
#   'file_path': 'ABTCWS004_frame_21.png',
#   'date_captured': '24-Oct-2023 14:24:21'},
#  {'id': 20,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_23.png',
#   'file_path': 'ABTCWS004_frame_23.png',
#   'date_captured': '24-Oct-2023 14:24:22'},
#  {'id': 21,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS001_frame_13.png',
#   'file_path': 'ABCCWS001_frame_13.png',
#   'date_captured': '20-Oct-2023 17:51:53'},
#  {'id': 22,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS001_frame_14.png',
#   'file_path': 'ABCCWS001_frame_14.png',
#   'date_captured': '20-Oct-2023 17:51:53'},
#  {'id': 23,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_13.png',
#   'file_path': 'ABTCWS004_frame_13.png',
#   'date_captured': '24-Oct-2023 14:24:18'},
#  {'id': 24,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBKAVS001_frame_14.png',
#   'file_path': 'FBKAVS001_frame_14.png',
#   'date_captured': '20-Oct-2023 17:52:38'},
#  {'id': 25,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBIDVS003_frame_13.png',
#   'file_path': 'JBIDVS003_frame_13.png',
#   'date_captured': '23-Oct-2023 10:23:40'},
#  {'id': 26,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'BBXCWS003_frame_26.png',
#   'file_path': 'BBXCWS003_frame_26.png',
#   'date_captured': '26-Oct-2023 09:54:12'},
#  {'id': 27,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBXCWS001_frame_20.png',
#   'file_path': 'FBXCWS001_frame_20.png',
#   'date_captured': '02-Nov-2023 14:32:56'},
#  {'id': 28,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBXCWS001_frame_21.png',
#   'file_path': 'FBXCWS001_frame_21.png',
#   'date_captured': '26-Oct-2023 10:16:11'},
#  {'id': 29,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBXCWS001_frame_22.png',
#   'file_path': 'FBXCWS001_frame_22.png',
#   'date_captured': '26-Oct-2023 10:16:11'},
#  {'id': 30,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBXCWS001_frame_24.png',
#   'file_path': 'FBXCWS001_frame_24.png',
#   'date_captured': '26-Oct-2023 10:16:12'},
#  {'id': 31,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBXCWS001_frame_26.png',
#   'file_path': 'FBXCWS001_frame_26.png',
#   'date_captured': '26-Oct-2023 10:16:12'},
#  {'id': 32,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBTCWS003_frame_21.png',
#   'file_path': 'SBTCWS003_frame_21.png',
#   'date_captured': '26-Oct-2023 11:46:30'},
#  {'id': 33,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBTCWS003_frame_22.png',
#   'file_path': 'SBTCWS003_frame_22.png',
#   'date_captured': '26-Oct-2023 11:46:30'},
#  {'id': 34,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBTCWS003_frame_23.png',
#   'file_path': 'SBTCWS003_frame_23.png',
#   'date_captured': '02-Nov-2023 14:41:30'},
#  {'id': 35,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBTCWS003_frame_24.png',
#   'file_path': 'SBTCWS003_frame_24.png',
#   'date_captured': '02-Nov-2023 11:47:13'},
#  {'id': 36,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBTCWS003_frame_26.png',
#   'file_path': 'SBTCWS003_frame_26.png',
#   'date_captured': '02-Nov-2023 14:50:13'},
#  {'id': 37,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS001_frame_22.png',
#   'file_path': 'ABCCWS001_frame_22.png',
#   'date_captured': '27-Oct-2023 12:07:47'},
#  {'id': 38,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_24.png',
#   'file_path': 'ABTCWS004_frame_24.png',
#   'date_captured': '24-Oct-2023 14:24:22'},
#  {'id': 39,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'BBCCWS001_frame_13.png',
#   'file_path': 'BBCCWS001_frame_13.png',
#   'date_captured': '20-Oct-2023 17:52:14'},
#  {'id': 40,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'FBXCWS001_frame_14.png',
#   'file_path': 'FBXCWS001_frame_14.png',
#   'date_captured': '26-Oct-2023 10:16:09'},
#  {'id': 41,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'JBKLWS002_frame_13.png',
#   'file_path': 'JBKLWS002_frame_13.png',
#   'date_captured': '26-Oct-2023 09:04:18'},
#  {'id': 42,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABXCWS002_frame_25.png',
#   'file_path': 'ABXCWS002_frame_25.png',
#   'date_captured': '17-Nov-2023 10:47:23'},
#  {'id': 43,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABXCWS002_frame_27.png',
#   'file_path': 'ABXCWS002_frame_27.png',
#   'date_captured': '17-Nov-2023 10:47:24'},
#  {'id': 44,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'SBTCWS003_frame_27.png',
#   'file_path': 'SBTCWS003_frame_27.png',
#   'date_captured': '26-Oct-2023 11:46:32'},
#  {'id': 45,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_25.png',
#   'file_path': 'ABTCWS004_frame_25.png',
#   'date_captured': '24-Oct-2023 14:24:23'},
#  {'id': 46,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS004_frame_28.png',
#   'file_path': 'ABTCWS004_frame_28.png',
#   'date_captured': '24-Oct-2023 14:24:24'},
#  {'id': 47,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS002_frame_21.png',
#   'file_path': 'ABTCWS002_frame_21.png',
#   'date_captured': '20-Nov-2023 15:59:17'},
#  {'id': 48,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS002_frame_23.png',
#   'file_path': 'ABTCWS002_frame_23.png',
#   'date_captured': '20-Nov-2023 15:59:17'},
#  {'id': 49,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS002_frame_24.png',
#   'file_path': 'ABTCWS002_frame_24.png',
#   'date_captured': '20-Nov-2023 15:59:17'},
#  {'id': 50,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS002_frame_39.png',
#   'file_path': 'ABTCWS002_frame_39.png',
#   'date_captured': '20-Nov-2023 15:59:22'},
#  {'id': 51,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABTCWS002_frame_26.png',
#   'file_path': 'ABTCWS002_frame_26.png',
#   'date_captured': '20-Nov-2023 15:59:18'},
#  {'id': 52,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS002_frame_21.png',
#   'file_path': 'ABCCWS002_frame_21.png',
#   'date_captured': '21-Nov-2023 10:07:31'},
#  {'id': 53,
#   'width': 2072,
#   'height': 1536,
#   'file_name': 'ABCCWS002_frame_24.png',
#   'file_path': 'ABCCWS002_frame_24.png',
#   'date_captured': '21-Nov-2023 10:07:32'}]
